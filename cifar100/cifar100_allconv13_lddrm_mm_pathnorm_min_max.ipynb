# %%
import os
import math
import mxnet as mx
from mxnet import image
from mxnet import nd, gluon, autograd, init
from mxnet.gluon.data.vision import ImageFolderDataset
from mxnet.gluon.data import DataLoader
from mxnet.gluon import nn
from tensorboardX import SummaryWriter
import numpy as np
import shutil
import _pickle as cPickle
from sklearn import preprocessing
from mxnet.gluon.parameter import Parameter, ParameterDict
from common.util import download_file
import subprocess

from IPython.core.debugger import Tracer

# %%
def unpickle(file):
    fo = open(file, 'rb')
    dict = cPickle.load(fo, encoding='bytes')
    fo.close()
    return dict

# %%
class Options:
    def __init__(self):
        self.seed_val = 0
        self.num_train_sup = 10000
        self.batch_size = 128
        self.data_dir = '/tanData/datasets/cifar100'
        self.log_dir = '/tanData/logs'
        self.model_dir ='/tanData/models'
        self.exp_name = 'cifar100_nlabels_%i_allconv13_lddrm_mm_pathnorm_min_max_seed_%i'%(self.num_train_sup, self.seed_val)
        self.ctx = mx.gpu(0)
        self.alpha_drm = 0.5
        self.alpha_pn = 1.0
        self.alpha_kl = 0.5
        self.alpha_nn = 0.5
        self.alpha_min = 0.5
        self.alpha_max = 1.0 - self.alpha_min
        
        self.use_bias = True
        self.use_bn = True
        self.do_topdown = True
        self.do_countpath = False
        self.do_pn = True
        self.relu_td = False
        self.do_nn = True
        self.min_max = True

opt = Options()

# %%
# Preparing the data step 1
meta = unpickle(os.path.join(opt.data_dir, 'meta'))
class_name = meta[b'fine_label_names']

with open(os.path.join(opt.data_dir, 'cifar100_train.lst'), 'r') as f:
    lines = f.readlines()
    tokens = [i.rstrip().split('\t') for i in lines]
    idx_label = dict((int(idx), class_name[int(label)].decode("utf-8")) for idx, label, _ in tokens)
    idx_name = dict((name, int(idx)) for idx, _, name in tokens)
    
labels = set(idx_label.values())

num_train = len(os.listdir(os.path.join(opt.data_dir, 'train')))

num_train_tuning = int(num_train * (1 - 0.1))

num_train_tuning_per_label = num_train_tuning // len(labels)

num_train_sup = opt.num_train_sup

num_train_sup_per_label = num_train_sup // len(labels)

ratio_unsup_sup = (num_train - num_train_sup) // num_train_sup

# select labeled data
data_rng = np.random.RandomState(opt.seed_val)
indx = data_rng.permutation(range(1, num_train + 1))
indx_sup = []

for c in labels:
    c_count = 0
    for i in indx:
        if idx_label[i] == c and c_count < num_train_sup_per_label:
            indx_sup.append(i)
            c_count += 1
        if c_count >= num_train_sup_per_label:
            break
            
label_count = dict()
# print(indx_sup)
# for i in indx_sup:
#     print(idx_label[i])

def mkdir_if_not_exist(path):
    if not os.path.exists(os.path.join(*path)):
        os.makedirs(os.path.join(*path))
        
for train_file in os.listdir(os.path.join(opt.data_dir, 'train')):
    idx = idx_name[train_file]
    label = idx_label[idx]
    if idx in indx_sup:
        mkdir_if_not_exist([opt.data_dir, 'train_valid_sup_nsup_%i_seed_%i'%(opt.num_train_sup, opt.seed_val), label])
        for i in range(ratio_unsup_sup):
            shutil.copy(os.path.join(opt.data_dir,'train', train_file),
                        os.path.join(opt.data_dir, 'train_valid_sup_nsup_%i_seed_%i'%(opt.num_train_sup, opt.seed_val), label, '%i_%i.png'%(idx, i)))
    else:
        mkdir_if_not_exist([opt.data_dir, 'train_valid_unsup_nsup_%i_seed_%i'%(opt.num_train_sup, opt.seed_val), label])
        shutil.copy(os.path.join(opt.data_dir,'train', train_file),
                   os.path.join(opt.data_dir, 'train_valid_unsup_nsup_%i_seed_%i'%(opt.num_train_sup, opt.seed_val), label))

# %%
# %%bash -s "$opt.num_train_sup" "$opt.seed_val"
# DATA_DIR=/tanData/datasets/cifar100
# data_name=( "train_valid_sup_nsup_$1_seed_$2" "train_valid_unsup_nsup_$1_seed_$2" )
# list_name=( "cifar100_train_valid_sup_nsup_$1_seed_$2" "cifar100_train_valid_unsup_nsup_$1_seed_$2" )
# MX_DIR=/mxnet
#
# for ((i=0;i<${#data_name[@]};++i)); do
#     # clean stuffs
#     rm -rf ${DATA_DIR}/${list_name[i]}.*
#     # make list for all classes
#     python ${MX_DIR}/tools/im2rec.py --list --exts '.png' --recursive ${DATA_DIR}/${list_name[i]} ${DATA_DIR}/${data_name[i]}
#     # make .rec file for all classes
#     python ${MX_DIR}/tools/im2rec.py --exts '.png' --quality 95 --num-thread 16 --color 1 ${DATA_DIR}/${list_name[i]} ${DATA_DIR}/${data_name[i]}
#     # remove folders
#     rm -rf ${DATA_DIR}/${data_name[i]}
# done

# %%
def gpu_device(ctx=mx.gpu(0)):
    try:
        _ = mx.nd.array([1, 2, 3], ctx=ctx)
    except mx.MXNetError:
        return None
    return ctx

assert gpu_device(opt.ctx), 'No GPU device found!'

# %%
log_dir = os.path.join(opt.log_dir, opt.exp_name)
if not os.path.exists(log_dir):
    os.makedirs(log_dir)

# %%
data_shape = (3, 32, 32)
train_data_unsup = mx.io.ImageRecordIter(
    path_imgrec = os.path.join(opt.data_dir,'cifar100_train_valid_unsup_nsup_%i_seed_%i.rec'%(opt.num_train_sup, opt.seed_val)),
    data_shape  = data_shape,
    batch_size  = opt.batch_size // 2,
    mean_r             = 129.3,
    mean_g             = 124.1,
    mean_b             = 112.4,
    std_r              = 68.2,
    std_g              = 65.4,
    std_b              = 70.4,
    shuffle = True,
    ## Data augmentation
    rand_crop   = True,
    max_crop_size = 32,
    min_crop_size = 32,
    pad = 4,
    fill_value = 0,
    rand_mirror = True)
train_data_sup = mx.io.ImageRecordIter(
    path_imgrec = os.path.join(opt.data_dir,'cifar100_train_valid_sup_nsup_%i_seed_%i.rec'%(opt.num_train_sup, opt.seed_val)),
    data_shape  = data_shape,
    batch_size  = opt.batch_size // 2,
    mean_r             = 129.3,
    mean_g             = 124.1,
    mean_b             = 112.4,
    std_r              = 68.2,
    std_g              = 65.4,
    std_b              = 70.4,
    shuffle = True,
    ## Data augmentation
    rand_crop   = True,
    max_crop_size = 32,
    min_crop_size = 32,
    pad = 4,
    fill_value = 0,
    rand_mirror = True)
valid_data = mx.io.ImageRecordIter(
    path_imgrec = os.path.join(opt.data_dir,'cifar100_val.rec'),
    data_shape  = data_shape,
    batch_size  = opt.batch_size // 2,
    mean_r             = 129.3,
    mean_g             = 124.1,
    mean_b             = 112.4,
    std_r              = 68.2,
    std_g              = 65.4,
    std_b              = 70.4,
    ## No data augmentation
    rand_crop   = False,
    rand_mirror = False)

# %%
criterion = gluon.loss.SoftmaxCrossEntropyLoss()
L2_loss = gluon.loss.L2Loss()
L1_loss = gluon.loss.L1Loss()

# %%
class Normal(mx.init.Initializer):
    """Initializes weights with random values sampled from a normal distribution
    with a mean and standard deviation of `sigma`.
    """
    def __init__(self, mean=0, sigma=0.01):
        super(Normal, self).__init__(sigma=sigma)
        self.sigma = sigma
        self.mean = mean

    def _init_weight(self, _, arr):
        mx.random.normal(self.mean, self.sigma, out=arr)

# %%
# from resnet import ResNet164_v2
from mxnet.gluon.model_zoo import vision as models
from vgg_ld_opt_min_max import VGG_DRM

# %%
import datetime
writer = SummaryWriter(os.path.join(opt.log_dir, opt.exp_name))

def get_acc(output, label):
    pred = output.argmax(1, keepdims=False)
    correct = (pred == label).sum()
    return correct.asscalar()

def extract_acts(net, x, layer_indx):
    start_layer = 0
    out = []
    for i in layer_indx:
        for block in net.features._children[start_layer:i]:
            x = block(x)
        out.append(x)
        start_layer = i
    return out

# %%
def train(net, train_data_unsup, train_data_sup, valid_data, num_epochs, lr, wd, ctx, lr_decay, relu_indx):
    trainer = gluon.Trainer(
        net.collect_params(), 'adam', {'learning_rate': 0.001, 'wd': wd})
    
    prev_time = datetime.datetime.now()
    best_valid_acc = 0; best_valid_acc2 = 0; best_valid_accmax = 0; best_valid_accmin = 0
    iter_indx = 0
    
    for epoch in range(num_epochs-100):
        train_data_unsup.reset(); train_data_sup.reset()
        train_loss = 0; train_loss_xentropy = 0; train_loss_drm = 0; train_loss_pn = 0; train_loss_kl = 0; train_loss_nn = 0
        correct = 0; total = 0; correct2=0; correctmax=0; correctmin=0
        num_batch_train = 0
        
        if epoch == 20:
            sgd_lr = 0.15
            decay_val = np.exp(np.log(sgd_lr / 0.0001) / (num_epochs - 2))
            sgd_lr = sgd_lr * decay_val
            trainer = gluon.Trainer(net.collect_params(), 'SGD', {'learning_rate': sgd_lr, 'wd': wd})
            
        if epoch >= 20:
            trainer.set_learning_rate(trainer.learning_rate / decay_val)
        
        for batch_unsup, batch_sup in zip(train_data_unsup, train_data_sup):
            assert batch_unsup.data[0].shape[0] == batch_sup.data[0].shape[0], "batch_unsup and batch_sup must have the same size"
            bs = batch_unsup.data[0].shape[0]
            data_unsup = batch_unsup.data[0].as_in_context(ctx)
            label_unsup = batch_unsup.label[0].as_in_context(ctx)
            data_sup = batch_sup.data[0].as_in_context(ctx)
            label_sup = batch_sup.label[0].as_in_context(ctx)
            with autograd.record():
                [output_unsup, output_min_unsup, xhat_unsup, xhat_min_unsup, _, loss_pn_unsup, loss_nn_unsup] = net(data_unsup)
                loss_drm_unsup = opt.alpha_max * L2_loss(xhat_unsup, data_unsup) + opt.alpha_min * L2_loss(xhat_min_unsup, data_unsup)
                softmax_unsup = opt.alpha_max * nd.softmax(output_unsup) + opt.alpha_min * nd.softmax(output_min_unsup)
                loss_kl_unsup = -nd.sum(nd.log(100.0*softmax_unsup + 1e-8) * softmax_unsup, axis=1)
                loss_unsup = opt.alpha_drm * loss_drm_unsup + opt.alpha_kl * loss_kl_unsup + opt.alpha_nn * loss_nn_unsup + opt.alpha_pn * loss_pn_unsup
                
                [output_sup, output_min_sup, xhat_sup, xhat_min_sup, _, loss_pn_sup, loss_nn_sup] = net(data_sup, label_sup)
                loss_xentropy_sup = opt.alpha_max * criterion(output_sup, label_sup) + opt.alpha_min * criterion(output_min_sup, label_sup)
                loss_drm_sup = opt.alpha_max * L2_loss(xhat_sup, data_sup) + opt.alpha_min * L2_loss(xhat_min_sup, data_sup)
                softmax_sup = opt.alpha_max * nd.softmax(output_sup) + opt.alpha_min * nd.softmax(output_min_sup)
                loss_kl_sup = -nd.sum(nd.log(100.0*softmax_sup + 1e-8) * softmax_sup, axis=1)
                loss_sup = loss_xentropy_sup + opt.alpha_drm * loss_drm_sup + opt.alpha_kl * loss_kl_sup + opt.alpha_nn * loss_nn_sup + opt.alpha_pn * loss_pn_sup
                
                loss = loss_unsup + loss_sup
                
            loss.backward()
            trainer.step(bs)
            
            loss_drm = loss_drm_unsup + loss_drm_sup
            loss_pn = loss_pn_unsup + loss_pn_sup
            loss_xentropy = loss_xentropy_sup
            loss_kl = loss_kl_unsup + loss_kl_sup
            loss_nn = loss_nn_unsup + loss_nn_sup
            
            train_loss_xentropy += nd.mean(loss_xentropy).asscalar()
            train_loss_drm += nd.mean(loss_drm).asscalar()
            train_loss_pn += nd.mean(loss_pn).asscalar()
            train_loss_kl += nd.mean(loss_kl).asscalar()
            train_loss_nn += nd.mean(loss_nn).asscalar()
            train_loss += nd.mean(loss).asscalar()
            correct += (get_acc(opt.alpha_max * output_sup + opt.alpha_min * output_min_sup, label_sup) + get_acc(opt.alpha_max * output_unsup + opt.alpha_min * output_min_unsup, label_unsup))/2
            correct2 += (opt.alpha_max * get_acc(output_sup, label_sup) + opt.alpha_min * get_acc(output_min_sup, label_sup) + opt.alpha_max * get_acc(output_unsup, label_unsup) + opt.alpha_min * get_acc(output_min_unsup, label_unsup))/2
            correctmax += (get_acc(output_sup, label_sup) + get_acc(output_unsup, label_unsup))/2
            correctmin += (get_acc(output_min_sup, label_sup) + get_acc(output_min_unsup, label_unsup))/2
            
            total += bs
            num_batch_train += 1
            iter_indx += 1
        
        writer.add_scalars('loss', {'train': train_loss / num_batch_train}, epoch)
        writer.add_scalars('loss_xentropy', {'train': train_loss_xentropy / num_batch_train}, epoch)
        writer.add_scalars('loss_drm', {'train': train_loss_drm / num_batch_train}, epoch)
        writer.add_scalars('loss_pn', {'train': train_loss_pn / num_batch_train}, epoch)
        writer.add_scalars('loss_kl', {'train': train_loss_kl / num_batch_train}, epoch)
        writer.add_scalars('loss_nn', {'train': train_loss_nn / num_batch_train}, epoch)
        writer.add_scalars('acc', {'train': correct / total}, epoch)
        writer.add_scalars('acc', {'train2': correct2 / total}, epoch)
        writer.add_scalars('acc', {'trainmax': correctmax / total}, epoch)
        writer.add_scalars('acc', {'trainmin': correctmin / total}, epoch)
        
        cur_time = datetime.datetime.now()
        h, remainder = divmod((cur_time - prev_time).seconds, 3600)
        m, s = divmod(remainder, 60)
        time_str = "Time %02d:%02d:%02d" % (h, m, s)
        if valid_data is not None:
            valid_data.reset()
            valid_loss = 0; valid_loss_xentropy = 0; valid_loss_drm = 0; valid_loss_pn = 0; valid_loss_kl = 0; valid_loss_nn = 0
            valid_correct = 0; valid_total = 0; valid_correct2 = 0; valid_correctmax = 0; valid_correctmin = 0
            num_batch_valid = 0
            for batch in valid_data:
                bs = batch.data[0].shape[0]
                data = batch.data[0].as_in_context(ctx)
                label = batch.label[0].as_in_context(ctx)
                [output, output_min, xhat, xhat_min, _, loss_pn, loss_nn] = net(data, label)
                loss_xentropy = opt.alpha_max * criterion(output, label) + opt.alpha_min * criterion(output_min, label)
                loss_drm = opt.alpha_max * L2_loss(xhat, data) + opt.alpha_min * L2_loss(xhat_min, data)
                softmax_val = opt.alpha_max * nd.softmax(output) + opt.alpha_min * nd.softmax(output_min)
                loss_kl = -nd.sum(nd.log(100.0*softmax_val + 1e-8) * softmax_val, axis=1)
                loss = loss_xentropy + opt.alpha_drm * loss_drm + opt.alpha_kl * loss_kl + opt.alpha_nn * loss_nn + opt.alpha_pn * loss_pn
                
                valid_loss_xentropy += nd.mean(loss_xentropy).asscalar()
                valid_loss_drm += nd.mean(loss_drm).asscalar()
                valid_loss_pn += nd.mean(loss_pn).asscalar()
                valid_loss_kl += nd.mean(loss_kl).asscalar()
                valid_loss_nn += nd.mean(loss_nn).asscalar()
                valid_loss += nd.mean(loss).asscalar()
                valid_correct += get_acc(opt.alpha_max * output + opt.alpha_min * output_min, label)
                valid_correct2 += opt.alpha_max * get_acc(output, label) + opt.alpha_min * get_acc(output_min, label)
                valid_correctmax += get_acc(output, label)
                valid_correctmin += get_acc(output_min, label)
                
                valid_total += bs
                num_batch_valid += 1
            valid_acc = valid_correct / valid_total
            valid_acc2 = valid_correct2 / valid_total
            valid_accmax = valid_correctmax / valid_total
            valid_accmin = valid_correctmin / valid_total
            if valid_acc > best_valid_acc:
                best_valid_acc = valid_acc
                net.collect_params().save('%s/%s_best.params'%(opt.model_dir, opt.exp_name))
            if valid_acc2 > best_valid_acc2:
                best_valid_acc2 = valid_acc2
                net.collect_params().save('%s/%s_best_2.params'%(opt.model_dir, opt.exp_name))
            if valid_accmax > best_valid_accmax:
                best_valid_accmax = valid_accmax
                net.collect_params().save('%s/%s_best_max.params'%(opt.model_dir, opt.exp_name))
            if valid_accmin > best_valid_accmin:
                best_valid_accmin = valid_accmin
                net.collect_params().save('%s/%s_best_min.params'%(opt.model_dir, opt.exp_name))
            writer.add_scalars('loss', {'valid': valid_loss / num_batch_valid}, epoch)
            writer.add_scalars('loss_xentropy', {'valid': valid_loss_xentropy / num_batch_valid}, epoch)
            writer.add_scalars('loss_drm', {'valid': valid_loss_drm / num_batch_valid}, epoch)
            writer.add_scalars('loss_pn', {'valid': valid_loss_pn / num_batch_valid}, epoch)
            writer.add_scalars('loss_kl', {'valid': valid_loss_kl / num_batch_valid}, epoch)
            writer.add_scalars('loss_nn', {'valid': valid_loss_nn / num_batch_valid}, epoch)
            writer.add_scalars('acc', {'valid': valid_acc}, epoch)
            writer.add_scalars('acc', {'valid2': valid_acc2}, epoch)
            writer.add_scalars('acc', {'validmax': valid_accmax}, epoch)
            writer.add_scalars('acc', {'validmin': valid_accmin}, epoch)
            epoch_str = ("Epoch %d. Train Loss: %f, Train Xent: %f, Train Reconst: %f, Train Pn: %f, Train acc %f, Valid Loss: %f, Valid acc %f, Valid acc2 %f, Valid accmax %f, Valid accmin %f, Best valid acc %f, Best valid acc2 %f, Best valid accmax %f, Best valid accmin %f, "
                         % (epoch, train_loss / num_batch_train, train_loss_xentropy / num_batch_train, train_loss_drm / num_batch_train, train_loss_pn / num_batch_train,
                            correct / total, valid_loss / num_batch_valid, valid_acc, valid_acc2, valid_accmax, valid_accmin, best_valid_acc, best_valid_acc2, best_valid_accmax, best_valid_accmin))
            
            # net.collect_params().save('%s/%s_latest.params'%(opt.model_dir, opt.exp_name))
            if not epoch % 20:
                net.collect_params().save('%s/%s_epoch_%i.params'%(opt.model_dir, opt.exp_name, epoch))
        else:
            epoch_str = ("Epoch %d. Loss: %f, Train acc %f, "
                         % (epoch, train_loss / num_batch_train,
                            correct / total))
        prev_time = cur_time
        print(epoch_str + time_str + ', lr ' + str(trainer.learning_rate))
        
    return best_valid_acc

# %%
num_epochs = 500
learning_rate = 0.15
weight_decay = 5e-4
lr_decay = 0.1

# %%
def run_train(num_exp, ctx):
    valid_acc = 0
    for i in range(num_exp):
        ### CIFAR VGG_DRM
        model = VGG_DRM('AllConv13', batch_size=opt.batch_size // 2, num_class=100, use_bias=opt.use_bias, use_bn=opt.use_bn, do_topdown=opt.do_topdown, do_countpath=opt.do_countpath, do_pn=opt.do_pn, relu_td=opt.relu_td, do_nn=opt.do_nn, min_max=opt.min_max)
        for param in model.collect_params().values():
            if param.name.find('conv') != -1 or param.name.find('dense') != -1:
                if param.name.find('weight') != -1:
                    param.initialize(init=mx.initializer.Xavier(), ctx=ctx)
                else:
                    param.initialize(init=mx.init.Zero(), ctx=ctx)
            elif param.name.find('batchnorm') != -1 or param.name.find('instancenorm') != -1:
                if param.name.find('gamma') != -1:
                    param.initialize(init=Normal(mean=1, sigma=0.02), ctx=ctx)
                else:
                    param.initialize(init=mx.init.Zero(), ctx=ctx)
            elif param.name.find('biasadder') != -1:
                param.initialize(init=mx.init.Zero(), ctx=ctx)
        
        # model.collect_params().load('%s/%s_epoch_%i.params'%(opt.model_dir, opt.exp_name, 380), ctx=ctx)
        # model.hybridize()
        
        relu_indx = []
        
        for i in range(len(model.features._children)):
            if model.features._children[i].name.find('relu') != -1:
                relu_indx.append(i)
                
        acc = train(model, train_data_unsup, train_data_sup, valid_data, num_epochs, learning_rate, weight_decay, ctx, lr_decay, relu_indx)
        print('Validation Accuracy - Run %i = %f'%(i, acc))
        valid_acc += acc

    print('Validation Accuracy = %f'%(valid_acc/num_exp))

# %%
run_train(1, ctx=opt.ctx)
# Out:
# Epoch 381. Train Loss: -2.247031, Train Xent: 0.000907, Train Reconst: 0.014904, Train Pn: 0.000133, Train acc 0.931970, Valid Loss: 1.077986, Valid acc 0.870920, Valid acc2 0.867436, Valid accmax 0.870521, Valid accmin 0.864351, Best valid acc 0.870920, Best valid acc2 0.867436, Best valid accmax 0.870521, Best valid accmin 0.864351, Time 00:04:46, lr 0.000755708594883
# Epoch 382. Train Loss: -2.246813, Train Xent: 0.000732, Train Reconst: 0.014416, Train Pn: 0.000126, Train acc 0.932383, Valid Loss: 1.040399, Valid acc 0.871194, Valid acc2 0.868339, Valid accmax 0.870393, Valid accmin 0.866286, Best valid acc 0.871194, Best valid acc2 0.868339, Best valid accmax 0.870521, Best valid accmin 0.866286, Time 00:04:55, lr 0.000752639572421
# Epoch 383. Train Loss: -2.246853, Train Xent: 0.000759, Train Reconst: 0.014445, Train Pn: 0.000128, Train acc 0.932140, Valid Loss: 1.070378, Valid acc 0.870593, Valid acc2 0.866887, Valid accmax 0.869591, Valid accmin 0.864183, Best valid acc 0.871194, Best valid acc2 0.868339, Best valid accmax 0.870521, Best valid accmin 0.866286, Time 00:04:57, lr 0.000749583013623
# Epoch 384. Train Loss: -2.246659, Train Xent: 0.000851, Train Reconst: 0.014808, Train Pn: 0.000130, Train acc 0.932246, Valid Loss: 1.063040, Valid acc 0.872095, Valid acc2 0.868740, Valid accmax 0.871795, Valid accmin 0.865685, Best valid acc 0.872095, Best valid acc2 0.868740, Best valid accmax 0.871795, Best valid accmin 0.866286, Time 00:04:56, lr 0.000746538867874
# Epoch 385. Train Loss: -2.247030, Train Xent: 0.000921, Train Reconst: 0.014706, Train Pn: 0.000128, Train acc 0.932629, Valid Loss: 1.057460, Valid acc 0.870721, Valid acc2 0.867436, Valid accmax 0.868929, Valid accmin 0.865943, Best valid acc 0.872095, Best valid acc2 0.868740, Best valid accmax 0.871795, Best valid accmin 0.866286, Time 00:04:58, lr 0.000743507084763
# Epoch 386. Train Loss: -2.246570, Train Xent: 0.000781, Train Reconst: 0.014642, Train Pn: 0.000126, Train acc 0.932553, Valid Loss: 1.051765, Valid acc 0.872296, Valid acc2 0.868540, Valid accmax 0.871394, Valid accmin 0.865685, Best valid acc 0.872296, Best valid acc2 0.868740, Best valid accmax 0.871795, Best valid accmin 0.866286, Time 00:04:57, lr 0.000740487614084
# Epoch 387. Train Loss: -2.246903, Train Xent: 0.000823, Train Reconst: 0.014600, Train Pn: 0.000127, Train acc 0.932254, Valid Loss: 1.045437, Valid acc 0.870994, Valid acc2 0.868740, Valid accmax 0.870693, Valid accmin 0.866787, Best valid acc 0.872296, Best valid acc2 0.868740, Best valid accmax 0.871795, Best valid accmin 0.866787, Time 00:04:57, lr 0.000737480405834
# Epoch 388. Train Loss: -2.246867, Train Xent: 0.000877, Train Reconst: 0.014742, Train Pn: 0.000132, Train acc 0.932110, Valid Loss: 1.051796, Valid acc 0.868590, Valid acc2 0.866587, Valid accmax 0.869091, Valid accmin 0.864083, Best valid acc 0.872296, Best valid acc2 0.868740, Best valid accmax 0.871795, Best valid accmin 0.866787, Time 00:04:57, lr 0.000734485410215
# Epoch 389. Train Loss: -2.246634, Train Xent: 0.000779, Train Reconst: 0.014653, Train Pn: 0.000133, Train acc 0.932322, Valid Loss: 1.024365, Valid acc 0.872114, Valid acc2 0.869377, Valid accmax 0.872014, Valid accmin 0.866740, Best valid acc 0.872296, Best valid acc2 0.869377, Best valid accmax 0.872014, Best valid accmin 0.866787, Time 00:04:57, lr 0.000731502577629
# Epoch 390. Train Loss: -2.246928, Train Xent: 0.000827, Train Reconst: 0.014792, Train Pn: 0.000130, Train acc 0.932178, Valid Loss: 1.019358, Valid acc 0.872196, Valid acc2 0.869491, Valid accmax 0.871595, Valid accmin 0.867388, Best valid acc 0.872296, Best valid acc2 0.869491, Best valid accmax 0.872014, Best valid accmin 0.867388, Time 00:04:57, lr 0.00072853185868
# Epoch 391. Train Loss: -2.246866, Train Xent: 0.000951, Train Reconst: 0.014769, Train Pn: 0.000133, Train acc 0.932174, Valid Loss: 1.020506, Valid acc 0.872396, Valid acc2 0.869391, Valid accmax 0.872496, Valid accmin 0.866286, Best valid acc 0.872396, Best valid acc2 0.869491, Best valid accmax 0.872496, Best valid accmin 0.867388, Time 00:04:57, lr 0.000725573204175
# Epoch 392. Train Loss: -2.247515, Train Xent: 0.000967, Train Reconst: 0.014566, Train Pn: 0.000128, Train acc 0.932496, Valid Loss: 1.036447, Valid acc 0.870793, Valid acc2 0.868890, Valid accmax 0.872095, Valid accmin 0.865685, Best valid acc 0.872396, Best valid acc2 0.869491, Best valid accmax 0.872496, Best valid accmin 0.867388, Time 00:04:58, lr 0.000722626565117
# Epoch 393. Train Loss: -2.247696, Train Xent: 0.000728, Train Reconst: 0.014568, Train Pn: 0.000125, Train acc 0.932935, Valid Loss: 1.014988, Valid acc 0.869427, Valid acc2 0.869029, Valid accmax 0.870621, Valid accmin 0.867436, Best valid acc 0.872396, Best valid acc2 0.869491, Best valid accmax 0.872496, Best valid accmin 0.867436, Time 00:04:59, lr 0.000719691892711
# Epoch 394. Train Loss: -2.246795, Train Xent: 0.001169, Train Reconst: 0.014827, Train Pn: 0.000129, Train acc 0.932508, Valid Loss: 1.030046, Valid acc 0.870393, Valid acc2 0.869491, Valid accmax 0.872196, Valid accmin 0.866787, Best valid acc 0.872396, Best valid acc2 0.869491, Best valid accmax 0.872496, Best valid accmin 0.867436, Time 00:04:59, lr 0.000716769138358
# Epoch 395. Train Loss: -2.247867, Train Xent: 0.000829, Train Reconst: 0.014540, Train Pn: 0.000123, Train acc 0.932311, Valid Loss: 1.026139, Valid acc 0.872095, Valid acc2 0.868990, Valid accmax 0.871895, Valid accmin 0.866086, Best valid acc 0.872396, Best valid acc2 0.869491, Best valid accmax 0.872496, Best valid accmin 0.867436, Time 00:04:57, lr 0.000713858253659
# Epoch 396. Train Loss: -2.247066, Train Xent: 0.000954, Train Reconst: 0.014730, Train Pn: 0.000132, Train acc 0.932314, Valid Loss: 1.059919, Valid acc 0.871595, Valid acc2 0.868490, Valid accmax 0.871194, Valid accmin 0.865785, Best valid acc 0.872396, Best valid acc2 0.869491, Best valid accmax 0.872496, Best valid accmin 0.867436, Time 00:04:57, lr 0.000710959190408
# Epoch 397. Train Loss: -2.246610, Train Xent: 0.000891, Train Reconst: 0.014626, Train Pn: 0.000123, Train acc 0.932015, Valid Loss: 1.010566, Valid acc 0.872014, Valid acc2 0.869477, Valid accmax 0.872313, Valid accmin 0.866640, Best valid acc 0.872396, Best valid acc2 0.869491, Best valid accmax 0.872496, Best valid accmin 0.867436, Time 00:04:58, lr 0.000708071900598
# Epoch 398. Train Loss: -2.247289, Train Xent: 0.000833, Train Reconst: 0.014847, Train Pn: 0.000126, Train acc 0.932405, Valid Loss: 1.008404, Valid acc 0.870092, Valid acc2 0.867338, Valid accmax 0.870393, Valid accmin 0.864283, Best valid acc 0.872396, Best valid acc2 0.869491, Best valid accmax 0.872496, Best valid accmin 0.867436, Time 00:04:57, lr 0.000705196336415
# Epoch 399. Train Loss: -2.247117, Train Xent: 0.000846, Train Reconst: 0.014577, Train Pn: 0.000127, Train acc 0.932470, Valid Loss: 1.027237, Valid acc 0.871394, Valid acc2 0.868490, Valid accmax 0.872196, Valid accmin 0.864784, Best valid acc 0.872396, Best valid acc2 0.869491, Best valid accmax 0.872496, Best valid accmin 0.867436, Time 00:04:59, lr 0.00070233245024
# Epoch 400. Train Loss: -2.247655, Train Xent: 0.000849, Train Reconst: 0.014835, Train Pn: 0.000124, Train acc 0.932223, Valid Loss: 1.034600, Valid acc 0.870793, Valid acc2 0.868089, Valid accmax 0.870092, Valid accmin 0.866086, Best valid acc 0.872396, Best valid acc2 0.869491, Best valid accmax 0.872496, Best valid accmin 0.867436, Time 00:04:57, lr 0.000699480194648
# Epoch 401. Train Loss: -2.247397, Train Xent: 0.000652, Train Reconst: 0.014807, Train Pn: 0.000118, Train acc 0.932470, Valid Loss: 0.997796, Valid acc 0.870223, Valid acc2 0.868581, Valid accmax 0.871019, Valid accmin 0.866143, Best valid acc 0.872396, Best valid acc2 0.869491, Best valid accmax 0.872496, Best valid accmin 0.867436, Time 00:04:57, lr 0.000696639522405
# Epoch 402. Train Loss: -2.247596, Train Xent: 0.000850, Train Reconst: 0.014357, Train Pn: 0.000125, Train acc 0.932167, Valid Loss: 1.032013, Valid acc 0.872296, Valid acc2 0.869692, Valid accmax 0.872596, Valid accmin 0.866787, Best valid acc 0.872396, Best valid acc2 0.869692, Best valid accmax 0.872596, Best valid accmin 0.867436, Time 00:04:57, lr 0.000693810386469
# Epoch 403. Train Loss: -2.247246, Train Xent: 0.000768, Train Reconst: 0.014866, Train Pn: 0.000122, Train acc 0.932231, Valid Loss: 1.046199, Valid acc 0.871995, Valid acc2 0.869591, Valid accmax 0.873197, Valid accmin 0.865986, Best valid acc 0.872396, Best valid acc2 0.869692, Best valid accmax 0.873197, Best valid accmin 0.867436, Time 00:05:00, lr 0.000690992739991
# Epoch 404. Train Loss: -2.248233, Train Xent: 0.000764, Train Reconst: 0.014602, Train Pn: 0.000118, Train acc 0.932519, Valid Loss: 1.052673, Valid acc 0.870192, Valid acc2 0.868239, Valid accmax 0.870994, Valid accmin 0.865485, Best valid acc 0.872396, Best valid acc2 0.869692, Best valid accmax 0.873197, Best valid accmin 0.867436, Time 00:04:59, lr 0.00068818653631
# Epoch 405. Train Loss: -2.247702, Train Xent: 0.000794, Train Reconst: 0.014770, Train Pn: 0.000122, Train acc 0.932186, Valid Loss: 1.005868, Valid acc 0.870721, Valid acc2 0.869775, Valid accmax 0.872512, Valid accmin 0.867038, Best valid acc 0.872396, Best valid acc2 0.869775, Best valid accmax 0.873197, Best valid accmin 0.867436, Time 00:04:57, lr 0.000685391728956
# Epoch 406. Train Loss: -2.247049, Train Xent: 0.001015, Train Reconst: 0.014741, Train Pn: 0.000127, Train acc 0.932542, Valid Loss: 1.047974, Valid acc 0.870994, Valid acc2 0.868389, Valid accmax 0.870793, Valid accmin 0.865986, Best valid acc 0.872396, Best valid acc2 0.869775, Best valid accmax 0.873197, Best valid accmin 0.867436, Time 00:04:57, lr 0.000682608271647
# Epoch 407. Train Loss: -2.247085, Train Xent: 0.000780, Train Reconst: 0.015032, Train Pn: 0.000121, Train acc 0.932129, Valid Loss: 1.057830, Valid acc 0.869792, Valid acc2 0.867087, Valid accmax 0.869692, Valid accmin 0.864483, Best valid acc 0.872396, Best valid acc2 0.869775, Best valid accmax 0.873197, Best valid accmin 0.867436, Time 00:04:57, lr 0.000679836118289
# Epoch 408. Train Loss: -2.247277, Train Xent: 0.000932, Train Reconst: 0.014591, Train Pn: 0.000121, Train acc 0.931723, Valid Loss: 1.014797, Valid acc 0.870292, Valid acc2 0.868289, Valid accmax 0.872196, Valid accmin 0.864383, Best valid acc 0.872396, Best valid acc2 0.869775, Best valid accmax 0.873197, Best valid accmin 0.867436, Time 00:04:56, lr 0.000677075222975
# Epoch 409. Train Loss: -2.247266, Train Xent: 0.000967, Train Reconst: 0.014694, Train Pn: 0.000126, Train acc 0.932515, Valid Loss: 1.041087, Valid acc 0.871417, Valid acc2 0.868830, Valid accmax 0.870920, Valid accmin 0.866740, Best valid acc 0.872396, Best valid acc2 0.869775, Best valid accmax 0.873197, Best valid accmin 0.867436, Time 00:04:58, lr 0.000674325539986
# Epoch 410. Train Loss: -2.247279, Train Xent: 0.000800, Train Reconst: 0.014866, Train Pn: 0.000120, Train acc 0.932462, Valid Loss: 1.075391, Valid acc 0.870793, Valid acc2 0.868139, Valid accmax 0.870393, Valid accmin 0.865885, Best valid acc 0.872396, Best valid acc2 0.869775, Best valid accmax 0.873197, Best valid accmin 0.867436, Time 00:04:54, lr 0.000671587023786
# Epoch 411. Train Loss: -2.247258, Train Xent: 0.000891, Train Reconst: 0.014638, Train Pn: 0.000123, Train acc 0.932197, Valid Loss: 1.060659, Valid acc 0.871194, Valid acc2 0.868790, Valid accmax 0.872696, Valid accmin 0.864884, Best valid acc 0.872396, Best valid acc2 0.869775, Best valid accmax 0.873197, Best valid accmin 0.867436, Time 00:04:59, lr 0.000668859629027
# Epoch 412. Train Loss: -2.247246, Train Xent: 0.000883, Train Reconst: 0.014914, Train Pn: 0.000120, Train acc 0.932337, Valid Loss: 1.008698, Valid acc 0.870693, Valid acc2 0.868690, Valid accmax 0.870793, Valid accmin 0.866587, Best valid acc 0.872396, Best valid acc2 0.869775, Best valid accmax 0.873197, Best valid accmin 0.867436, Time 00:04:57, lr 0.000666143310541
# Epoch 413. Train Loss: -2.247543, Train Xent: 0.000742, Train Reconst: 0.014667, Train Pn: 0.000115, Train acc 0.932367, Valid Loss: 1.017976, Valid acc 0.873209, Valid acc2 0.870123, Valid accmax 0.872910, Valid accmin 0.867337, Best valid acc 0.873209, Best valid acc2 0.870123, Best valid accmax 0.873197, Best valid accmin 0.867436, Time 00:04:58, lr 0.000663438023348
# Epoch 414. Train Loss: -2.248369, Train Xent: 0.000738, Train Reconst: 0.014590, Train Pn: 0.000116, Train acc 0.933042, Valid Loss: 1.055417, Valid acc 0.869591, Valid acc2 0.867688, Valid accmax 0.870292, Valid accmin 0.865084, Best valid acc 0.873209, Best valid acc2 0.870123, Best valid accmax 0.873197, Best valid accmin 0.867436, Time 00:04:57, lr 0.000660743722648
# Epoch 415. Train Loss: -2.247256, Train Xent: 0.000849, Train Reconst: 0.014775, Train Pn: 0.000122, Train acc 0.931936, Valid Loss: 1.007549, Valid acc 0.872396, Valid acc2 0.870192, Valid accmax 0.873297, Valid accmin 0.867087, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873297, Best valid accmin 0.867436, Time 00:04:57, lr 0.000658060363823
# Epoch 416. Train Loss: -2.248051, Train Xent: 0.000768, Train Reconst: 0.014879, Train Pn: 0.000115, Train acc 0.931951, Valid Loss: 1.048294, Valid acc 0.870493, Valid acc2 0.868289, Valid accmax 0.869992, Valid accmin 0.866587, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873297, Best valid accmin 0.867436, Time 00:04:58, lr 0.000655387902438
# Epoch 417. Train Loss: -2.247865, Train Xent: 0.000776, Train Reconst: 0.014700, Train Pn: 0.000115, Train acc 0.932470, Valid Loss: 1.015567, Valid acc 0.871218, Valid acc2 0.869078, Valid accmax 0.871119, Valid accmin 0.867038, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873297, Best valid accmin 0.867436, Time 00:05:00, lr 0.000652726294236
# Epoch 418. Train Loss: -2.248216, Train Xent: 0.000701, Train Reconst: 0.014688, Train Pn: 0.000114, Train acc 0.932690, Valid Loss: 1.034667, Valid acc 0.871394, Valid acc2 0.868039, Valid accmax 0.870493, Valid accmin 0.865585, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873297, Best valid accmin 0.867436, Time 00:04:58, lr 0.000650075495142
# Epoch 419. Train Loss: -2.247851, Train Xent: 0.000852, Train Reconst: 0.014549, Train Pn: 0.000121, Train acc 0.932061, Valid Loss: 1.053835, Valid acc 0.871094, Valid acc2 0.869040, Valid accmax 0.873297, Valid accmin 0.864784, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873297, Best valid accmin 0.867436, Time 00:04:57, lr 0.000647435461258
# Epoch 420. Train Loss: -2.247498, Train Xent: 0.000841, Train Reconst: 0.014632, Train Pn: 0.000116, Train acc 0.932474, Valid Loss: 1.045594, Valid acc 0.867788, Valid acc2 0.866837, Valid accmax 0.868690, Valid accmin 0.864984, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873297, Best valid accmin 0.867436, Time 00:04:53, lr 0.000644806148865
# Epoch 421. Train Loss: -2.247662, Train Xent: 0.000840, Train Reconst: 0.014557, Train Pn: 0.000118, Train acc 0.932333, Valid Loss: 1.050238, Valid acc 0.869327, Valid acc2 0.868282, Valid accmax 0.871517, Valid accmin 0.865048, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873297, Best valid accmin 0.867436, Time 00:04:54, lr 0.000642187514423
# Epoch 422. Train Loss: -2.247404, Train Xent: 0.000916, Train Reconst: 0.014640, Train Pn: 0.000117, Train acc 0.932258, Valid Loss: 1.038820, Valid acc 0.870292, Valid acc2 0.868289, Valid accmax 0.870593, Valid accmin 0.865986, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873297, Best valid accmin 0.867436, Time 00:04:54, lr 0.000639579514566
# Epoch 423. Train Loss: -2.247416, Train Xent: 0.000913, Train Reconst: 0.014697, Train Pn: 0.000122, Train acc 0.932197, Valid Loss: 1.042272, Valid acc 0.869291, Valid acc2 0.865986, Valid accmax 0.868590, Valid accmin 0.863381, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873297, Best valid accmin 0.867436, Time 00:04:54, lr 0.000636982106107
# Epoch 424. Train Loss: -2.247815, Train Xent: 0.000940, Train Reconst: 0.014848, Train Pn: 0.000120, Train acc 0.932565, Valid Loss: 1.044332, Valid acc 0.870893, Valid acc2 0.868189, Valid accmax 0.870393, Valid accmin 0.865986, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873297, Best valid accmin 0.867436, Time 00:04:54, lr 0.000634395246033
# Epoch 425. Train Loss: -2.248396, Train Xent: 0.000834, Train Reconst: 0.014480, Train Pn: 0.000116, Train acc 0.932004, Valid Loss: 0.977596, Valid acc 0.871716, Valid acc2 0.869029, Valid accmax 0.871815, Valid accmin 0.866242, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873297, Best valid accmin 0.867436, Time 00:04:54, lr 0.000631818891505
# Epoch 426. Train Loss: -2.247447, Train Xent: 0.000907, Train Reconst: 0.014839, Train Pn: 0.000118, Train acc 0.932735, Valid Loss: 1.010866, Valid acc 0.871394, Valid acc2 0.868640, Valid accmax 0.870493, Valid accmin 0.866787, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873297, Best valid accmin 0.867436, Time 00:04:55, lr 0.000629252999859
# Epoch 427. Train Loss: -2.247584, Train Xent: 0.000902, Train Reconst: 0.014616, Train Pn: 0.000113, Train acc 0.932640, Valid Loss: 1.025218, Valid acc 0.869892, Valid acc2 0.868540, Valid accmax 0.871394, Valid accmin 0.865685, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873297, Best valid accmin 0.867436, Time 00:04:55, lr 0.000626697528604
# Epoch 428. Train Loss: -2.247965, Train Xent: 0.000720, Train Reconst: 0.014614, Train Pn: 0.000111, Train acc 0.932530, Valid Loss: 1.054399, Valid acc 0.869692, Valid acc2 0.866436, Valid accmax 0.868990, Valid accmin 0.863882, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873297, Best valid accmin 0.867436, Time 00:04:54, lr 0.000624152435422
# Epoch 429. Train Loss: -2.247727, Train Xent: 0.000698, Train Reconst: 0.014596, Train Pn: 0.000110, Train acc 0.932424, Valid Loss: 1.009549, Valid acc 0.872811, Valid acc2 0.868879, Valid accmax 0.871815, Valid accmin 0.865943, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873297, Best valid accmin 0.867436, Time 00:04:55, lr 0.000621617678166
# Epoch 430. Train Loss: -2.248195, Train Xent: 0.000733, Train Reconst: 0.014529, Train Pn: 0.000110, Train acc 0.932997, Valid Loss: 1.011369, Valid acc 0.872296, Valid acc2 0.870192, Valid accmax 0.873698, Valid accmin 0.866687, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:56, lr 0.00061909321486
# Epoch 431. Train Loss: -2.247324, Train Xent: 0.000968, Train Reconst: 0.014506, Train Pn: 0.000116, Train acc 0.932674, Valid Loss: 1.000675, Valid acc 0.870994, Valid acc2 0.869391, Valid accmax 0.872496, Valid accmin 0.866286, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:55, lr 0.0006165790037
# Epoch 432. Train Loss: -2.248143, Train Xent: 0.000827, Train Reconst: 0.014453, Train Pn: 0.000112, Train acc 0.932758, Valid Loss: 1.041935, Valid acc 0.870994, Valid acc2 0.867638, Valid accmax 0.871094, Valid accmin 0.864183, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:55, lr 0.000614075003051
# Epoch 433. Train Loss: -2.247931, Train Xent: 0.000871, Train Reconst: 0.014650, Train Pn: 0.000113, Train acc 0.932799, Valid Loss: 1.019467, Valid acc 0.871517, Valid acc2 0.868680, Valid accmax 0.871716, Valid accmin 0.865645, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:54, lr 0.000611581171446
# Epoch 434. Train Loss: -2.247957, Train Xent: 0.000834, Train Reconst: 0.014601, Train Pn: 0.000111, Train acc 0.931860, Valid Loss: 1.005498, Valid acc 0.871294, Valid acc2 0.868640, Valid accmax 0.872296, Valid accmin 0.864984, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:56, lr 0.000609097467587
# Epoch 435. Train Loss: -2.248846, Train Xent: 0.000706, Train Reconst: 0.014439, Train Pn: 0.000108, Train acc 0.933071, Valid Loss: 1.043819, Valid acc 0.869792, Valid acc2 0.867588, Valid accmax 0.870292, Valid accmin 0.864884, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:56, lr 0.000606623850346
# Epoch 436. Train Loss: -2.247155, Train Xent: 0.000768, Train Reconst: 0.014621, Train Pn: 0.000109, Train acc 0.932462, Valid Loss: 1.042652, Valid acc 0.869591, Valid acc2 0.868389, Valid accmax 0.871595, Valid accmin 0.865184, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:49, lr 0.000604160278758
# Epoch 437. Train Loss: -2.247996, Train Xent: 0.000755, Train Reconst: 0.014497, Train Pn: 0.000109, Train acc 0.932697, Valid Loss: 1.064521, Valid acc 0.869924, Valid acc2 0.867834, Valid accmax 0.870123, Valid accmin 0.865545, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:39, lr 0.000601706712027
# Epoch 438. Train Loss: -2.247329, Train Xent: 0.000854, Train Reconst: 0.014603, Train Pn: 0.000111, Train acc 0.932405, Valid Loss: 1.044789, Valid acc 0.872095, Valid acc2 0.870042, Valid accmax 0.872997, Valid accmin 0.867087, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:40, lr 0.000599263109522
# Epoch 439. Train Loss: -2.247959, Train Xent: 0.000747, Train Reconst: 0.014705, Train Pn: 0.000110, Train acc 0.932072, Valid Loss: 1.038353, Valid acc 0.870994, Valid acc2 0.868590, Valid accmax 0.871595, Valid accmin 0.865585, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:40, lr 0.000596829430778
# Epoch 440. Train Loss: -2.247941, Train Xent: 0.000808, Train Reconst: 0.014409, Train Pn: 0.000108, Train acc 0.932383, Valid Loss: 1.028100, Valid acc 0.870593, Valid acc2 0.867588, Valid accmax 0.869792, Valid accmin 0.865385, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:41, lr 0.000594405635493
# Epoch 441. Train Loss: -2.248382, Train Xent: 0.000677, Train Reconst: 0.014552, Train Pn: 0.000104, Train acc 0.932436, Valid Loss: 1.050068, Valid acc 0.870422, Valid acc2 0.867635, Valid accmax 0.871318, Valid accmin 0.863953, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:42, lr 0.000591991683528
# Epoch 442. Train Loss: -2.248059, Train Xent: 0.000757, Train Reconst: 0.014491, Train Pn: 0.000105, Train acc 0.932610, Valid Loss: 0.986338, Valid acc 0.870793, Valid acc2 0.868339, Valid accmax 0.870994, Valid accmin 0.865685, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:40, lr 0.000589587534909
# Epoch 443. Train Loss: -2.249310, Train Xent: 0.000652, Train Reconst: 0.014585, Train Pn: 0.000104, Train acc 0.932492, Valid Loss: 1.037385, Valid acc 0.870092, Valid acc2 0.867037, Valid accmax 0.869692, Valid accmin 0.864383, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:40, lr 0.000587193149824
# Epoch 444. Train Loss: -2.247989, Train Xent: 0.000837, Train Reconst: 0.014856, Train Pn: 0.000108, Train acc 0.932064, Valid Loss: 1.066678, Valid acc 0.871194, Valid acc2 0.868690, Valid accmax 0.871294, Valid accmin 0.866086, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:39, lr 0.000584808488622
# Epoch 445. Train Loss: -2.248545, Train Xent: 0.000676, Train Reconst: 0.014729, Train Pn: 0.000103, Train acc 0.931947, Valid Loss: 1.019063, Valid acc 0.870820, Valid acc2 0.866740, Valid accmax 0.868133, Valid accmin 0.865346, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:42, lr 0.000582433511812
# Epoch 446. Train Loss: -2.248700, Train Xent: 0.000722, Train Reconst: 0.014406, Train Pn: 0.000107, Train acc 0.932041, Valid Loss: 1.099291, Valid acc 0.870893, Valid acc2 0.867788, Valid accmax 0.871194, Valid accmin 0.864383, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:40, lr 0.000580068180065
# Epoch 447. Train Loss: -2.248325, Train Xent: 0.000795, Train Reconst: 0.014713, Train Pn: 0.000104, Train acc 0.932674, Valid Loss: 1.051803, Valid acc 0.871094, Valid acc2 0.867488, Valid accmax 0.869992, Valid accmin 0.864984, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:38, lr 0.000577712454212
# Epoch 448. Train Loss: -2.249179, Train Xent: 0.000744, Train Reconst: 0.014480, Train Pn: 0.000104, Train acc 0.932894, Valid Loss: 1.038674, Valid acc 0.869692, Valid acc2 0.867788, Valid accmax 0.869792, Valid accmin 0.865785, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:40, lr 0.000575366295241
# Epoch 449. Train Loss: -2.248559, Train Xent: 0.000790, Train Reconst: 0.014648, Train Pn: 0.000104, Train acc 0.932708, Valid Loss: 1.031519, Valid acc 0.872213, Valid acc2 0.867735, Valid accmax 0.868830, Valid accmin 0.866640, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:42, lr 0.000573029664301
# Epoch 450. Train Loss: -2.249231, Train Xent: 0.000767, Train Reconst: 0.014462, Train Pn: 0.000105, Train acc 0.932565, Valid Loss: 1.050147, Valid acc 0.870393, Valid acc2 0.868790, Valid accmax 0.871394, Valid accmin 0.866186, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:39, lr 0.000570702522697
# Epoch 451. Train Loss: -2.248408, Train Xent: 0.000881, Train Reconst: 0.014490, Train Pn: 0.000108, Train acc 0.932390, Valid Loss: 1.027601, Valid acc 0.869491, Valid acc2 0.867738, Valid accmax 0.870793, Valid accmin 0.864683, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:41, lr 0.000568384831892
# Epoch 452. Train Loss: -2.248811, Train Xent: 0.000902, Train Reconst: 0.014383, Train Pn: 0.000102, Train acc 0.932530, Valid Loss: 1.043352, Valid acc 0.871094, Valid acc2 0.868339, Valid accmax 0.870092, Valid accmin 0.866587, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:39, lr 0.000566076553505
# Epoch 453. Train Loss: -2.248445, Train Xent: 0.000723, Train Reconst: 0.014694, Train Pn: 0.000102, Train acc 0.932356, Valid Loss: 1.036411, Valid acc 0.868631, Valid acc2 0.867635, Valid accmax 0.869228, Valid accmin 0.866043, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:41, lr 0.000563777649311
# Epoch 454. Train Loss: -2.248349, Train Xent: 0.000821, Train Reconst: 0.014553, Train Pn: 0.000107, Train acc 0.932246, Valid Loss: 1.034050, Valid acc 0.869491, Valid acc2 0.867889, Valid accmax 0.870192, Valid accmin 0.865585, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:40, lr 0.00056148808124
# Epoch 455. Train Loss: -2.248565, Train Xent: 0.000918, Train Reconst: 0.014471, Train Pn: 0.000107, Train acc 0.932753, Valid Loss: 1.049882, Valid acc 0.871494, Valid acc2 0.868189, Valid accmax 0.870493, Valid accmin 0.865885, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:40, lr 0.000559207811378
# Epoch 456. Train Loss: -2.248712, Train Xent: 0.000805, Train Reconst: 0.014809, Train Pn: 0.000104, Train acc 0.932553, Valid Loss: 1.021396, Valid acc 0.871895, Valid acc2 0.867738, Valid accmax 0.869692, Valid accmin 0.865785, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:39, lr 0.000556936801962
# Epoch 457. Train Loss: -2.247662, Train Xent: 0.000952, Train Reconst: 0.014532, Train Pn: 0.000107, Train acc 0.932685, Valid Loss: 1.035662, Valid acc 0.871517, Valid acc2 0.868282, Valid accmax 0.871019, Valid accmin 0.865545, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:39, lr 0.000554675015386
# Epoch 458. Train Loss: -2.248881, Train Xent: 0.000765, Train Reconst: 0.014383, Train Pn: 0.000101, Train acc 0.931757, Valid Loss: 1.063204, Valid acc 0.871895, Valid acc2 0.868239, Valid accmax 0.870493, Valid accmin 0.865986, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:42, lr 0.000552422414194
# Epoch 459. Train Loss: -2.248708, Train Xent: 0.000707, Train Reconst: 0.014342, Train Pn: 0.000098, Train acc 0.932299, Valid Loss: 1.041365, Valid acc 0.870994, Valid acc2 0.867939, Valid accmax 0.869992, Valid accmin 0.865885, Best valid acc 0.873209, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:43, lr 0.000550178961083
# Epoch 460. Train Loss: -2.248627, Train Xent: 0.000716, Train Reconst: 0.014610, Train Pn: 0.000100, Train acc 0.932940, Valid Loss: 1.023638, Valid acc 0.873397, Valid acc2 0.869892, Valid accmax 0.872796, Valid accmin 0.866987, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:41, lr 0.000547944618902
# Epoch 461. Train Loss: -2.248587, Train Xent: 0.000929, Train Reconst: 0.014696, Train Pn: 0.000100, Train acc 0.932197, Valid Loss: 1.034364, Valid acc 0.870521, Valid acc2 0.868033, Valid accmax 0.870322, Valid accmin 0.865744, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:41, lr 0.00054571935065
# Epoch 462. Train Loss: -2.248838, Train Xent: 0.000815, Train Reconst: 0.014670, Train Pn: 0.000102, Train acc 0.933122, Valid Loss: 1.041476, Valid acc 0.870493, Valid acc2 0.869341, Valid accmax 0.872696, Valid accmin 0.865986, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:42, lr 0.000543503119477
# Epoch 463. Train Loss: -2.248350, Train Xent: 0.000835, Train Reconst: 0.014778, Train Pn: 0.000104, Train acc 0.932810, Valid Loss: 1.064920, Valid acc 0.870793, Valid acc2 0.868540, Valid accmax 0.871394, Valid accmin 0.865685, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:40, lr 0.000541295888683
# Epoch 464. Train Loss: -2.248502, Train Xent: 0.000782, Train Reconst: 0.014826, Train Pn: 0.000102, Train acc 0.932690, Valid Loss: 1.076460, Valid acc 0.871394, Valid acc2 0.868840, Valid accmax 0.871795, Valid accmin 0.865885, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:41, lr 0.000539097621715
# Epoch 465. Train Loss: -2.248205, Train Xent: 0.000899, Train Reconst: 0.014755, Train Pn: 0.000101, Train acc 0.932663, Valid Loss: 1.081145, Valid acc 0.871019, Valid acc2 0.867486, Valid accmax 0.869924, Valid accmin 0.865048, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:43, lr 0.000536908282171
# Epoch 466. Train Loss: -2.249004, Train Xent: 0.000762, Train Reconst: 0.014560, Train Pn: 0.000099, Train acc 0.932667, Valid Loss: 1.073759, Valid acc 0.872997, Valid acc2 0.869341, Valid accmax 0.872596, Valid accmin 0.866086, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:42, lr 0.000534727833795
# Epoch 467. Train Loss: -2.248356, Train Xent: 0.000720, Train Reconst: 0.014856, Train Pn: 0.000098, Train acc 0.932606, Valid Loss: 1.045551, Valid acc 0.870793, Valid acc2 0.867889, Valid accmax 0.870593, Valid accmin 0.865184, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:41, lr 0.000532556240479
# Epoch 468. Train Loss: -2.248769, Train Xent: 0.000727, Train Reconst: 0.014711, Train Pn: 0.000094, Train acc 0.932258, Valid Loss: 1.087890, Valid acc 0.870593, Valid acc2 0.867839, Valid accmax 0.871194, Valid accmin 0.864483, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:44, lr 0.000530393466262
# Epoch 469. Train Loss: -2.247473, Train Xent: 0.000997, Train Reconst: 0.014852, Train Pn: 0.000106, Train acc 0.932311, Valid Loss: 1.044287, Valid acc 0.870621, Valid acc2 0.867834, Valid accmax 0.870024, Valid accmin 0.865645, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:41, lr 0.000528239475328
# Epoch 470. Train Loss: -2.248156, Train Xent: 0.000832, Train Reconst: 0.014771, Train Pn: 0.000101, Train acc 0.932508, Valid Loss: 1.073822, Valid acc 0.869692, Valid acc2 0.866737, Valid accmax 0.868389, Valid accmin 0.865084, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:42, lr 0.000526094232008
# Epoch 471. Train Loss: -2.248863, Train Xent: 0.000727, Train Reconst: 0.014534, Train Pn: 0.000095, Train acc 0.932810, Valid Loss: 1.035254, Valid acc 0.871595, Valid acc2 0.867989, Valid accmax 0.870893, Valid accmin 0.865084, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:46, lr 0.000523957700776
# Epoch 472. Train Loss: -2.248287, Train Xent: 0.000840, Train Reconst: 0.014684, Train Pn: 0.000099, Train acc 0.932064, Valid Loss: 1.031417, Valid acc 0.871795, Valid acc2 0.867989, Valid accmax 0.870092, Valid accmin 0.865885, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:42, lr 0.000521829846251
# Epoch 473. Train Loss: -2.249087, Train Xent: 0.001086, Train Reconst: 0.014748, Train Pn: 0.000101, Train acc 0.932538, Valid Loss: 1.024185, Valid acc 0.871019, Valid acc2 0.868730, Valid accmax 0.871119, Valid accmin 0.866342, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:42, lr 0.000519710633196
# Epoch 474. Train Loss: -2.249129, Train Xent: 0.000828, Train Reconst: 0.014379, Train Pn: 0.000094, Train acc 0.932542, Valid Loss: 1.026596, Valid acc 0.871695, Valid acc2 0.868089, Valid accmax 0.870893, Valid accmin 0.865284, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:41, lr 0.000517600026517
# Epoch 475. Train Loss: -2.248194, Train Xent: 0.000804, Train Reconst: 0.014715, Train Pn: 0.000097, Train acc 0.932912, Valid Loss: 1.036004, Valid acc 0.871494, Valid acc2 0.868389, Valid accmax 0.871494, Valid accmin 0.865284, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:41, lr 0.000515497991264
# Epoch 476. Train Loss: -2.249048, Train Xent: 0.000574, Train Reconst: 0.014584, Train Pn: 0.000095, Train acc 0.932974, Valid Loss: 1.025846, Valid acc 0.870493, Valid acc2 0.868440, Valid accmax 0.870593, Valid accmin 0.866286, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:39, lr 0.000513404492625
# Epoch 477. Train Loss: -2.248847, Train Xent: 0.000898, Train Reconst: 0.014570, Train Pn: 0.000098, Train acc 0.932663, Valid Loss: 1.026330, Valid acc 0.870123, Valid acc2 0.868033, Valid accmax 0.869725, Valid accmin 0.866342, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:37, lr 0.000511319495933
# Epoch 478. Train Loss: -2.248317, Train Xent: 0.000910, Train Reconst: 0.014622, Train Pn: 0.000101, Train acc 0.932485, Valid Loss: 1.043051, Valid acc 0.871695, Valid acc2 0.868740, Valid accmax 0.870994, Valid accmin 0.866486, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:43, lr 0.000509242966661
# Epoch 479. Train Loss: -2.248264, Train Xent: 0.000791, Train Reconst: 0.014646, Train Pn: 0.000094, Train acc 0.932390, Valid Loss: 1.040692, Valid acc 0.869591, Valid acc2 0.867137, Valid accmax 0.869491, Valid accmin 0.864784, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:41, lr 0.000507174870421
# Epoch 480. Train Loss: -2.249029, Train Xent: 0.000877, Train Reconst: 0.014688, Train Pn: 0.000096, Train acc 0.932258, Valid Loss: 1.070722, Valid acc 0.869892, Valid acc2 0.867238, Valid accmax 0.868990, Valid accmin 0.865485, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:37, lr 0.000505115172965
# Epoch 481. Train Loss: -2.249076, Train Xent: 0.000618, Train Reconst: 0.014616, Train Pn: 0.000090, Train acc 0.932311, Valid Loss: 1.043795, Valid acc 0.869924, Valid acc2 0.866839, Valid accmax 0.869526, Valid accmin 0.864152, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:42, lr 0.000503063840186
# Epoch 482. Train Loss: -2.248817, Train Xent: 0.000936, Train Reconst: 0.014526, Train Pn: 0.000094, Train acc 0.932758, Valid Loss: 1.039130, Valid acc 0.870893, Valid acc2 0.868389, Valid accmax 0.870192, Valid accmin 0.866587, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:38, lr 0.000501020838114
# Epoch 483. Train Loss: -2.248625, Train Xent: 0.000822, Train Reconst: 0.014411, Train Pn: 0.000095, Train acc 0.932038, Valid Loss: 1.028348, Valid acc 0.871795, Valid acc2 0.867939, Valid accmax 0.869792, Valid accmin 0.866086, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:37, lr 0.000498986132915
# Epoch 484. Train Loss: -2.248710, Train Xent: 0.000923, Train Reconst: 0.014433, Train Pn: 0.000096, Train acc 0.932815, Valid Loss: 1.043985, Valid acc 0.871294, Valid acc2 0.868039, Valid accmax 0.870192, Valid accmin 0.865885, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:40, lr 0.000496959690897
# Epoch 485. Train Loss: -2.248905, Train Xent: 0.000862, Train Reconst: 0.014623, Train Pn: 0.000098, Train acc 0.932413, Valid Loss: 1.025743, Valid acc 0.871616, Valid acc2 0.867984, Valid accmax 0.870621, Valid accmin 0.865346, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:40, lr 0.0004949414785
# Epoch 486. Train Loss: -2.248979, Train Xent: 0.000878, Train Reconst: 0.014639, Train Pn: 0.000097, Train acc 0.932883, Valid Loss: 1.041871, Valid acc 0.870994, Valid acc2 0.867087, Valid accmax 0.869291, Valid accmin 0.864884, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:44, lr 0.000492931462304
# Epoch 487. Train Loss: -2.249183, Train Xent: 0.000776, Train Reconst: 0.014761, Train Pn: 0.000091, Train acc 0.932356, Valid Loss: 1.017209, Valid acc 0.872296, Valid acc2 0.868840, Valid accmax 0.871094, Valid accmin 0.866587, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:39, lr 0.000490929609023
# Epoch 488. Train Loss: -2.248276, Train Xent: 0.000841, Train Reconst: 0.014721, Train Pn: 0.000090, Train acc 0.932621, Valid Loss: 1.045231, Valid acc 0.871494, Valid acc2 0.868590, Valid accmax 0.870593, Valid accmin 0.866587, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:40, lr 0.000488935885506
# Epoch 489. Train Loss: -2.249120, Train Xent: 0.000725, Train Reconst: 0.014742, Train Pn: 0.000094, Train acc 0.932311, Valid Loss: 1.061118, Valid acc 0.870024, Valid acc2 0.867934, Valid accmax 0.869825, Valid accmin 0.866043, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:39, lr 0.000486950258737
# Epoch 490. Train Loss: -2.248986, Train Xent: 0.000773, Train Reconst: 0.014239, Train Pn: 0.000093, Train acc 0.932269, Valid Loss: 1.045858, Valid acc 0.870393, Valid acc2 0.866937, Valid accmax 0.869892, Valid accmin 0.863982, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:43, lr 0.000484972695834
# Epoch 491. Train Loss: -2.248751, Train Xent: 0.000792, Train Reconst: 0.014638, Train Pn: 0.000092, Train acc 0.932969, Valid Loss: 1.041282, Valid acc 0.871995, Valid acc2 0.868840, Valid accmax 0.871595, Valid accmin 0.866086, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:42, lr 0.00048300316405
# Epoch 492. Train Loss: -2.249526, Train Xent: 0.000746, Train Reconst: 0.014600, Train Pn: 0.000087, Train acc 0.932997, Valid Loss: 1.040494, Valid acc 0.871795, Valid acc2 0.868440, Valid accmax 0.870393, Valid accmin 0.866486, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:40, lr 0.000481041630768
# Epoch 493. Train Loss: -2.248420, Train Xent: 0.000797, Train Reconst: 0.014883, Train Pn: 0.000091, Train acc 0.932277, Valid Loss: 1.090850, Valid acc 0.870223, Valid acc2 0.867188, Valid accmax 0.870721, Valid accmin 0.863654, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:41, lr 0.000479088063507
# Epoch 494. Train Loss: -2.249594, Train Xent: 0.000680, Train Reconst: 0.014679, Train Pn: 0.000088, Train acc 0.932098, Valid Loss: 1.032903, Valid acc 0.872296, Valid acc2 0.869141, Valid accmax 0.871494, Valid accmin 0.866787, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:42, lr 0.000477142429914
# Epoch 495. Train Loss: -2.249385, Train Xent: 0.000790, Train Reconst: 0.014719, Train Pn: 0.000092, Train acc 0.932401, Valid Loss: 1.037211, Valid acc 0.871094, Valid acc2 0.867438, Valid accmax 0.869892, Valid accmin 0.864984, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:42, lr 0.000475204697771
# Epoch 496. Train Loss: -2.249162, Train Xent: 0.000790, Train Reconst: 0.014470, Train Pn: 0.000089, Train acc 0.932383, Valid Loss: 1.022844, Valid acc 0.870793, Valid acc2 0.867338, Valid accmax 0.869591, Valid accmin 0.865084, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:40, lr 0.000473274834988
# Epoch 497. Train Loss: -2.249422, Train Xent: 0.000678, Train Reconst: 0.014539, Train Pn: 0.000086, Train acc 0.933060, Valid Loss: 1.055270, Valid acc 0.870721, Valid acc2 0.867735, Valid accmax 0.870621, Valid accmin 0.864849, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:41, lr 0.000471352809608
# Epoch 498. Train Loss: -2.249760, Train Xent: 0.000818, Train Reconst: 0.014713, Train Pn: 0.000084, Train acc 0.932690, Valid Loss: 1.029238, Valid acc 0.871795, Valid acc2 0.868590, Valid accmax 0.871394, Valid accmin 0.865785, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:37, lr 0.000469438589801
# Epoch 499. Train Loss: -2.248258, Train Xent: 0.000748, Train Reconst: 0.014524, Train Pn: 0.000091, Train acc 0.933037, Valid Loss: 1.018123, Valid acc 0.871194, Valid acc2 0.868590, Valid accmax 0.870693, Valid accmin 0.866486, Best valid acc 0.873397, Best valid acc2 0.870192, Best valid accmax 0.873698, Best valid accmin 0.867436, Time 00:04:44, lr 0.000467532143868
# Validation Accuracy - Run 40 = 0.873397
# Validation Accuracy = 0.873397
