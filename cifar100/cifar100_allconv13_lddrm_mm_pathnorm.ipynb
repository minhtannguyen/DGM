# %%
import os
import math
import mxnet as mx
from mxnet import image
from mxnet import nd, gluon, autograd, init
from mxnet.gluon.data.vision import ImageFolderDataset
from mxnet.gluon.data import DataLoader
from mxnet.gluon import nn
from tensorboardX import SummaryWriter
import numpy as np
import shutil
import _pickle as cPickle
from sklearn import preprocessing
from mxnet.gluon.parameter import Parameter, ParameterDict
from common.util import download_file
import subprocess

from IPython.core.debugger import Tracer

# %%
def unpickle(file):
    fo = open(file, 'rb')
    dict = cPickle.load(fo, encoding='bytes')
    fo.close()
    return dict

# %%
class Options:
    def __init__(self):
        self.seed_val = 0
        self.num_train_sup = 10000
        self.batch_size = 128
        self.data_dir = '/tanData/datasets/cifar100'
        self.log_dir = '/tanData/logs'
        self.model_dir ='/tanData/models'
        self.exp_name = 'cifar100_nlabels_%i_allconv13_lddrm_mm_pathnorm_seed_%i'%(self.num_train_sup, self.seed_val)
        self.ctx = mx.gpu(5)
        self.alpha_drm = 0.5
        self.alpha_pn = 1.0
        self.alpha_kl = 0.5
        self.alpha_nn = 0.5
        
        self.use_bias = True
        self.use_bn = True
        self.do_topdown = True
        self.do_countpath = False
        self.do_pn = True
        self.relu_td = False
        self.do_nn = True

opt = Options()

# %%
# Preparing the data step 1
meta = unpickle(os.path.join(opt.data_dir, 'meta'))
class_name = meta[b'fine_label_names']

with open(os.path.join(opt.data_dir, 'cifar100_train.lst'), 'r') as f:
    lines = f.readlines()
    tokens = [i.rstrip().split('\t') for i in lines]
    idx_label = dict((int(idx), class_name[int(label)].decode("utf-8")) for idx, label, _ in tokens)
    idx_name = dict((name, int(idx)) for idx, _, name in tokens)
    
labels = set(idx_label.values())

num_train = len(os.listdir(os.path.join(opt.data_dir, 'train')))

num_train_tuning = int(num_train * (1 - 0.1))

num_train_tuning_per_label = num_train_tuning // len(labels)

num_train_sup = opt.num_train_sup

num_train_sup_per_label = num_train_sup // len(labels)

ratio_unsup_sup = (num_train - num_train_sup) // num_train_sup

# select labeled data
data_rng = np.random.RandomState(opt.seed_val)
indx = data_rng.permutation(range(1, num_train + 1))
indx_sup = []

for c in labels:
    c_count = 0
    for i in indx:
        if idx_label[i] == c and c_count < num_train_sup_per_label:
            indx_sup.append(i)
            c_count += 1
        if c_count >= num_train_sup_per_label:
            break
            
label_count = dict()
# print(indx_sup)
# for i in indx_sup:
#     print(idx_label[i])

def mkdir_if_not_exist(path):
    if not os.path.exists(os.path.join(*path)):
        os.makedirs(os.path.join(*path))
        
for train_file in os.listdir(os.path.join(opt.data_dir, 'train')):
    idx = idx_name[train_file]
    label = idx_label[idx]
    if idx in indx_sup:
        mkdir_if_not_exist([opt.data_dir, 'train_valid_sup_nsup_%i_seed_%i'%(opt.num_train_sup, opt.seed_val), label])
        for i in range(ratio_unsup_sup):
            shutil.copy(os.path.join(opt.data_dir,'train', train_file),
                        os.path.join(opt.data_dir, 'train_valid_sup_nsup_%i_seed_%i'%(opt.num_train_sup, opt.seed_val), label, '%i_%i.png'%(idx, i)))
    else:
        mkdir_if_not_exist([opt.data_dir, 'train_valid_unsup_nsup_%i_seed_%i'%(opt.num_train_sup, opt.seed_val), label])
        shutil.copy(os.path.join(opt.data_dir,'train', train_file),
                   os.path.join(opt.data_dir, 'train_valid_unsup_nsup_%i_seed_%i'%(opt.num_train_sup, opt.seed_val), label))

# %%
# %%bash -s "$opt.num_train_sup" "$opt.seed_val"
# DATA_DIR=/tanData/datasets/cifar100
# data_name=( "train_valid_sup_nsup_$1_seed_$2" "train_valid_unsup_nsup_$1_seed_$2" )
# list_name=( "cifar100_train_valid_sup_nsup_$1_seed_$2" "cifar100_train_valid_unsup_nsup_$1_seed_$2" )
# MX_DIR=/mxnet
#
# for ((i=0;i<${#data_name[@]};++i)); do
#     # clean stuffs
#     rm -rf ${DATA_DIR}/${list_name[i]}.*
#     # make list for all classes
#     python ${MX_DIR}/tools/im2rec.py --list --exts '.png' --recursive ${DATA_DIR}/${list_name[i]} ${DATA_DIR}/${data_name[i]}
#     # make .rec file for all classes
#     python ${MX_DIR}/tools/im2rec.py --exts '.png' --quality 95 --num-thread 16 --color 1 ${DATA_DIR}/${list_name[i]} ${DATA_DIR}/${data_name[i]}
#     # remove folders
#     rm -rf ${DATA_DIR}/${data_name[i]}
# done

# %%
def gpu_device(ctx=mx.gpu(0)):
    try:
        _ = mx.nd.array([1, 2, 3], ctx=ctx)
    except mx.MXNetError:
        return None
    return ctx

assert gpu_device(opt.ctx), 'No GPU device found!'

# %%
log_dir = os.path.join(opt.log_dir, opt.exp_name)
if not os.path.exists(log_dir):
    os.makedirs(log_dir)

# %%
data_shape = (3, 32, 32)
train_data_unsup = mx.io.ImageRecordIter(
    path_imgrec = os.path.join(opt.data_dir,'cifar100_train_valid_unsup_nsup_%i_seed_%i.rec'%(opt.num_train_sup, opt.seed_val)),
    data_shape  = data_shape,
    batch_size  = opt.batch_size // 2,
    mean_r             = 129.3,
    mean_g             = 124.1,
    mean_b             = 112.4,
    std_r              = 68.2,
    std_g              = 65.4,
    std_b              = 70.4,
    shuffle = True,
    ## Data augmentation
    rand_crop   = True,
    max_crop_size = 32,
    min_crop_size = 32,
    pad = 4,
    fill_value = 0,
    rand_mirror = True)
train_data_sup = mx.io.ImageRecordIter(
    path_imgrec = os.path.join(opt.data_dir,'cifar100_train_valid_sup_nsup_%i_seed_%i.rec'%(opt.num_train_sup, opt.seed_val)),
    data_shape  = data_shape,
    batch_size  = opt.batch_size // 2,
    mean_r             = 129.3,
    mean_g             = 124.1,
    mean_b             = 112.4,
    std_r              = 68.2,
    std_g              = 65.4,
    std_b              = 70.4,
    shuffle = True,
    ## Data augmentation
    rand_crop   = True,
    max_crop_size = 32,
    min_crop_size = 32,
    pad = 4,
    fill_value = 0,
    rand_mirror = True)
valid_data = mx.io.ImageRecordIter(
    path_imgrec = os.path.join(opt.data_dir,'cifar100_val.rec'),
    data_shape  = data_shape,
    batch_size  = opt.batch_size // 2,
    mean_r             = 129.3,
    mean_g             = 124.1,
    mean_b             = 112.4,
    std_r              = 68.2,
    std_g              = 65.4,
    std_b              = 70.4,
    ## No data augmentation
    rand_crop   = False,
    rand_mirror = False)

# %%
criterion = gluon.loss.SoftmaxCrossEntropyLoss()
L2_loss = gluon.loss.L2Loss()
L1_loss = gluon.loss.L1Loss()

# %%
class Normal(mx.init.Initializer):
    """Initializes weights with random values sampled from a normal distribution
    with a mean and standard deviation of `sigma`.
    """
    def __init__(self, mean=0, sigma=0.01):
        super(Normal, self).__init__(sigma=sigma)
        self.sigma = sigma
        self.mean = mean

    def _init_weight(self, _, arr):
        mx.random.normal(self.mean, self.sigma, out=arr)

# %%
# from resnet import ResNet164_v2
from mxnet.gluon.model_zoo import vision as models
from vgg_ld_opt import VGG_DRM

# %%
import datetime
writer = SummaryWriter(os.path.join(opt.log_dir, opt.exp_name))

def get_acc(output, label):
    pred = output.argmax(1, keepdims=False)
    correct = (pred == label).sum()
    return correct.asscalar()

def extract_acts(net, x, layer_indx):
    start_layer = 0
    out = []
    for i in layer_indx:
        for block in net.features._children[start_layer:i]:
            x = block(x)
        out.append(x)
        start_layer = i
    return out

# %%
def train(net, train_data_unsup, train_data_sup, valid_data, num_epochs, lr, wd, ctx, lr_decay, relu_indx):
    trainer = gluon.Trainer(
        net.collect_params(), 'adam', {'learning_rate': 0.0001, 'wd': wd})
    
    prev_time = datetime.datetime.now()
    best_valid_acc = 0
    iter_indx = 0
    
    for epoch in range(num_epochs-100):
        train_data_unsup.reset(); train_data_sup.reset()
        train_loss = 0; train_loss_xentropy = 0; train_loss_drm = 0; train_loss_pn = 0; train_loss_kl = 0; train_loss_nn = 0
        correct = 0; total = 0
        num_batch_train = 0
        
        if epoch == 20:
            sgd_lr = 0.15
            decay_val = np.exp(np.log(sgd_lr / 0.0001) / (num_epochs - 2))
            sgd_lr = sgd_lr * decay_val
            trainer = gluon.Trainer(net.collect_params(), 'SGD', {'learning_rate': sgd_lr, 'wd': wd})
            
        if epoch >= 20:
            trainer.set_learning_rate(trainer.learning_rate / decay_val)
        
        for batch_unsup, batch_sup in zip(train_data_unsup, train_data_sup):
            assert batch_unsup.data[0].shape[0] == batch_sup.data[0].shape[0], "batch_unsup and batch_sup must have the same size"
            bs = batch_unsup.data[0].shape[0]
            data_unsup = batch_unsup.data[0].as_in_context(ctx)
            label_unsup = batch_unsup.label[0].as_in_context(ctx)
            data_sup = batch_sup.data[0].as_in_context(ctx)
            label_sup = batch_sup.label[0].as_in_context(ctx)
            with autograd.record():
                [output_unsup, xhat_unsup, _, loss_pn_unsup, loss_nn_unsup] = net(data_unsup)
                loss_drm_unsup = L2_loss(xhat_unsup, data_unsup)
                softmax_unsup = nd.softmax(output_unsup)
                loss_kl_unsup = -nd.sum(nd.log(100.0*softmax_unsup + 1e-8) * softmax_unsup, axis=1)
                loss_unsup = opt.alpha_drm * loss_drm_unsup + opt.alpha_kl * loss_kl_unsup + opt.alpha_nn * loss_nn_unsup + opt.alpha_pn * loss_pn_unsup
                
                [output_sup, xhat_sup, _, loss_pn_sup, loss_nn_sup] = net(data_sup, label_sup)
                loss_xentropy_sup = criterion(output_sup, label_sup)
                loss_drm_sup = L2_loss(xhat_sup, data_sup)
                softmax_sup = nd.softmax(output_sup)
                loss_kl_sup = -nd.sum(nd.log(100.0*softmax_sup + 1e-8) * softmax_sup, axis=1)
                loss_sup = loss_xentropy_sup + opt.alpha_drm * loss_drm_sup + opt.alpha_kl * loss_kl_sup + opt.alpha_nn * loss_nn_sup + opt.alpha_pn * loss_pn_sup
                
                loss = loss_unsup + loss_sup
                
            loss.backward()
            trainer.step(bs)
            
            loss_drm = loss_drm_unsup + loss_drm_sup
            loss_pn = loss_pn_unsup + loss_pn_sup
            loss_xentropy = loss_xentropy_sup
            loss_kl = loss_kl_unsup + loss_kl_sup
            loss_nn = loss_nn_unsup + loss_nn_sup
            
            train_loss_xentropy += nd.mean(loss_xentropy).asscalar()
            train_loss_drm += nd.mean(loss_drm).asscalar()
            train_loss_pn += nd.mean(loss_pn).asscalar()
            train_loss_kl += nd.mean(loss_kl).asscalar()
            train_loss_nn += nd.mean(loss_nn).asscalar()
            train_loss += nd.mean(loss).asscalar()
            correct += (get_acc(output_sup, label_sup) + get_acc(output_unsup, label_unsup))/2
            
            total += bs
            num_batch_train += 1
            iter_indx += 1
        
        writer.add_scalars('loss', {'train': train_loss / num_batch_train}, epoch)
        writer.add_scalars('loss_xentropy', {'train': train_loss_xentropy / num_batch_train}, epoch)
        writer.add_scalars('loss_drm', {'train': train_loss_drm / num_batch_train}, epoch)
        writer.add_scalars('loss_pn', {'train': train_loss_pn / num_batch_train}, epoch)
        writer.add_scalars('loss_kl', {'train': train_loss_kl / num_batch_train}, epoch)
        writer.add_scalars('loss_nn', {'train': train_loss_nn / num_batch_train}, epoch)
        writer.add_scalars('acc', {'train': correct / total}, epoch)
        
        cur_time = datetime.datetime.now()
        h, remainder = divmod((cur_time - prev_time).seconds, 3600)
        m, s = divmod(remainder, 60)
        time_str = "Time %02d:%02d:%02d" % (h, m, s)
        if valid_data is not None:
            valid_data.reset()
            valid_loss = 0; valid_loss_xentropy = 0; valid_loss_drm = 0; valid_loss_pn = 0; valid_loss_kl = 0; valid_loss_nn = 0
            valid_correct = 0; valid_total = 0
            num_batch_valid = 0
            for batch in valid_data:
                bs = batch.data[0].shape[0]
                data = batch.data[0].as_in_context(ctx)
                label = batch.label[0].as_in_context(ctx)
                [output, xhat, _, loss_pn, loss_nn] = net(data, label)
                loss_xentropy = criterion(output, label)
                loss_drm = L2_loss(xhat, data)
                softmax_val = nd.softmax(output)
                loss_kl = -nd.sum(nd.log(100.0*softmax_val + 1e-8) * softmax_val, axis=1)
                loss = loss_xentropy + opt.alpha_drm * loss_drm + opt.alpha_kl * loss_kl + opt.alpha_nn * loss_nn + opt.alpha_pn * loss_pn
                
                valid_loss_xentropy += nd.mean(loss_xentropy).asscalar()
                valid_loss_drm += nd.mean(loss_drm).asscalar()
                valid_loss_pn += nd.mean(loss_pn).asscalar()
                valid_loss_kl += nd.mean(loss_kl).asscalar()
                valid_loss_nn += nd.mean(loss_nn).asscalar()
                valid_loss += nd.mean(loss).asscalar()
                valid_correct += get_acc(output, label)
                
                valid_total += bs
                num_batch_valid += 1
            valid_acc = valid_correct / valid_total
            if valid_acc > best_valid_acc:
                best_valid_acc = valid_acc
                net.collect_params().save('%s/%s_best.params'%(opt.model_dir, opt.exp_name))
            writer.add_scalars('loss', {'valid': valid_loss / num_batch_valid}, epoch)
            writer.add_scalars('loss_xentropy', {'valid': valid_loss_xentropy / num_batch_valid}, epoch)
            writer.add_scalars('loss_drm', {'valid': valid_loss_drm / num_batch_valid}, epoch)
            writer.add_scalars('loss_pn', {'valid': valid_loss_pn / num_batch_valid}, epoch)
            writer.add_scalars('loss_kl', {'valid': valid_loss_kl / num_batch_valid}, epoch)
            writer.add_scalars('loss_nn', {'valid': valid_loss_nn / num_batch_valid}, epoch)
            writer.add_scalars('acc', {'valid': valid_acc}, epoch)
            epoch_str = ("Epoch %d. Train Loss: %f, Train Xent: %f, Train Reconst: %f, Train Pn: %f, Train acc %f, Valid Loss: %f, Valid acc %f, Best valid acc %f, "
                         % (epoch, train_loss / num_batch_train, train_loss_xentropy / num_batch_train, train_loss_drm / num_batch_train, train_loss_pn / num_batch_train,
                            correct / total, valid_loss / num_batch_valid, valid_acc, best_valid_acc))
            if not epoch % 20:
                net.collect_params().save('%s/%s_epoch_%i.params'%(opt.model_dir, opt.exp_name, epoch))
        else:
            epoch_str = ("Epoch %d. Loss: %f, Train acc %f, "
                         % (epoch, train_loss / num_batch_train,
                            correct / total))
        prev_time = cur_time
        print(epoch_str + time_str + ', lr ' + str(trainer.learning_rate))
        
    return best_valid_acc

# %%
num_epochs = 500
learning_rate = 0.15
weight_decay = 5e-4
lr_decay = 0.1

# %%
def run_train(num_exp, ctx):
    valid_acc = 0
    for i in range(num_exp):
        ### CIFAR VGG_DRM
        model = VGG_DRM('AllConv13', batch_size=opt.batch_size // 2, num_class=100, use_bias=opt.use_bias, use_bn=opt.use_bn, do_topdown=opt.do_topdown, do_countpath=opt.do_countpath, do_pn=opt.do_pn, relu_td=opt.relu_td, do_nn=opt.do_nn)
        for param in model.collect_params().values():
            if param.name.find('conv') != -1 or param.name.find('dense') != -1:
                if param.name.find('weight') != -1:
                    param.initialize(init=mx.initializer.Xavier(), ctx=ctx)
                else:
                    param.initialize(init=mx.init.Zero(), ctx=ctx)
            elif param.name.find('batchnorm') != -1 or param.name.find('instancenorm') != -1:
                if param.name.find('gamma') != -1:
                    param.initialize(init=Normal(mean=1, sigma=0.02), ctx=ctx)
                else:
                    param.initialize(init=mx.init.Zero(), ctx=ctx)
            elif param.name.find('biasadder') != -1:
                param.initialize(init=mx.init.Zero(), ctx=ctx)
                
        # model.hybridize()
        
        relu_indx = []
        
        for i in range(len(model.features._children)):
            if model.features._children[i].name.find('relu') != -1:
                relu_indx.append(i)
                
        acc = train(model, train_data_unsup, train_data_sup, valid_data, num_epochs, learning_rate, weight_decay, ctx, lr_decay, relu_indx)
        print('Validation Accuracy - Run %i = %f'%(i, acc))
        valid_acc += acc

    print('Validation Accuracy = %f'%(valid_acc/num_exp))

# %%
run_train(1, ctx=opt.ctx)
# Out:
# Epoch 0. Train Loss: 5.470928, Train Xent: 4.131528, Train Reconst: 1.378407, Train Pn: 0.001101, Train acc 0.082639, Valid Loss: 4.492615, Valid acc 0.100518, Best valid acc 0.100518, Time 00:03:09, lr 0.0001
# Epoch 1. Train Loss: 4.658518, Train Xent: 3.708207, Train Reconst: 0.680362, Train Pn: 0.001974, Train acc 0.145656, Valid Loss: 4.116848, Valid acc 0.157752, Best valid acc 0.157752, Time 00:03:16, lr 0.0001
# Epoch 2. Train Loss: 4.227372, Train Xent: 3.417808, Train Reconst: 0.495868, Train Pn: 0.003178, Train acc 0.187583, Valid Loss: 3.813403, Valid acc 0.194010, Best valid acc 0.194010, Time 00:03:15, lr 0.0001
# Epoch 3. Train Loss: 3.871539, Train Xent: 3.176535, Train Reconst: 0.398586, Train Pn: 0.004756, Train acc 0.224309, Valid Loss: 3.567010, Valid acc 0.221955, Best valid acc 0.221955, Time 00:03:15, lr 0.0001
# Epoch 4. Train Loss: 3.563382, Train Xent: 2.971368, Train Reconst: 0.333304, Train Pn: 0.006794, Train acc 0.257046, Valid Loss: 3.367435, Valid acc 0.249701, Best valid acc 0.249701, Time 00:03:16, lr 0.0001
# Epoch 5. Train Loss: 3.270097, Train Xent: 2.773482, Train Reconst: 0.287105, Train Pn: 0.009287, Train acc 0.287797, Valid Loss: 3.169521, Valid acc 0.274439, Best valid acc 0.274439, Time 00:03:15, lr 0.0001
# Epoch 6. Train Loss: 3.014663, Train Xent: 2.605108, Train Reconst: 0.253872, Train Pn: 0.012143, Train acc 0.314499, Valid Loss: 3.140757, Valid acc 0.291366, Best valid acc 0.291366, Time 00:03:16, lr 0.0001
# Epoch 7. Train Loss: 2.774470, Train Xent: 2.447236, Train Reconst: 0.226183, Train Pn: 0.015200, Train acc 0.338391, Valid Loss: 2.978954, Valid acc 0.319211, Best valid acc 0.319211, Time 00:03:15, lr 0.0001
# Epoch 8. Train Loss: 2.559658, Train Xent: 2.307960, Train Reconst: 0.204731, Train Pn: 0.018322, Train acc 0.359292, Valid Loss: 2.823598, Valid acc 0.344148, Best valid acc 0.344148, Time 00:03:16, lr 0.0001
# Epoch 9. Train Loss: 2.350219, Train Xent: 2.172778, Train Reconst: 0.185282, Train Pn: 0.021404, Train acc 0.383645, Valid Loss: 2.880308, Valid acc 0.355369, Best valid acc 0.355369, Time 00:03:16, lr 0.0001
# Epoch 10. Train Loss: 2.154155, Train Xent: 2.046792, Train Reconst: 0.169995, Train Pn: 0.024609, Train acc 0.404801, Valid Loss: 2.734589, Valid acc 0.375701, Best valid acc 0.375701, Time 00:03:16, lr 0.0001
# Epoch 11. Train Loss: 1.960610, Train Xent: 1.922076, Train Reconst: 0.155879, Train Pn: 0.027435, Train acc 0.423077, Valid Loss: 2.817132, Valid acc 0.371194, Best valid acc 0.375701, Time 00:03:15, lr 0.0001
# Epoch 12. Train Loss: 1.787654, Train Xent: 1.813068, Train Reconst: 0.145501, Train Pn: 0.030254, Train acc 0.440798, Valid Loss: 2.788696, Valid acc 0.391819, Best valid acc 0.391819, Time 00:03:16, lr 0.0001
# Epoch 13. Train Loss: 1.624391, Train Xent: 1.713755, Train Reconst: 0.135824, Train Pn: 0.032970, Train acc 0.458555, Valid Loss: 2.888031, Valid acc 0.388421, Best valid acc 0.391819, Time 00:03:15, lr 0.0001
# Epoch 14. Train Loss: 1.463846, Train Xent: 1.616732, Train Reconst: 0.127600, Train Pn: 0.035195, Train acc 0.473564, Valid Loss: 2.821924, Valid acc 0.407552, Best valid acc 0.407552, Time 00:03:15, lr 0.0001
# Epoch 15. Train Loss: 1.299446, Train Xent: 1.512650, Train Reconst: 0.119765, Train Pn: 0.037367, Train acc 0.488732, Valid Loss: 3.320255, Valid acc 0.425180, Best valid acc 0.425180, Time 00:03:15, lr 0.0001
# Epoch 16. Train Loss: 1.162500, Train Xent: 1.431017, Train Reconst: 0.113092, Train Pn: 0.038903, Train acc 0.503265, Valid Loss: 3.824192, Valid acc 0.420581, Best valid acc 0.425180, Time 00:03:16, lr 0.0001
# Epoch 17. Train Loss: 1.014696, Train Xent: 1.335100, Train Reconst: 0.106818, Train Pn: 0.040366, Train acc 0.518174, Valid Loss: 4.030803, Valid acc 0.429287, Best valid acc 0.429287, Time 00:03:16, lr 0.0001
# Epoch 18. Train Loss: 0.895312, Train Xent: 1.257742, Train Reconst: 0.100932, Train Pn: 0.040829, Train acc 0.528002, Valid Loss: 4.642703, Valid acc 0.436198, Best valid acc 0.436198, Time 00:03:16, lr 0.0001
# Epoch 19. Train Loss: 0.778922, Train Xent: 1.178900, Train Reconst: 0.095426, Train Pn: 0.041360, Train acc 0.541333, Valid Loss: 5.444618, Valid acc 0.441206, Best valid acc 0.441206, Time 00:03:15, lr 0.0001
# Epoch 20. Train Loss: 2.586430, Train Xent: 2.602650, Train Reconst: 0.134160, Train Pn: 0.112733, Train acc 0.312450, Valid Loss: 3.461102, Valid acc 0.367337, Best valid acc 0.441206, Time 00:03:14, lr 0.15
# Epoch 21. Train Loss: 1.601249, Train Xent: 1.885759, Train Reconst: 0.107807, Train Pn: 0.122689, Train acc 0.424857, Valid Loss: 2.778378, Valid acc 0.410457, Best valid acc 0.441206, Time 00:03:14, lr 0.14781331798330893
# Epoch 22. Train Loss: 1.198141, Train Xent: 1.617581, Train Reconst: 0.092619, Train Pn: 0.112895, Train acc 0.469166, Valid Loss: 2.940133, Valid acc 0.421274, Best valid acc 0.441206, Time 00:03:13, lr 0.14565851315489867
# Epoch 23. Train Loss: 0.910386, Train Xent: 1.406947, Train Reconst: 0.080116, Train Pn: 0.100305, Train acc 0.503439, Valid Loss: 4.022786, Valid acc 0.413462, Best valid acc 0.441206, Time 00:03:14, lr 0.14353512081294018
# Epoch 24. Train Loss: 0.699708, Train Xent: 1.245104, Train Reconst: 0.071133, Train Pn: 0.088347, Train acc 0.526153, Valid Loss: 2.694255, Valid acc 0.457205, Best valid acc 0.457205, Time 00:03:13, lr 0.14144268302997196
# Epoch 25. Train Loss: 0.520434, Train Xent: 1.099036, Train Reconst: 0.061574, Train Pn: 0.081249, Train acc 0.550806, Valid Loss: 3.076920, Valid acc 0.451422, Best valid acc 0.457205, Time 00:03:13, lr 0.13938074855414412
# Epoch 26. Train Loss: 0.345305, Train Xent: 0.957388, Train Reconst: 0.056595, Train Pn: 0.072639, Train acc 0.570379, Valid Loss: 2.454231, Valid acc 0.473458, Best valid acc 0.473458, Time 00:03:13, lr 0.13734887271190221
# Epoch 27. Train Loss: 0.226355, Train Xent: 0.862410, Train Reconst: 0.051266, Train Pn: 0.065919, Train acc 0.585654, Valid Loss: 2.849786, Valid acc 0.468249, Best valid acc 0.473458, Time 00:03:13, lr 0.1353466173120895
# Epoch 28. Train Loss: 0.097042, Train Xent: 0.758201, Train Reconst: 0.047194, Train Pn: 0.058624, Train acc 0.603278, Valid Loss: 2.948285, Valid acc 0.459494, Best valid acc 0.473458, Time 00:03:13, lr 0.1333735505514474
# Epoch 29. Train Loss: -0.008843, Train Xent: 0.667954, Train Reconst: 0.044896, Train Pn: 0.055170, Train acc 0.618670, Valid Loss: 2.850979, Valid acc 0.471655, Best valid acc 0.473458, Time 00:03:13, lr 0.1314292469214935
# Epoch 30. Train Loss: -0.062983, Train Xent: 0.627035, Train Reconst: 0.042856, Train Pn: 0.053486, Train acc 0.624400, Valid Loss: 2.713764, Valid acc 0.480268, Best valid acc 0.480268, Time 00:03:13, lr 0.12951328711675697
# Epoch 31. Train Loss: -0.146980, Train Xent: 0.557378, Train Reconst: 0.041034, Train Pn: 0.050802, Train acc 0.636068, Valid Loss: 2.723780, Valid acc 0.488381, Best valid acc 0.488381, Time 00:03:13, lr 0.12762525794435192
# Epoch 32. Train Loss: -0.200704, Train Xent: 0.514495, Train Reconst: 0.039772, Train Pn: 0.048209, Train acc 0.644506, Valid Loss: 2.886297, Valid acc 0.482584, Best valid acc 0.488381, Time 00:03:13, lr 0.12576475223486877
# Epoch 33. Train Loss: -0.284753, Train Xent: 0.442901, Train Reconst: 0.038955, Train Pn: 0.045906, Train acc 0.655584, Valid Loss: 2.900404, Valid acc 0.488582, Best valid acc 0.488582, Time 00:03:13, lr 0.12393136875456481
# Epoch 34. Train Loss: -0.326683, Train Xent: 0.410022, Train Reconst: 0.036947, Train Pn: 0.045441, Train acc 0.663263, Valid Loss: 3.138278, Valid acc 0.480970, Best valid acc 0.488582, Time 00:03:13, lr 0.12212471211883472
# Epoch 35. Train Loss: -0.369554, Train Xent: 0.374481, Train Reconst: 0.036139, Train Pn: 0.044511, Train acc 0.667668, Valid Loss: 2.848053, Valid acc 0.490785, Best valid acc 0.490785, Time 00:03:13, lr 0.12034439270694253
# Epoch 36. Train Loss: -0.413443, Train Xent: 0.338440, Train Reconst: 0.035216, Train Pn: 0.043590, Train acc 0.674307, Valid Loss: 2.966000, Valid acc 0.490446, Best valid acc 0.490785, Time 00:03:13, lr 0.11859002657799667
# Epoch 37. Train Loss: -0.434256, Train Xent: 0.322443, Train Reconst: 0.034478, Train Pn: 0.043726, Train acc 0.677139, Valid Loss: 3.090032, Valid acc 0.490585, Best valid acc 0.490785, Time 00:03:15, lr 0.11686123538814987
# Epoch 38. Train Loss: -0.480047, Train Xent: 0.283977, Train Reconst: 0.033818, Train Pn: 0.041833, Train acc 0.683436, Valid Loss: 2.962526, Valid acc 0.489083, Best valid acc 0.490785, Time 00:03:13, lr 0.11515764630900607
# Epoch 39. Train Loss: -0.484998, Train Xent: 0.282422, Train Reconst: 0.032866, Train Pn: 0.042446, Train acc 0.683527, Valid Loss: 3.006640, Valid acc 0.492388, Best valid acc 0.492388, Time 00:03:13, lr 0.11347889194721691
# Epoch 40. Train Loss: -0.523808, Train Xent: 0.249177, Train Reconst: 0.032511, Train Pn: 0.040278, Train acc 0.690798, Valid Loss: 3.105197, Valid acc 0.487162, Best valid acc 0.492388, Time 00:03:13, lr 0.1118246102652502
# Epoch 41. Train Loss: -0.551541, Train Xent: 0.225525, Train Reconst: 0.032030, Train Pn: 0.039712, Train acc 0.697894, Valid Loss: 2.950633, Valid acc 0.513321, Best valid acc 0.513321, Time 00:03:15, lr 0.11019444450331348
# Epoch 42. Train Loss: -0.566349, Train Xent: 0.215333, Train Reconst: 0.031357, Train Pn: 0.038971, Train acc 0.702042, Valid Loss: 3.278595, Valid acc 0.492087, Best valid acc 0.513321, Time 00:03:16, lr 0.10858804310241577
# Epoch 43. Train Loss: -0.590344, Train Xent: 0.194021, Train Reconst: 0.030527, Train Pn: 0.038517, Train acc 0.702123, Valid Loss: 3.029787, Valid acc 0.501703, Best valid acc 0.513321, Time 00:03:14, lr 0.10700505962855092
# Epoch 44. Train Loss: -0.600074, Train Xent: 0.187123, Train Reconst: 0.030255, Train Pn: 0.038228, Train acc 0.707223, Valid Loss: 3.124063, Valid acc 0.503185, Best valid acc 0.513321, Time 00:03:15, lr 0.10544515269798621
# Epoch 45. Train Loss: -0.610864, Train Xent: 0.178815, Train Reconst: 0.029296, Train Pn: 0.037232, Train acc 0.707839, Valid Loss: 3.041095, Valid acc 0.501202, Best valid acc 0.513321, Time 00:03:15, lr 0.10390798590364002
# Epoch 46. Train Loss: -0.604030, Train Xent: 0.184436, Train Reconst: 0.028916, Train Pn: 0.037733, Train acc 0.707239, Valid Loss: 3.185456, Valid acc 0.511819, Best valid acc 0.513321, Time 00:03:14, lr 0.10239322774253283
# Epoch 47. Train Loss: -0.623513, Train Xent: 0.168304, Train Reconst: 0.028553, Train Pn: 0.036412, Train acc 0.711538, Valid Loss: 3.054817, Valid acc 0.495693, Best valid acc 0.513321, Time 00:03:13, lr 0.10090055154429584
# Epoch 48. Train Loss: -0.639081, Train Xent: 0.155250, Train Reconst: 0.027930, Train Pn: 0.035455, Train acc 0.717217, Valid Loss: 3.057530, Valid acc 0.512739, Best valid acc 0.513321, Time 00:03:13, lr 0.0994296354007217
# Epoch 49. Train Loss: -0.637204, Train Xent: 0.157959, Train Reconst: 0.027331, Train Pn: 0.035562, Train acc 0.714202, Valid Loss: 3.099772, Valid acc 0.509014, Best valid acc 0.513321, Time 00:03:13, lr 0.09798016209634232
# Epoch 50. Train Loss: -0.663876, Train Xent: 0.135080, Train Reconst: 0.027688, Train Pn: 0.033227, Train acc 0.720916, Valid Loss: 2.950597, Valid acc 0.516126, Best valid acc 0.516126, Time 00:03:13, lr 0.09655181904001867
# Epoch 51. Train Loss: -0.659831, Train Xent: 0.139208, Train Reconst: 0.027164, Train Pn: 0.033804, Train acc 0.721287, Valid Loss: 3.099650, Valid acc 0.510216, Best valid acc 0.516126, Time 00:03:13, lr 0.09514429819752787
# Epoch 52. Train Loss: -0.675720, Train Xent: 0.125497, Train Reconst: 0.026836, Train Pn: 0.032658, Train acc 0.723348, Valid Loss: 3.110927, Valid acc 0.503782, Best valid acc 0.516126, Time 00:03:12, lr 0.09375729602513302
# Epoch 53. Train Loss: -0.668303, Train Xent: 0.132734, Train Reconst: 0.026745, Train Pn: 0.033194, Train acc 0.721598, Valid Loss: 3.026288, Valid acc 0.517728, Best valid acc 0.517728, Time 00:03:13, lr 0.09239051340412144
# Epoch 54. Train Loss: -0.687816, Train Xent: 0.116318, Train Reconst: 0.025824, Train Pn: 0.031428, Train acc 0.724397, Valid Loss: 3.087969, Valid acc 0.516927, Best valid acc 0.517728, Time 00:03:13, lr 0.09104365557629712
# Epoch 55. Train Loss: -0.686868, Train Xent: 0.117241, Train Reconst: 0.026212, Train Pn: 0.031265, Train acc 0.725845, Valid Loss: 2.975241, Valid acc 0.509415, Best valid acc 0.517728, Time 00:03:12, lr 0.08971643208041376
# Epoch 56. Train Loss: -0.695707, Train Xent: 0.110285, Train Reconst: 0.025564, Train Pn: 0.030617, Train acc 0.726163, Valid Loss: 3.018988, Valid acc 0.517516, Best valid acc 0.517728, Time 00:03:13, lr 0.08840855668953425
# Epoch 57. Train Loss: -0.715293, Train Xent: 0.094035, Train Reconst: 0.025289, Train Pn: 0.029200, Train acc 0.732393, Valid Loss: 3.182764, Valid acc 0.508814, Best valid acc 0.517728, Time 00:03:13, lr 0.08711974734930347
# Epoch 58. Train Loss: -0.696354, Train Xent: 0.110383, Train Reconst: 0.024999, Train Pn: 0.030774, Train acc 0.727845, Valid Loss: 3.262604, Valid acc 0.507812, Best valid acc 0.517728, Time 00:03:13, lr 0.08584972611712087
# Epoch 59. Train Loss: -0.705112, Train Xent: 0.102555, Train Reconst: 0.025097, Train Pn: 0.029261, Train acc 0.730085, Valid Loss: 2.860160, Valid acc 0.529948, Best valid acc 0.529948, Time 00:03:13, lr 0.08459821910219979
# Epoch 60. Train Loss: -0.724770, Train Xent: 0.086289, Train Reconst: 0.024545, Train Pn: 0.027659, Train acc 0.734242, Valid Loss: 2.943471, Valid acc 0.524980, Best valid acc 0.529948, Time 00:03:12, lr 0.08336495640650066
# Epoch 61. Train Loss: -0.724662, Train Xent: 0.087059, Train Reconst: 0.024154, Train Pn: 0.027599, Train acc 0.734858, Valid Loss: 2.885076, Valid acc 0.531150, Best valid acc 0.531150, Time 00:03:13, lr 0.08214967206652513
# Epoch 62. Train Loss: -0.747361, Train Xent: 0.069001, Train Reconst: 0.023983, Train Pn: 0.025037, Train acc 0.741105, Valid Loss: 3.061452, Valid acc 0.524940, Best valid acc 0.531150, Time 00:03:12, lr 0.08095210399595887
# Epoch 63. Train Loss: -0.737731, Train Xent: 0.077114, Train Reconst: 0.024053, Train Pn: 0.025801, Train acc 0.737664, Valid Loss: 2.866834, Valid acc 0.535357, Best valid acc 0.535357, Time 00:03:13, lr 0.07977199392915042
# Epoch 64. Train Loss: -0.733608, Train Xent: 0.080580, Train Reconst: 0.024057, Train Pn: 0.026088, Train acc 0.738423, Valid Loss: 2.991841, Valid acc 0.534534, Best valid acc 0.535357, Time 00:03:13, lr 0.07860908736541401
# Epoch 65. Train Loss: -0.733768, Train Xent: 0.080396, Train Reconst: 0.023806, Train Pn: 0.025843, Train acc 0.737190, Valid Loss: 2.920818, Valid acc 0.529848, Best valid acc 0.535357, Time 00:03:13, lr 0.07746313351414437
# Epoch 66. Train Loss: -0.723950, Train Xent: 0.088257, Train Reconst: 0.023595, Train Pn: 0.026725, Train acc 0.733809, Valid Loss: 3.008915, Valid acc 0.520232, Best valid acc 0.535357, Time 00:03:13, lr 0.07633388524073158
# Epoch 67. Train Loss: -0.734611, Train Xent: 0.079780, Train Reconst: 0.023367, Train Pn: 0.025609, Train acc 0.738515, Valid Loss: 3.105290, Valid acc 0.520633, Best valid acc 0.535357, Time 00:03:12, lr 0.07522109901326446
# Epoch 68. Train Loss: -0.743132, Train Xent: 0.072786, Train Reconst: 0.023215, Train Pn: 0.024557, Train acc 0.739606, Valid Loss: 2.804302, Valid acc 0.532146, Best valid acc 0.535357, Time 00:03:12, lr 0.07412453485001083
# Epoch 69. Train Loss: -0.730095, Train Xent: 0.083957, Train Reconst: 0.022649, Train Pn: 0.025943, Train acc 0.737523, Valid Loss: 2.962598, Valid acc 0.521034, Best valid acc 0.535357, Time 00:03:13, lr 0.07304395626766344
# Epoch 70. Train Loss: -0.750392, Train Xent: 0.067185, Train Reconst: 0.022729, Train Pn: 0.023873, Train acc 0.743170, Valid Loss: 2.792375, Valid acc 0.538562, Best valid acc 0.538562, Time 00:03:13, lr 0.07197913023034032
# Epoch 71. Train Loss: -0.749809, Train Xent: 0.067270, Train Reconst: 0.022724, Train Pn: 0.023803, Train acc 0.742839, Valid Loss: 2.978319, Valid acc 0.527744, Best valid acc 0.538562, Time 00:03:12, lr 0.07092982709932866
# Epoch 72. Train Loss: -0.753729, Train Xent: 0.065924, Train Reconst: 0.022446, Train Pn: 0.022905, Train acc 0.744186, Valid Loss: 2.894326, Valid acc 0.524881, Best valid acc 0.538562, Time 00:03:12, lr 0.06989582058356127
# Epoch 73. Train Loss: -0.759228, Train Xent: 0.060763, Train Reconst: 0.022179, Train Pn: 0.022352, Train acc 0.744936, Valid Loss: 2.862643, Valid acc 0.534655, Best valid acc 0.538562, Time 00:03:13, lr 0.06887688769081501
# Epoch 74. Train Loss: -0.766792, Train Xent: 0.055057, Train Reconst: 0.022008, Train Pn: 0.021122, Train acc 0.748901, Valid Loss: 2.812077, Valid acc 0.542768, Best valid acc 0.542768, Time 00:03:13, lr 0.06787280867962064
# Epoch 75. Train Loss: -0.764062, Train Xent: 0.057793, Train Reconst: 0.022236, Train Pn: 0.021233, Train acc 0.748464, Valid Loss: 2.870578, Valid acc 0.531851, Best valid acc 0.542768, Time 00:03:12, lr 0.06688336701187371
# Epoch 76. Train Loss: -0.767310, Train Xent: 0.055389, Train Reconst: 0.022097, Train Pn: 0.020868, Train acc 0.746435, Valid Loss: 2.920326, Valid acc 0.530255, Best valid acc 0.542768, Time 00:03:13, lr 0.06590834930613629
# Epoch 77. Train Loss: -0.766237, Train Xent: 0.055586, Train Reconst: 0.021800, Train Pn: 0.020499, Train acc 0.745836, Valid Loss: 2.734010, Valid acc 0.543870, Best valid acc 0.543870, Time 00:03:13, lr 0.06494754529161949
# Epoch 78. Train Loss: -0.776449, Train Xent: 0.048536, Train Reconst: 0.021639, Train Pn: 0.019582, Train acc 0.749067, Valid Loss: 2.815194, Valid acc 0.537861, Best valid acc 0.543870, Time 00:03:12, lr 0.06400074776283673
# Epoch 79. Train Loss: -0.763019, Train Xent: 0.058494, Train Reconst: 0.021679, Train Pn: 0.020707, Train acc 0.745343, Valid Loss: 2.729346, Valid acc 0.540966, Best valid acc 0.543870, Time 00:03:12, lr 0.06306775253491823
# Epoch 80. Train Loss: -0.769245, Train Xent: 0.052522, Train Reconst: 0.021634, Train Pn: 0.020258, Train acc 0.749783, Valid Loss: 2.835841, Valid acc 0.541003, Best valid acc 0.543870, Time 00:03:13, lr 0.062148358399576706
# Epoch 81. Train Loss: -0.769129, Train Xent: 0.052539, Train Reconst: 0.021534, Train Pn: 0.020217, Train acc 0.750600, Valid Loss: 2.760596, Valid acc 0.549479, Best valid acc 0.549479, Time 00:03:13, lr 0.0612423670817152
# Epoch 82. Train Loss: -0.780238, Train Xent: 0.045191, Train Reconst: 0.021231, Train Pn: 0.018355, Train acc 0.752882, Valid Loss: 2.717221, Valid acc 0.549780, Best valid acc 0.549780, Time 00:03:12, lr 0.06034958319666734
# Epoch 83. Train Loss: -0.758599, Train Xent: 0.062492, Train Reconst: 0.021044, Train Pn: 0.020883, Train acc 0.747079, Valid Loss: 2.848628, Valid acc 0.534956, Best valid acc 0.549780, Time 00:03:12, lr 0.05946981420806098
# Epoch 84. Train Loss: -0.771379, Train Xent: 0.052029, Train Reconst: 0.020928, Train Pn: 0.019264, Train acc 0.749584, Valid Loss: 2.767804, Valid acc 0.541700, Best valid acc 0.549780, Time 00:03:13, lr 0.05860287038629614
# Epoch 85. Train Loss: -0.772032, Train Xent: 0.051124, Train Reconst: 0.020938, Train Pn: 0.019230, Train acc 0.750616, Valid Loss: 2.760597, Valid acc 0.544571, Best valid acc 0.549780, Time 00:03:13, lr 0.0577485647676282
# Epoch 86. Train Loss: -0.775664, Train Xent: 0.048507, Train Reconst: 0.020978, Train Pn: 0.018482, Train acc 0.753032, Valid Loss: 2.922052, Valid acc 0.536959, Best valid acc 0.549780, Time 00:03:13, lr 0.05690671311384759
# Epoch 87. Train Loss: -0.776006, Train Xent: 0.048853, Train Reconst: 0.020920, Train Pn: 0.018865, Train acc 0.751719, Valid Loss: 2.874108, Valid acc 0.537159, Best valid acc 0.549780, Time 00:03:12, lr 0.05607713387254727
# Epoch 88. Train Loss: -0.768885, Train Xent: 0.053690, Train Reconst: 0.021247, Train Pn: 0.018928, Train acc 0.750000, Valid Loss: 2.867138, Valid acc 0.536326, Best valid acc 0.549780, Time 00:03:13, lr 0.05525964813796943
# Epoch 89. Train Loss: -0.783537, Train Xent: 0.043952, Train Reconst: 0.021074, Train Pn: 0.017161, Train acc 0.755147, Valid Loss: 2.864739, Valid acc 0.536358, Best valid acc 0.549780, Time 00:03:13, lr 0.05445407961242294
# Epoch 90. Train Loss: -0.788095, Train Xent: 0.040003, Train Reconst: 0.020733, Train Pn: 0.016799, Train acc 0.755814, Valid Loss: 2.719186, Valid acc 0.555889, Best valid acc 0.555889, Time 00:03:13, lr 0.05366025456826328
# Epoch 91. Train Loss: -0.800535, Train Xent: 0.032073, Train Reconst: 0.020479, Train Pn: 0.014814, Train acc 0.759983, Valid Loss: 2.734267, Valid acc 0.551783, Best valid acc 0.555889, Time 00:03:12, lr 0.05287800181042671
# Epoch 92. Train Loss: -0.797450, Train Xent: 0.034429, Train Reconst: 0.020258, Train Pn: 0.015279, Train acc 0.761427, Valid Loss: 2.702597, Valid acc 0.549662, Best valid acc 0.555889, Time 00:03:11, lr 0.052107152639510594
# Epoch 93. Train Loss: -0.792725, Train Xent: 0.038105, Train Reconst: 0.020198, Train Pn: 0.015860, Train acc 0.757130, Valid Loss: 2.702913, Valid acc 0.555990, Best valid acc 0.555990, Time 00:03:11, lr 0.051347540815391966
# Epoch 94. Train Loss: -0.801434, Train Xent: 0.032057, Train Reconst: 0.020571, Train Pn: 0.014107, Train acc 0.759662, Valid Loss: 2.676234, Valid acc 0.557993, Best valid acc 0.557993, Time 00:03:12, lr 0.050599002521376446
# Epoch 95. Train Loss: -0.799253, Train Xent: 0.033051, Train Reconst: 0.020479, Train Pn: 0.014563, Train acc 0.759231, Valid Loss: 2.796315, Valid acc 0.556090, Best valid acc 0.557993, Time 00:03:12, lr 0.049861376328869784
# Epoch 96. Train Loss: -0.805139, Train Xent: 0.029212, Train Reconst: 0.020610, Train Pn: 0.013608, Train acc 0.762976, Valid Loss: 2.655031, Valid acc 0.557922, Best valid acc 0.557993, Time 00:03:11, lr 0.049134503162564416
# Epoch 97. Train Loss: -0.808870, Train Xent: 0.026844, Train Reconst: 0.019760, Train Pn: 0.013404, Train acc 0.762144, Valid Loss: 2.759183, Valid acc 0.549079, Best valid acc 0.557993, Time 00:03:12, lr 0.048418226266133554
# Epoch 98. Train Loss: -0.805991, Train Xent: 0.030053, Train Reconst: 0.019987, Train Pn: 0.013445, Train acc 0.764076, Valid Loss: 2.710262, Valid acc 0.548478, Best valid acc 0.557993, Time 00:03:11, lr 0.047712391168425336
# Epoch 99. Train Loss: -0.798512, Train Xent: 0.034109, Train Reconst: 0.020000, Train Pn: 0.014509, Train acc 0.758914, Valid Loss: 2.815864, Valid acc 0.550982, Best valid acc 0.557993, Time 00:03:12, lr 0.04701684565014984
# Epoch 100. Train Loss: -0.805941, Train Xent: 0.029336, Train Reconst: 0.019402, Train Pn: 0.013376, Train acc 0.761677, Valid Loss: 2.762572, Valid acc 0.554140, Best valid acc 0.557993, Time 00:03:12, lr 0.04633143971105169
# Epoch 101. Train Loss: -0.802814, Train Xent: 0.031565, Train Reconst: 0.019586, Train Pn: 0.013853, Train acc 0.762193, Valid Loss: 2.658270, Valid acc 0.558894, Best valid acc 0.558894, Time 00:03:12, lr 0.045656025537561276
# Epoch 102. Train Loss: -0.800209, Train Xent: 0.034084, Train Reconst: 0.019613, Train Pn: 0.014075, Train acc 0.762193, Valid Loss: 2.659451, Valid acc 0.551583, Best valid acc 0.558894, Time 00:03:12, lr 0.044990457470917455
# Epoch 103. Train Loss: -0.806285, Train Xent: 0.029127, Train Reconst: 0.019372, Train Pn: 0.012965, Train acc 0.762687, Valid Loss: 2.683338, Valid acc 0.554888, Best valid acc 0.558894, Time 00:03:11, lr 0.04433459197575506
# Epoch 104. Train Loss: -0.803978, Train Xent: 0.030554, Train Reconst: 0.019137, Train Pn: 0.013189, Train acc 0.761477, Valid Loss: 2.709459, Valid acc 0.558519, Best valid acc 0.558894, Time 00:03:12, lr 0.043688287609150264
# Epoch 105. Train Loss: -0.812466, Train Xent: 0.025151, Train Reconst: 0.018940, Train Pn: 0.012075, Train acc 0.764659, Valid Loss: 2.618798, Valid acc 0.562300, Best valid acc 0.562300, Time 00:03:11, lr 0.043051404990117226
# Epoch 106. Train Loss: -0.805247, Train Xent: 0.030541, Train Reconst: 0.018830, Train Pn: 0.012810, Train acc 0.763993, Valid Loss: 2.595502, Valid acc 0.555389, Best valid acc 0.562300, Time 00:03:12, lr 0.042423806769549405
# Epoch 107. Train Loss: -0.814236, Train Xent: 0.024060, Train Reconst: 0.019364, Train Pn: 0.011524, Train acc 0.765825, Valid Loss: 2.640646, Valid acc 0.563401, Best valid acc 0.563401, Time 00:03:11, lr 0.04180535760059907
# Epoch 108. Train Loss: -0.817280, Train Xent: 0.022814, Train Reconst: 0.019681, Train Pn: 0.010879, Train acc 0.766508, Valid Loss: 2.792449, Valid acc 0.548268, Best valid acc 0.563401, Time 00:03:12, lr 0.041195924109488614
# Epoch 109. Train Loss: -0.808351, Train Xent: 0.028331, Train Reconst: 0.019426, Train Pn: 0.012348, Train acc 0.763676, Valid Loss: 2.648862, Valid acc 0.559595, Best valid acc 0.563401, Time 00:03:11, lr 0.04059537486674736
# Epoch 110. Train Loss: -0.802864, Train Xent: 0.032017, Train Reconst: 0.019097, Train Pn: 0.012758, Train acc 0.761744, Valid Loss: 2.702200, Valid acc 0.560697, Best valid acc 0.563401, Time 00:03:12, lr 0.040003580358867696
# Epoch 111. Train Loss: -0.809999, Train Xent: 0.027708, Train Reconst: 0.019075, Train Pn: 0.011950, Train acc 0.765959, Valid Loss: 2.643699, Valid acc 0.564303, Best valid acc 0.564303, Time 00:03:12, lr 0.03942041296037442
# Epoch 112. Train Loss: -0.812840, Train Xent: 0.025757, Train Reconst: 0.019382, Train Pn: 0.011423, Train acc 0.766241, Valid Loss: 2.624683, Valid acc 0.562400, Best valid acc 0.564303, Time 00:03:12, lr 0.03884574690630118
# Epoch 113. Train Loss: -0.810154, Train Xent: 0.027887, Train Reconst: 0.018844, Train Pn: 0.011691, Train acc 0.766008, Valid Loss: 2.615723, Valid acc 0.563702, Best valid acc 0.564303, Time 00:03:12, lr 0.03827945826506824
# Epoch 114. Train Loss: -0.818188, Train Xent: 0.022389, Train Reconst: 0.019068, Train Pn: 0.010600, Train acc 0.768923, Valid Loss: 2.587237, Valid acc 0.566607, Best valid acc 0.566607, Time 00:03:11, lr 0.03772142491175557
# Epoch 115. Train Loss: -0.814372, Train Xent: 0.025919, Train Reconst: 0.018975, Train Pn: 0.011100, Train acc 0.766810, Valid Loss: 2.650735, Valid acc 0.561198, Best valid acc 0.566607, Time 00:03:11, lr 0.037171526501765584
# Epoch 116. Train Loss: -0.817958, Train Xent: 0.023115, Train Reconst: 0.018805, Train Pn: 0.010350, Train acc 0.768424, Valid Loss: 2.697760, Valid acc 0.555434, Best valid acc 0.566607, Time 00:03:11, lr 0.03662964444486981
# Epoch 117. Train Loss: -0.821400, Train Xent: 0.020657, Train Reconst: 0.018395, Train Pn: 0.010046, Train acc 0.770223, Valid Loss: 2.575897, Valid acc 0.570613, Best valid acc 0.570613, Time 00:03:11, lr 0.036095661879633915
# Epoch 118. Train Loss: -0.819961, Train Xent: 0.022538, Train Reconst: 0.018314, Train Pn: 0.009906, Train acc 0.771389, Valid Loss: 2.574594, Valid acc 0.568910, Best valid acc 0.570613, Time 00:03:12, lr 0.03556946364821554
# Epoch 119. Train Loss: -0.818259, Train Xent: 0.023618, Train Reconst: 0.018414, Train Pn: 0.010299, Train acc 0.769748, Valid Loss: 2.574570, Valid acc 0.571314, Best valid acc 0.571314, Time 00:03:12, lr 0.03505093627152955
# Epoch 120. Train Loss: -0.822305, Train Xent: 0.021050, Train Reconst: 0.018848, Train Pn: 0.009639, Train acc 0.770589, Valid Loss: 2.614960, Valid acc 0.563296, Best valid acc 0.571314, Time 00:03:11, lr 0.034539967924775296
# Epoch 121. Train Loss: -0.823648, Train Xent: 0.019877, Train Reconst: 0.018425, Train Pn: 0.009196, Train acc 0.771339, Valid Loss: 2.631559, Valid acc 0.565905, Best valid acc 0.571314, Time 00:03:12, lr 0.03403644841332068
# Epoch 122. Train Loss: -0.827075, Train Xent: 0.018377, Train Reconst: 0.018294, Train Pn: 0.008704, Train acc 0.772555, Valid Loss: 2.689511, Valid acc 0.559195, Best valid acc 0.571314, Time 00:03:12, lr 0.033540269148937735
# Epoch 123. Train Loss: -0.827578, Train Xent: 0.018195, Train Reconst: 0.017812, Train Pn: 0.008762, Train acc 0.772102, Valid Loss: 2.663123, Valid acc 0.559595, Best valid acc 0.571314, Time 00:03:11, lr 0.03305132312638467
