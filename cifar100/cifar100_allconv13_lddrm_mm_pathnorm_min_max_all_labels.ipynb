# %%
import os
import math
import mxnet as mx
from mxnet import image
from mxnet import nd, gluon, autograd, init
from mxnet.gluon.data.vision import ImageFolderDataset
from mxnet.gluon.data import DataLoader
from mxnet.gluon import nn
from tensorboardX import SummaryWriter
import numpy as np
import shutil
import _pickle as cPickle
from sklearn import preprocessing
from mxnet.gluon.parameter import Parameter, ParameterDict
from common.util import download_file
import subprocess

from IPython.core.debugger import Tracer

# %%
class Options:
    def __init__(self):
        self.seed_val = 0
        self.num_train_sup = 50000
        self.batch_size = 128
        self.data_dir = '/tanData/datasets/cifar100'
        self.log_dir = '/tanData/logs'
        self.model_dir ='/tanData/models'
        self.exp_name = 'cifar100_nlabels_%i_allconv13_lddrm_mm_pathnorm_maxmin_seed_%i'%(self.num_train_sup, self.seed_val)
        self.ctx = mx.gpu(0)
        self.alpha_drm = 0.5
        self.alpha_pn = 1.0
        self.alpha_kl = 0.5
        self.alpha_nn = 0.5
        self.alpha_min = 0.5
        self.alpha_max = 1.0 - self.alpha_min
        
        self.use_bias = True
        self.use_bn = True
        self.do_topdown = True
        self.do_countpath = False
        self.do_pn = True
        self.relu_td = False
        self.do_nn = True
        self.min_max = True

opt = Options()

# %%
def gpu_device(ctx=mx.gpu(0)):
    try:
        _ = mx.nd.array([1, 2, 3], ctx=ctx)
    except mx.MXNetError:
        return None
    return ctx

assert gpu_device(opt.ctx), 'No GPU device found!'

# %%
log_dir = os.path.join(opt.log_dir, opt.exp_name)
if not os.path.exists(log_dir):
    os.makedirs(log_dir)

# %%
data_shape = (3, 32, 32)
train_data_sup = mx.io.ImageRecordIter(
    path_imgrec = os.path.join(opt.data_dir,'cifar100_train.rec'),
    data_shape  = data_shape,
    batch_size  = opt.batch_size,
    mean_r             = 129.3,
    mean_g             = 124.1,
    mean_b             = 112.4,
    std_r              = 68.2,
    std_g              = 65.4,
    std_b              = 70.4,
    shuffle = True,
    ## Data augmentation
    rand_crop   = True,
    max_crop_size = 32,
    min_crop_size = 32,
    pad = 4,
    fill_value = 0,
    rand_mirror = True)
valid_data = mx.io.ImageRecordIter(
    path_imgrec = os.path.join(opt.data_dir,'cifar100_val.rec'),
    data_shape  = data_shape,
    batch_size  = opt.batch_size,
    mean_r             = 129.3,
    mean_g             = 124.1,
    mean_b             = 112.4,
    std_r              = 68.2,
    std_g              = 65.4,
    std_b              = 70.4,
    ## No data augmentation
    rand_crop   = False,
    rand_mirror = False)

# %%
criterion = gluon.loss.SoftmaxCrossEntropyLoss()
L2_loss = gluon.loss.L2Loss()
L1_loss = gluon.loss.L1Loss()

# %%
class Normal(mx.init.Initializer):
    """Initializes weights with random values sampled from a normal distribution
    with a mean and standard deviation of `sigma`.
    """
    def __init__(self, mean=0, sigma=0.01):
        super(Normal, self).__init__(sigma=sigma)
        self.sigma = sigma
        self.mean = mean

    def _init_weight(self, _, arr):
        mx.random.normal(self.mean, self.sigma, out=arr)

# %%
# from resnet import ResNet164_v2
from mxnet.gluon.model_zoo import vision as models
from vgg_ld_opt_min_max import VGG_DRM

# %%
import datetime
writer = SummaryWriter(os.path.join(opt.log_dir, opt.exp_name))

def get_acc(output, label):
    pred = output.argmax(1, keepdims=False)
    correct = (pred == label).sum()
    return correct.asscalar()

def extract_acts(net, x, layer_indx):
    start_layer = 0
    out = []
    for i in layer_indx:
        for block in net.features._children[start_layer:i]:
            x = block(x)
        out.append(x)
        start_layer = i
    return out

# %%
def train(net, train_data_sup, valid_data, num_epochs, lr, wd, ctx, lr_decay, relu_indx):
    trainer = gluon.Trainer(
        net.collect_params(), 'adam', {'learning_rate': 0.001, 'wd': wd})
    
    prev_time = datetime.datetime.now()
    best_valid_acc = 0; best_valid_acc2 = 0; best_valid_accmax = 0; best_valid_accmin = 0
    iter_indx = 0
    
    for epoch in range(num_epochs-100):
        train_data_sup.reset()
        train_loss = 0; train_loss_xentropy = 0; train_loss_drm = 0; train_loss_pn = 0; train_loss_kl = 0; train_loss_nn = 0
        correct = 0; total = 0; correct2=0; correctmax=0; correctmin=0
        num_batch_train = 0
        
        if epoch == 20:
            sgd_lr = 0.15
            decay_val = np.exp(np.log(sgd_lr / 0.0001) / (num_epochs - 2))
            sgd_lr = sgd_lr * decay_val
            trainer = gluon.Trainer(net.collect_params(), 'SGD', {'learning_rate': sgd_lr, 'wd': wd})
            
        if epoch >= 20:
            trainer.set_learning_rate(trainer.learning_rate / decay_val)
        
        for batch_sup in train_data_sup:
            bs = batch_sup.data[0].shape[0]
            data_sup = batch_sup.data[0].as_in_context(ctx)
            label_sup = batch_sup.label[0].as_in_context(ctx)
            with autograd.record():
                [output_sup, output_min_sup, xhat_sup, xhat_min_sup, _, loss_pn_sup, loss_nn_sup] = net(data_sup, label_sup)
                loss_xentropy_sup = opt.alpha_max * criterion(output_sup, label_sup) + opt.alpha_min * criterion(output_min_sup, label_sup)
                loss_drm_sup = opt.alpha_max * L2_loss(xhat_sup, data_sup) + opt.alpha_min * L2_loss(xhat_min_sup, data_sup)
                softmax_sup = opt.alpha_max * nd.softmax(output_sup) + opt.alpha_min * nd.softmax(output_min_sup)
                loss_kl_sup = -nd.sum(nd.log(100.0*softmax_sup + 1e-8) * softmax_sup, axis=1)
                loss = loss_xentropy_sup + opt.alpha_drm * loss_drm_sup + opt.alpha_kl * loss_kl_sup + opt.alpha_nn * loss_nn_sup + opt.alpha_pn * loss_pn_sup
                
            loss.backward()
            trainer.step(bs)
            
            loss_drm = loss_drm_sup
            loss_pn = loss_pn_sup
            loss_xentropy = loss_xentropy_sup
            loss_kl = loss_kl_sup
            loss_nn = loss_nn_sup
            
            train_loss_xentropy += nd.mean(loss_xentropy).asscalar()
            train_loss_drm += nd.mean(loss_drm).asscalar()
            train_loss_pn += nd.mean(loss_pn).asscalar()
            train_loss_kl += nd.mean(loss_kl).asscalar()
            train_loss_nn += nd.mean(loss_nn).asscalar()
            train_loss += nd.mean(loss).asscalar()
            correct += get_acc(opt.alpha_max * output_sup + opt.alpha_min * output_min_sup, label_sup)
            correct2 += opt.alpha_max * get_acc(output_sup, label_sup) + opt.alpha_min * get_acc(output_min_sup, label_sup)
            correctmax += get_acc(output_sup, label_sup)
            correctmin += get_acc(output_min_sup, label_sup)
            
            total += bs
            num_batch_train += 1
            iter_indx += 1
        
        writer.add_scalars('loss', {'train': train_loss / num_batch_train}, epoch)
        writer.add_scalars('loss_xentropy', {'train': train_loss_xentropy / num_batch_train}, epoch)
        writer.add_scalars('loss_drm', {'train': train_loss_drm / num_batch_train}, epoch)
        writer.add_scalars('loss_pn', {'train': train_loss_pn / num_batch_train}, epoch)
        writer.add_scalars('loss_kl', {'train': train_loss_kl / num_batch_train}, epoch)
        writer.add_scalars('loss_nn', {'train': train_loss_nn / num_batch_train}, epoch)
        writer.add_scalars('acc', {'train': correct / total}, epoch)
        writer.add_scalars('acc', {'train2': correct2 / total}, epoch)
        writer.add_scalars('acc', {'trainmax': correctmax / total}, epoch)
        writer.add_scalars('acc', {'trainmin': correctmin / total}, epoch)
        
        cur_time = datetime.datetime.now()
        h, remainder = divmod((cur_time - prev_time).seconds, 3600)
        m, s = divmod(remainder, 60)
        time_str = "Time %02d:%02d:%02d" % (h, m, s)
        if valid_data is not None:
            valid_data.reset()
            valid_loss = 0; valid_loss_xentropy = 0; valid_loss_drm = 0; valid_loss_pn = 0; valid_loss_kl = 0; valid_loss_nn = 0
            valid_correct = 0; valid_total = 0; valid_correct2 = 0; valid_correctmax = 0; valid_correctmin = 0
            num_batch_valid = 0
            for batch in valid_data:
                bs = batch.data[0].shape[0]
                data = batch.data[0].as_in_context(ctx)
                label = batch.label[0].as_in_context(ctx)
                [output, output_min, xhat, xhat_min, _, loss_pn, loss_nn] = net(data, label)
                loss_xentropy = opt.alpha_max * criterion(output, label) + opt.alpha_min * criterion(output_min, label)
                loss_drm = opt.alpha_max * L2_loss(xhat, data) + opt.alpha_min * L2_loss(xhat_min, data)
                softmax_val = opt.alpha_max * nd.softmax(output) + opt.alpha_min * nd.softmax(output_min)
                loss_kl = -nd.sum(nd.log(100.0*softmax_val + 1e-8) * softmax_val, axis=1)
                loss = loss_xentropy + opt.alpha_drm * loss_drm + opt.alpha_kl * loss_kl + opt.alpha_nn * loss_nn + opt.alpha_pn * loss_pn
                
                valid_loss_xentropy += nd.mean(loss_xentropy).asscalar()
                valid_loss_drm += nd.mean(loss_drm).asscalar()
                valid_loss_pn += nd.mean(loss_pn).asscalar()
                valid_loss_kl += nd.mean(loss_kl).asscalar()
                valid_loss_nn += nd.mean(loss_nn).asscalar()
                valid_loss += nd.mean(loss).asscalar()
                valid_correct += get_acc(opt.alpha_max * output + opt.alpha_min * output_min, label)
                valid_correct2 += opt.alpha_max * get_acc(output, label) + opt.alpha_min * get_acc(output_min, label)
                valid_correctmax += get_acc(output, label)
                valid_correctmin += get_acc(output_min, label)
                
                valid_total += bs
                num_batch_valid += 1
            valid_acc = valid_correct / valid_total
            valid_acc2 = valid_correct2 / valid_total
            valid_accmax = valid_correctmax / valid_total
            valid_accmin = valid_correctmin / valid_total
            if valid_acc > best_valid_acc:
                best_valid_acc = valid_acc
                net.collect_params().save('%s/%s_best.params'%(opt.model_dir, opt.exp_name))
            if valid_acc2 > best_valid_acc2:
                best_valid_acc2 = valid_acc2
                net.collect_params().save('%s/%s_best_2.params'%(opt.model_dir, opt.exp_name))
            if valid_accmax > best_valid_accmax:
                best_valid_accmax = valid_accmax
                net.collect_params().save('%s/%s_best_max.params'%(opt.model_dir, opt.exp_name))
            if valid_accmin > best_valid_accmin:
                best_valid_accmin = valid_accmin
                net.collect_params().save('%s/%s_best_min.params'%(opt.model_dir, opt.exp_name))
            writer.add_scalars('loss', {'valid': valid_loss / num_batch_valid}, epoch)
            writer.add_scalars('loss_xentropy', {'valid': valid_loss_xentropy / num_batch_valid}, epoch)
            writer.add_scalars('loss_drm', {'valid': valid_loss_drm / num_batch_valid}, epoch)
            writer.add_scalars('loss_pn', {'valid': valid_loss_pn / num_batch_valid}, epoch)
            writer.add_scalars('loss_kl', {'valid': valid_loss_kl / num_batch_valid}, epoch)
            writer.add_scalars('loss_nn', {'valid': valid_loss_nn / num_batch_valid}, epoch)
            writer.add_scalars('acc', {'valid': valid_acc}, epoch)
            writer.add_scalars('acc', {'valid2': valid_acc2}, epoch)
            writer.add_scalars('acc', {'validmax': valid_accmax}, epoch)
            writer.add_scalars('acc', {'validmin': valid_accmin}, epoch)
            epoch_str = ("Epoch %d. Train Loss: %f, Train Xent: %f, Train Reconst: %f, Train Pn: %f, Train acc %f, Valid Loss: %f, Valid acc %f, Valid acc2 %f, Valid accmax %f, Valid accmin %f, Best valid acc %f, Best valid acc2 %f, Best valid accmax %f, Best valid accmin %f, "
                         % (epoch, train_loss / num_batch_train, train_loss_xentropy / num_batch_train, train_loss_drm / num_batch_train, train_loss_pn / num_batch_train,
                            correct / total, valid_loss / num_batch_valid, valid_acc, valid_acc2, valid_accmax, valid_accmin, best_valid_acc, best_valid_acc2, best_valid_accmax, best_valid_accmin))
            
            # net.collect_params().save('%s/%s_latest.params'%(opt.model_dir, opt.exp_name))
            if not epoch % 20:
                net.collect_params().save('%s/%s_epoch_%i.params'%(opt.model_dir, opt.exp_name, epoch))
        else:
            epoch_str = ("Epoch %d. Loss: %f, Train acc %f, "
                         % (epoch, train_loss / num_batch_train,
                            correct / total))
        prev_time = cur_time
        print(epoch_str + time_str + ', lr ' + str(trainer.learning_rate))
        
    return best_valid_acc

# %%
num_epochs = 500
learning_rate = 0.15
weight_decay = 5e-4
lr_decay = 0.1

# %%
def run_train(num_exp, ctx):
    valid_acc = 0
    for i in range(num_exp):
        ### CIFAR VGG_DRM
        model = VGG_DRM('AllConv13', batch_size=opt.batch_size, num_class=100, use_bias=opt.use_bias, use_bn=opt.use_bn, do_topdown=opt.do_topdown, do_countpath=opt.do_countpath, do_pn=opt.do_pn, relu_td=opt.relu_td, do_nn=opt.do_nn, min_max=opt.min_max)
        for param in model.collect_params().values():
            if param.name.find('conv') != -1 or param.name.find('dense') != -1:
                if param.name.find('weight') != -1:
                    param.initialize(init=mx.initializer.Xavier(), ctx=ctx)
                else:
                    param.initialize(init=mx.init.Zero(), ctx=ctx)
            elif param.name.find('batchnorm') != -1 or param.name.find('instancenorm') != -1:
                if param.name.find('gamma') != -1:
                    param.initialize(init=Normal(mean=1, sigma=0.02), ctx=ctx)
                else:
                    param.initialize(init=mx.init.Zero(), ctx=ctx)
            elif param.name.find('biasadder') != -1:
                param.initialize(init=mx.init.Zero(), ctx=ctx)
        
        # model.collect_params().load('%s/%s_epoch_%i.params'%(opt.model_dir, opt.exp_name, 380), ctx=ctx)
        # model.hybridize()
        
        relu_indx = []
        
        for i in range(len(model.features._children)):
            if model.features._children[i].name.find('relu') != -1:
                relu_indx.append(i)
                
        acc = train(model, train_data_sup, valid_data, num_epochs, learning_rate, weight_decay, ctx, lr_decay, relu_indx)
        print('Validation Accuracy - Run %i = %f'%(i, acc))
        valid_acc += acc

    print('Validation Accuracy = %f'%(valid_acc/num_exp))

# %%
run_train(1, ctx=opt.ctx)
# Out:
Best valid acc2 0.906646, Best valid accmax 0.908525, Best valid accmin 0.904767, Time 00:04:21, lr 0.12576475223486877
# Epoch 33. Train Loss: -0.767595, Train Xent: 0.246624, Train Reconst: 0.011487, Train Pn: 0.005846, Train acc 0.932864, Valid Loss: 1.744750, Valid acc 0.912260, Valid acc2 0.904147, Valid accmax 0.901743, Valid accmin 0.906550, Best valid acc 0.915051, Best valid acc2 0.906646, Best valid accmax 0.908525, Best valid accmin 0.906550, Time 00:04:21, lr 0.12393136875456481
# Epoch 34. Train Loss: -0.773184, Train Xent: 0.241835, Train Reconst: 0.012303, Train Pn: 0.005951, Train acc 0.934415, Valid Loss: 1.421987, Valid acc 0.911358, Valid acc2 0.904297, Valid accmax 0.906350, Valid accmin 0.902244, Best valid acc 0.915051, Best valid acc2 0.906646, Best valid accmax 0.908525, Best valid accmin 0.906550, Time 00:04:20, lr 0.12212471211883472
# Epoch 35. Train Loss: -0.781268, Train Xent: 0.234857, Train Reconst: 0.012074, Train Pn: 0.005959, Train acc 0.936001, Valid Loss: 1.312780, Valid acc 0.912159, Valid acc2 0.902093, Valid accmax 0.902344, Valid accmin 0.901843, Best valid acc 0.915051, Best valid acc2 0.906646, Best valid accmax 0.908525, Best valid accmin 0.906550, Time 00:04:20, lr 0.12034439270694253
# Epoch 36. Train Loss: -0.785702, Train Xent: 0.232639, Train Reconst: 0.011653, Train Pn: 0.006020, Train acc 0.937540, Valid Loss: 1.722756, Valid acc 0.913361, Valid acc2 0.903095, Valid accmax 0.899639, Valid accmin 0.906550, Best valid acc 0.915051, Best valid acc2 0.906646, Best valid accmax 0.908525, Best valid accmin 0.906550, Time 00:04:21, lr 0.11859002657799667
# Epoch 37. Train Loss: -0.791101, Train Xent: 0.228155, Train Reconst: 0.013010, Train Pn: 0.005904, Train acc 0.940345, Valid Loss: 1.688041, Valid acc 0.915765, Valid acc2 0.901492, Valid accmax 0.899940, Valid accmin 0.903045, Best valid acc 0.915765, Best valid acc2 0.906646, Best valid accmax 0.908525, Best valid accmin 0.906550, Time 00:04:20, lr 0.11686123538814987
# Epoch 38. Train Loss: -0.793021, Train Xent: 0.226382, Train Reconst: 0.012485, Train Pn: 0.006080, Train acc 0.940897, Valid Loss: 1.165991, Valid acc 0.920373, Valid acc2 0.908654, Valid accmax 0.909255, Valid accmin 0.908053, Best valid acc 0.920373, Best valid acc2 0.908654, Best valid accmax 0.909255, Best valid accmin 0.908053, Time 00:04:20, lr 0.11515764630900607
# Epoch 39. Train Loss: -0.790192, Train Xent: 0.228350, Train Reconst: 0.012027, Train Pn: 0.006227, Train acc 0.940104, Valid Loss: 0.733536, Valid acc 0.911659, Valid acc2 0.900841, Valid accmax 0.900942, Valid accmin 0.900741, Best valid acc 0.920373, Best valid acc2 0.908654, Best valid accmax 0.909255, Best valid accmin 0.908053, Time 00:04:20, lr 0.11347889194721691
# Epoch 40. Train Loss: -0.801136, Train Xent: 0.219343, Train Reconst: 0.012013, Train Pn: 0.006100, Train acc 0.942036, Valid Loss: 1.182907, Valid acc 0.918117, Valid acc2 0.910947, Valid accmax 0.908426, Valid accmin 0.913469, Best valid acc 0.920373, Best valid acc2 0.910947, Best valid accmax 0.909255, Best valid accmin 0.913469, Time 00:04:21, lr 0.1118246102652502
Best valid accmax 0.918570, Best valid accmin 0.919205, Time 00:04:20, lr 0.08584972611712087
# Epoch 59. Train Loss: -0.867216, Train Xent: 0.171399, Train Reconst: 0.012616, Train Pn: 0.005574, Train acc 0.957761, Valid Loss: 0.386260, Valid acc 0.922175, Valid acc2 0.911108, Valid accmax 0.910657, Valid accmin 0.911558, Best valid acc 0.925280, Best valid acc2 0.916683, Best valid accmax 0.918570, Best valid accmin 0.919205, Time 00:04:21, lr 0.08459821910219979
# Epoch 60. Train Loss: -0.866238, Train Xent: 0.173071, Train Reconst: 0.012727, Train Pn: 0.005632, Train acc 0.957581, Valid Loss: 0.269713, Valid acc 0.927985, Valid acc2 0.917518, Valid accmax 0.916466, Valid accmin 0.918570, Best valid acc 0.927985, Best valid acc2 0.917518, Best valid accmax 0.918570, Best valid accmin 0.919205, Time 00:04:21, lr 0.08336495640650066
# Epoch 61. Train Loss: -0.872719, Train Xent: 0.168031, Train Reconst: 0.012440, Train Pn: 0.005527, Train acc 0.959215, Valid Loss: 0.507694, Valid acc 0.926482, Valid acc2 0.915315, Valid accmax 0.915765, Valid accmin 0.914864, Best valid acc 0.927985, Best valid acc2 0.917518, Best valid accmax 0.918570, Best valid accmin 0.919205, Time 00:04:21, lr 0.08214967206652513
# Epoch 62. Train Loss: -0.873292, Train Xent: 0.167620, Train Reconst: 0.012048, Train Pn: 0.005492, Train acc 0.959459, Valid Loss: 0.363722, Valid acc 0.923578, Valid acc2 0.912961, Valid accmax 0.912159, Valid accmin 0.913762, Best valid acc 0.927985, Best valid acc2 0.917518, Best valid accmax 0.918570, Best valid accmin 0.919205, Time 00:04:22, lr 0.08095210399595887
# Epoch 63. Train Loss: -0.877130, Train Xent: 0.164561, Train Reconst: 0.012781, Train Pn: 0.005458, Train acc 0.959936, Valid Loss: 0.464864, Valid acc 0.922977, Valid acc2 0.912560, Valid accmax 0.912260, Valid accmin 0.912861, Best valid acc 0.927985, Best valid acc2 0.917518, Best valid accmax 0.918570, Best valid accmin 0.919205, Time 00:04:20, lr 0.07977199392915042
# Epoch 64. Train Loss: -0.879105, Train Xent: 0.163183, Train Reconst: 0.012510, Train Pn: 0.005437, Train acc 0.960478, Valid Loss: 0.277231, Valid acc 0.926325, Valid acc2 0.917326, Valid accmax 0.916337, Valid accmin 0.918315, Best valid acc 0.927985, Best valid acc2 0.917518, Best valid accmax 0.918570, Best valid accmin 0.919205, Time 00:04:21, lr 0.07860908736541401
# Epoch 65. Train Loss: -0.881198, Train Xent: 0.161980, Train Reconst: 0.012259, Train Pn: 0.005487, Train acc 0.959998, Valid Loss: 0.408428, Valid acc 0.925280, Valid acc2 0.916567, Valid accmax 0.921775, Valid accmin 0.911358, Best valid acc 0.927985, Best valid acc2 0.917518, Best valid accmax 0.921775, Best valid accmin 0.919205, Time 00:04:22, lr 0.07746313351414437
# Epoch 66. Train Loss: -0.885939, Train Xent: 0.158641, Train Reconst: 0.012437, Train Pn: 0.005337, Train acc 0.961719, Valid Loss: 0.461974, Valid acc 0.927784, Valid acc2 0.917969, Valid accmax 0.922476, Valid accmin 0.913462, Best valid acc 0.927985, Best valid acc2 0.917969, Best valid accmax 0.922476, Best valid accmin 0.919205, Time 00:04:21, lr 0.07633388524073158
# Epoch 67. Train Loss: -0.888187, Train Xent: 0.157319, Train Reconst: 0.011539, Train Pn: 0.005296, Train acc 0.962276, Valid Loss: 0.367744, Valid acc 0.931290, Valid acc2 0.920974, Valid accmax 0.916867, Valid accmin 0.925080, Best valid acc 0.931290, Best valid acc2 0.920974, Best valid accmax 0.922476, Best valid accmin 0.925080, Time 00:04:22, lr 0.07522109901326446
# Epoch 68. Train Loss: -0.893587, Train Xent: 0.153423, Train Reconst: 0.012395, Train Pn: 0.005278, Train acc 0.963715, Valid Loss: 0.378774, Valid acc 0.929988, Valid acc2 0.918570, Valid accmax 0.920272, Valid accmin 0.916867, Best valid acc 0.931290, Best valid acc2 0.920974, Best valid accmax 0.922476, Best valid accmin 0.925080, Time 00:04:21, lr 0.07412453485001083
# Epoch 69. Train Loss: -0.896760, Train Xent: 0.150377, Train Reconst: 0.012143, Train Pn: 0.005289, Train acc 0.964163, Valid Loss: 0.322763, Valid acc 0.931891, Valid acc2 0.921725, Valid accmax 0.923578, Valid accmin 0.919872, Best valid acc 0.931891, Best valid acc2 0.921725, Best valid accmax 0.923578, Best valid accmin 0.925080, Time 00:04:21, lr 0.07304395626766344
# Epoch 70. Train Loss: -0.899626, Train Xent: 0.148792, Train Reconst: 0.011924, Train Pn: 0.005179, Train acc 0.964654, Valid Loss: 0.260456, Valid acc 0.926182, Valid acc2 0.917869, Valid accmax 0.916466, Valid accmin 0.919271, Best valid acc 0.931891, Best valid acc2 0.921725, Best valid accmax 0.923578, Best valid accmin 0.925080, Time 00:04:21, lr 0.07197913023034032
# Epoch 71. Train Loss: -0.897360, Train Xent: 0.150515, Train Reconst: 0.012286, Train Pn: 0.005266, Train acc 0.964804, Valid Loss: 0.340978, Valid acc 0.930389, Valid acc2 0.917919, Valid accmax 0.922075, Valid accmin 0.913762, Best valid acc 0.931891, Best valid acc2 0.921725, Best valid accmax 0.923578, Best valid accmin 0.925080, Time 00:04:20, lr 0.07092982709932866
# Epoch 72. Train Loss: -0.905070, Train Xent: 0.144667, Train Reconst: 0.012052, Train Pn: 0.005085, Train acc 0.966392, Valid Loss: 0.267384, Valid acc 0.932259, Valid acc2 0.924545, Valid accmax 0.923556, Valid accmin 0.925534, Best valid acc 0.932259, Best valid acc2 0.924545, Best valid accmax 0.923578, Best valid accmin 0.925534, Time 00:04:22, lr 0.06989582058356127
# Epoch 73. Train Loss: -0.903035, Train Xent: 0.147061, Train Reconst: 0.011625, Train Pn: 0.005150, Train acc 0.965733, Valid Loss: 0.415844, Valid acc 0.923978, Valid acc2 0.918670, Valid accmax 0.919171, Valid accmin 0.918169, Best valid acc 0.932259, Best valid acc2 0.924545, Best valid accmax 0.923578, Best valid accmin 0.925534, Time 00:04:22, lr 0.06887688769081501
# Epoch 74. Train Loss: -0.906193, Train Xent: 0.144951, Train Reconst: 0.011119, Train Pn: 0.005129, Train acc 0.966827, Valid Loss: 0.374267, Valid acc 0.931390, Valid acc2 0.921124, Valid accmax 0.919671, Valid accmin 0.922576, Best valid acc 0.932259, Best valid acc2 0.924545, Best valid accmax 0.923578, Best valid accmin 0.925534, Time 00:04:21, lr 0.06787280867962064
# Epoch 75. Train Loss: -0.912332, Train Xent: 0.139982, Train Reconst: 0.011505, Train Pn: 0.005081, Train acc 0.967431, Valid Loss: 0.228836, Valid acc 0.932091, Valid acc2 0.923227, Valid accmax 0.926382, Valid accmin 0.920072, Best valid acc 0.932259, Best valid acc2 0.924545, Best valid accmax 0.926382, Best valid accmin 0.925534, Time 00:04:21, lr 0.06688336701187371
# Epoch 76. Train Loss: -0.916916, Train Xent: 0.136657, Train Reconst: 0.011556, Train Pn: 0.004933, Train acc 0.967971, Valid Loss: 0.326395, Valid acc 0.931490, Valid acc2 0.922476, Valid accmax 0.921875, Valid accmin 0.923077, Best valid acc 0.932259, Best valid acc2 0.924545, Best valid accmax 0.926382, Best valid accmin 0.925534, Time 00:04:21, lr 0.06590834930613629
# Epoch 77. Train Loss: -0.917768, Train Xent: 0.136214, Train Reconst: 0.011222, Train Pn: 0.004875, Train acc 0.968890, Valid Loss: 0.221955, Valid acc 0.933293, Valid acc2 0.923928, Valid accmax 0.926583, Valid accmin 0.921274, Best valid acc 0.933293, Best valid acc2 0.924545, Best valid accmax 0.926583, Best valid accmin 0.925534, Time 00:04:21, lr 0.06494754529161949
# Epoch 78. Train Loss: -0.924031, Train Xent: 0.132137, Train Reconst: 0.011031, Train Pn: 0.004867, Train acc 0.970229, Valid Loss: 0.381103, Valid acc 0.931991, Valid acc2 0.923127, Valid accmax 0.927684, Valid accmin 0.918570, Best valid acc 0.933293, Best valid acc2 0.924545, Best valid accmax 0.927684, Best valid accmin 0.925534, Time 00:04:22, lr 0.06400074776283673
# Epoch 79. Train Loss: -0.919210, Train Xent: 0.136179, Train Reconst: 0.010730, Train Pn: 0.004846, Train acc 0.968349, Valid Loss: 0.389933, Valid acc 0.930489, Valid acc2 0.922526, Valid accmax 0.920773, Valid accmin 0.924279, Best valid acc 0.933293, Best valid acc2 0.924545, Best valid accmax 0.927684, Best valid accmin 0.925534, Time 00:04:21, lr 0.06306775253491823
# Epoch 80. Train Loss: -0.924992, Train Xent: 0.131380, Train Reconst: 0.010770, Train Pn: 0.004848, Train acc 0.970348, Valid Loss: 0.416437, Valid acc 0.933248, Valid acc2 0.923803, Valid accmax 0.924446, Valid accmin 0.923161, Best valid acc 0.933293, Best valid acc2 0.924545, Best valid accmax 0.927684, Best valid accmin 0.925534, Time 00:04:21, lr 0.062148358399576706
# Epoch 81. Train Loss: -0.927338, Train Xent: 0.129452, Train Reconst: 0.011500, Train Pn: 0.004819, Train acc 0.970768, Valid Loss: 0.328374, Valid acc 0.930589, Valid acc2 0.919121, Valid accmax 0.920172, Valid accmin 0.918069, Best valid acc 0.933293, Best valid acc2 0.924545, Best valid accmax 0.927684, Best valid accmin 0.925534, Time 00:04:21, lr 0.0612423670817152
# Epoch 82. Train Loss: -0.929192, Train Xent: 0.128460, Train Reconst: 0.011463, Train Pn: 0.004704, Train acc 0.972075, Valid Loss: 0.415197, Valid acc 0.932492, Valid acc2 0.920673, Valid accmax 0.919872, Valid accmin 0.921474, Best valid acc 0.933293, Best valid acc2 0.924545, Best valid accmax 0.927684, Best valid accmin 0.925534, Time 00:04:21, lr 0.06034958319666734
# Epoch 83. Train Loss: -0.934449, Train Xent: 0.124724, Train Reconst: 0.012023, Train Pn: 0.004664, Train acc 0.972187, Valid Loss: 0.400343, Valid acc 0.930489, Valid acc2 0.921875, Valid accmax 0.920873, Valid accmin 0.922877, Best valid acc 0.933293, Best valid acc2 0.924545, Best valid accmax 0.927684, Best valid accmin 0.925534, Time 00:04:21, lr 0.05946981420806098
# Epoch 84. Train Loss: -0.937677, Train Xent: 0.122454, Train Reconst: 0.011845, Train Pn: 0.004586, Train acc 0.972966, Valid Loss: 0.367870, Valid acc 0.934996, Valid acc2 0.924529, Valid accmax 0.927083, Valid accmin 0.921975, Best valid acc 0.934996, Best valid acc2 0.924545, Best valid accmax 0.927684, Best valid accmin 0.925534, Time 00:04:21, lr 0.05860287038629614
# Epoch 85. Train Loss: -0.943969, Train Xent: 0.117692, Train Reconst: 0.011478, Train Pn: 0.004523, Train acc 0.974920, Valid Loss: 0.382240, Valid acc 0.926282, Valid acc2 0.918620, Valid accmax 0.918369, Valid accmin 0.918870, Best valid acc 0.934996, Best valid acc2 0.924545, Best valid accmax 0.927684, Best valid accmin 0.925534, Time 00:04:20, lr 0.0577485647676282
