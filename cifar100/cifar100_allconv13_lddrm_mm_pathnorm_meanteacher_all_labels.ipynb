# %%
import os
import math
import mxnet as mx
from mxnet import image
from mxnet import nd, gluon, autograd, init
from mxnet.gluon.data.vision import ImageFolderDataset
from mxnet.gluon.data import DataLoader
from mxnet.gluon import nn
from tensorboardX import SummaryWriter
import numpy as np
import shutil
import _pickle as cPickle
from sklearn import preprocessing
from mxnet.gluon.parameter import Parameter, ParameterDict
from common.util import download_file
import subprocess

from IPython.core.debugger import Tracer

# %%
class Options:
    def __init__(self):
        self.seed_val = 1
        self.num_train_sup = 50000
        self.batch_size = 128
        self.data_dir = '/tanData/datasets/cifar100'
        self.log_dir = '/tanData/logs'
        self.model_dir ='/tanData/models'
        self.exp_name = 'cifar100_nlabels_%i_allconv13_lddrm_mm_pathnorm_meanteacher_rampup_seed_%i'%(self.num_train_sup, self.seed_val)
        self.ctx = mx.gpu(5)
        self.alpha_drm = 0.5
        self.alpha_pn = 1.0
        self.alpha_kl = 0.5
        self.alpha_nn = 0.5
        self.alpha_consistent = 33.0
        
        self.use_bias = True
        self.use_bn = True
        self.do_topdown = True
        self.do_countpath = False
        self.do_pn = True
        self.relu_td = False
        self.do_nn = True

opt = Options()

# %%
def gpu_device(ctx=mx.gpu(0)):
    try:
        _ = mx.nd.array([1, 2, 3], ctx=ctx)
    except mx.MXNetError:
        return None
    return ctx

assert gpu_device(opt.ctx), 'No GPU device found!'

# %%
log_dir = os.path.join(opt.log_dir, opt.exp_name)
if not os.path.exists(log_dir):
    os.makedirs(log_dir)

# %%
data_shape = (3, 32, 32)
train_data_sup = mx.io.ImageRecordIter(
    path_imgrec = os.path.join(opt.data_dir,'cifar100_train.rec'),
    data_shape  = data_shape,
    batch_size  = opt.batch_size,
    mean_r             = 129.3,
    mean_g             = 124.1,
    mean_b             = 112.4,
    std_r              = 68.2,
    std_g              = 65.4,
    std_b              = 70.4,
    shuffle = True,
    ## Data augmentation
    rand_crop   = True,
    max_crop_size = 32,
    min_crop_size = 32,
    pad = 4,
    fill_value = 0,
    rand_mirror = True)
valid_data = mx.io.ImageRecordIter(
    path_imgrec = os.path.join(opt.data_dir,'cifar100_val.rec'),
    data_shape  = data_shape,
    batch_size  = opt.batch_size,
    mean_r             = 129.3,
    mean_g             = 124.1,
    mean_b             = 112.4,
    std_r              = 68.2,
    std_g              = 65.4,
    std_b              = 70.4,
    ## No data augmentation
    rand_crop   = False,
    rand_mirror = False)

# %%
criterion = gluon.loss.SoftmaxCrossEntropyLoss()
L2_loss = gluon.loss.L2Loss()
L1_loss = gluon.loss.L1Loss()

# %%
class Normal(mx.init.Initializer):
    """Initializes weights with random values sampled from a normal distribution
    with a mean and standard deviation of `sigma`.
    """
    def __init__(self, mean=0, sigma=0.01):
        super(Normal, self).__init__(sigma=sigma)
        self.sigma = sigma
        self.mean = mean

    def _init_weight(self, _, arr):
        mx.random.normal(self.mean, self.sigma, out=arr)

# %%
# from resnet import ResNet164_v2
from mxnet.gluon.model_zoo import vision as models
from vgg_ld_opt import VGG_DRM

# %%
import datetime
writer = SummaryWriter(os.path.join(opt.log_dir, opt.exp_name))

def get_acc(output, label):
    pred = output.argmax(1, keepdims=False)
    correct = (pred == label).sum()
    return correct.asscalar()

def extract_acts(net, x, layer_indx):
    start_layer = 0
    out = []
    for i in layer_indx:
        for block in net.features._children[start_layer:i]:
            x = block(x)
        out.append(x)
        start_layer = i
    return out

def update_ema_variables(model, ema_model, alpha, global_step):
    # Use the true average until the exponential average is more correct
    alpha = min(1 - 1 / (global_step + 1), alpha)
    for ema_param, param in zip(ema_model.collect_params().values(), model.collect_params().values()):
        ema_param.set_data(alpha * ema_param.data() + (1 - alpha) * param.data())
        
def test(net, valid_data, ctx):
    valid_data.reset()
    valid_loss = 0; valid_loss_xentropy = 0; valid_loss_drm = 0; valid_loss_pn = 0; valid_loss_kl = 0; valid_loss_nn = 0
    valid_correct = 0; valid_total = 0
    num_batch_valid = 0
    for batch in valid_data:
        bs = batch.data[0].shape[0]
        data = batch.data[0].as_in_context(ctx)
        label = batch.label[0].as_in_context(ctx)
        [output, xhat, _, loss_pn, loss_nn] = net(data, label)
        loss_xentropy = criterion(output, label)
        loss_drm = L2_loss(xhat, data)
        softmax_val = nd.softmax(output)
        loss_kl = -nd.sum(nd.log(100.0*softmax_val + 1e-8) * softmax_val, axis=1)
        loss = loss_xentropy + opt.alpha_drm * loss_drm + opt.alpha_kl * loss_kl + opt.alpha_nn * loss_nn + opt.alpha_pn * loss_pn

        valid_loss_xentropy += nd.mean(loss_xentropy).asscalar()
        valid_loss_drm += nd.mean(loss_drm).asscalar()
        valid_loss_pn += nd.mean(loss_pn).asscalar()
        valid_loss_kl += nd.mean(loss_kl).asscalar()
        valid_loss_nn += nd.mean(loss_nn).asscalar()
        valid_loss += nd.mean(loss).asscalar()
        valid_correct += get_acc(output, label)

        valid_total += bs
        num_batch_valid += 1
    valid_acc = valid_correct / valid_total
    return valid_acc, valid_loss_xentropy, valid_loss_drm, valid_loss_pn, valid_loss_kl, valid_loss_nn, valid_loss, num_batch_valid

def write_results(writer, name, valid_acc, valid_loss_xentropy, valid_loss_drm, valid_loss_pn, valid_loss_kl, valid_loss_nn, valid_loss, num_batch_valid, epoch):
    writer.add_scalars('loss', {'%s'%name: valid_loss / num_batch_valid}, epoch)
    writer.add_scalars('loss_xentropy', {'%s'%name: valid_loss_xentropy / num_batch_valid}, epoch)
    writer.add_scalars('loss_drm', {'%s'%name: valid_loss_drm / num_batch_valid}, epoch)
    writer.add_scalars('loss_pn', {'%s'%name: valid_loss_pn / num_batch_valid}, epoch)
    writer.add_scalars('loss_kl', {'%s'%name: valid_loss_kl / num_batch_valid}, epoch)
    writer.add_scalars('loss_nn', {'%s'%name: valid_loss_nn / num_batch_valid}, epoch)
    writer.add_scalars('acc', {'%s'%name: valid_acc}, epoch)

# %%
def train(net, ema_net, train_data_sup, valid_data, num_epochs, lr, wd, ctx, lr_decay, relu_indx, ema_decay):
    trainer = gluon.Trainer(
        net.collect_params(), 'adam', {'learning_rate': 0.0001, 'wd': wd})
    
    prev_time = datetime.datetime.now()
    best_valid_acc = 0
    best_valid_acc_ema = 0
    iter_indx = 0
    global_step = 0
    
    for epoch in range(num_epochs-100):
        train_data_sup.reset()
        train_loss = 0; train_loss_xentropy = 0; train_loss_drm = 0; train_loss_pn = 0; train_loss_kl = 0; train_loss_nn = 0
        correct = 0; total = 0
        num_batch_train = 0
        
        if epoch == 20:
            sgd_lr = 0.15
            decay_val = np.exp(np.log(sgd_lr / 0.0001) / (num_epochs - 2))
            sgd_lr = sgd_lr * decay_val
            trainer = gluon.Trainer(net.collect_params(), 'SGD', {'learning_rate': sgd_lr, 'wd': wd})
            
        if epoch >= 20:
            trainer.set_learning_rate(trainer.learning_rate / decay_val)
        
        for batch_sup in train_data_sup:
            bs = batch_sup.data[0].shape[0]
            data_sup = batch_sup.data[0].as_in_context(ctx)
            label_sup = batch_sup.label[0].as_in_context(ctx)
            with autograd.record():
                [output_sup, xhat_sup, _, loss_pn_sup, loss_nn_sup] = net(data_sup, label_sup)
                if global_step == 0:
                    for ema_param, param in zip(ema_net.collect_params().values(),net.collect_params().values()):
                        ema_param.initialize(init=mx.initializer.Constant(param.data()), ctx=ctx)
                [output_sup_ema, _, _, _, _] = ema_net(data_sup, label_sup)
                loss_xentropy_sup = criterion(output_sup, label_sup)
                loss_drm_sup = L2_loss(xhat_sup, data_sup)
                softmax_sup = nd.softmax(output_sup)
                softmax_sup_ema = nd.softmax(output_sup_ema)
                loss_kl_sup = -nd.sum(nd.log(100.0*softmax_sup + 1e-8) * softmax_sup, axis=1)
                loss_consistent_sup = L2_loss(softmax_sup, softmax_sup_ema)
                loss = loss_xentropy_sup + opt.alpha_drm * loss_drm_sup + opt.alpha_kl * loss_kl_sup + opt.alpha_nn * loss_nn_sup + opt.alpha_pn * loss_pn_sup + opt.alpha_consistent * loss_consistent_sup
                
            loss.backward()
            trainer.step(bs)
            global_step += 1
            if global_step < 40000:
                update_ema_variables(net, ema_net, ema_decay[0], global_step)
            else:
                update_ema_variables(net, ema_net, ema_decay[1], global_step)
            
            loss_drm = loss_drm_sup
            loss_pn = loss_pn_sup
            loss_xentropy = loss_xentropy_sup
            loss_kl = loss_kl_sup
            loss_nn = loss_nn_sup
            
            train_loss_xentropy += nd.mean(loss_xentropy).asscalar()
            train_loss_drm += nd.mean(loss_drm).asscalar()
            train_loss_pn += nd.mean(loss_pn).asscalar()
            train_loss_kl += nd.mean(loss_kl).asscalar()
            train_loss_nn += nd.mean(loss_nn).asscalar()
            train_loss += nd.mean(loss).asscalar()
            correct += get_acc(output_sup, label_sup)
            
            total += bs
            num_batch_train += 1
            iter_indx += 1
        
        writer.add_scalars('loss', {'train': train_loss / num_batch_train}, epoch)
        writer.add_scalars('loss_xentropy', {'train': train_loss_xentropy / num_batch_train}, epoch)
        writer.add_scalars('loss_drm', {'train': train_loss_drm / num_batch_train}, epoch)
        writer.add_scalars('loss_pn', {'train': train_loss_pn / num_batch_train}, epoch)
        writer.add_scalars('loss_kl', {'train': train_loss_kl / num_batch_train}, epoch)
        writer.add_scalars('loss_nn', {'train': train_loss_nn / num_batch_train}, epoch)
        writer.add_scalars('acc', {'train': correct / total}, epoch)
        
        cur_time = datetime.datetime.now()
        h, remainder = divmod((cur_time - prev_time).seconds, 3600)
        m, s = divmod(remainder, 60)
        time_str = "Time %02d:%02d:%02d" % (h, m, s)
        if valid_data is not None:
            valid_acc, valid_loss_xentropy, valid_loss_drm, valid_loss_pn, valid_loss_kl, valid_loss_nn, valid_loss, num_batch_valid = test(net, valid_data, ctx)
            if valid_acc > best_valid_acc:
                best_valid_acc = valid_acc
                net.collect_params().save('%s/%s_best.params'%(opt.model_dir, opt.exp_name))
            write_results(writer, 'valid', valid_acc, valid_loss_xentropy, valid_loss_drm, valid_loss_pn, valid_loss_kl, valid_loss_nn, valid_loss, num_batch_valid, epoch)
            epoch_str = ("Epoch %d. Train Loss: %f, Train Xent: %f, Train Reconst: %f, Train Pn: %f, Train acc %f, Valid Loss: %f, Valid acc %f, Best valid acc %f, "
                         % (epoch, train_loss / num_batch_train, train_loss_xentropy / num_batch_train, train_loss_drm / num_batch_train, train_loss_pn / num_batch_train,
                            correct / total, valid_loss / num_batch_valid, valid_acc, best_valid_acc))
            
            valid_acc, valid_loss_xentropy, valid_loss_drm, valid_loss_pn, valid_loss_kl, valid_loss_nn, valid_loss, num_batch_valid = test(ema_net, valid_data, ctx)
            if valid_acc > best_valid_acc_ema:
                best_valid_acc_ema = valid_acc
                net.collect_params().save('%s/%s_ema_best.params'%(opt.model_dir, opt.exp_name))
            write_results(writer, 'valid_ema', valid_acc, valid_loss_xentropy, valid_loss_drm, valid_loss_pn, valid_loss_kl, valid_loss_nn, valid_loss, num_batch_valid, epoch)    
            epoch_str_ema = ("Epoch %d. Valid Loss EMA: %f, Valid acc EMA %f, Best valid acc EMA %f, "
                         % (epoch, valid_loss / num_batch_valid, valid_acc, best_valid_acc))
            if not epoch % 20:
                net.collect_params().save('%s/%s_epoch_%i.params'%(opt.model_dir, opt.exp_name, epoch))
                net.collect_params().save('%s/%s_ema_epoch_%i.params'%(opt.model_dir, opt.exp_name, epoch))
        else:
            epoch_str = ("Epoch %d. Loss: %f, Train acc %f, "
                         % (epoch, train_loss / num_batch_train,
                            correct / total))
        prev_time = cur_time
        print(epoch_str + time_str + ', lr ' + str(trainer.learning_rate))
        print(epoch_str_ema + time_str)
        
    return best_valid_acc

# %%
num_epochs = 500
learning_rate = 0.15
weight_decay = 5e-4
lr_decay = 0.1
ema_decay = [0.99, 0.999]

# %%
def run_train(num_exp, ctx):
    valid_acc = 0
    for i in range(num_exp):
        ### CIFAR VGG_DRM
        model = VGG_DRM('AllConv13', batch_size=opt.batch_size, num_class=100, use_bias=opt.use_bias, use_bn=opt.use_bn, do_topdown=opt.do_topdown, do_countpath=opt.do_countpath, do_pn=opt.do_pn, relu_td=opt.relu_td, do_nn=opt.do_nn)
        for param in model.collect_params().values():
            if param.name.find('conv') != -1 or param.name.find('dense') != -1:
                if param.name.find('weight') != -1:
                    param.initialize(init=mx.initializer.Xavier(), ctx=ctx)
                else:
                    param.initialize(init=mx.init.Zero(), ctx=ctx)
            elif param.name.find('batchnorm') != -1 or param.name.find('instancenorm') != -1:
                if param.name.find('gamma') != -1:
                    param.initialize(init=Normal(mean=1, sigma=0.02), ctx=ctx)
                else:
                    param.initialize(init=mx.init.Zero(), ctx=ctx)
            elif param.name.find('biasadder') != -1:
                param.initialize(init=mx.init.Zero(), ctx=ctx)
                
        ema_model = VGG_DRM('AllConv13', batch_size=opt.batch_size, num_class=100, use_bias=opt.use_bias, use_bn=opt.use_bn, do_topdown=opt.do_topdown, do_countpath=opt.do_countpath, do_pn=opt.do_pn, relu_td=opt.relu_td, do_nn=opt.do_nn)
        # model.hybridize()
        
        relu_indx = []
        
        for i in range(len(model.features._children)):
            if model.features._children[i].name.find('relu') != -1:
                relu_indx.append(i)
                
        acc = train(model, ema_model, train_data_sup, valid_data, num_epochs, learning_rate, weight_decay, ctx, lr_decay, relu_indx, ema_decay)
        print('Validation Accuracy - Run %i = %f'%(i, acc))
        valid_acc += acc

    print('Validation Accuracy = %f'%(valid_acc/num_exp))

# %%
run_train(1, ctx=opt.ctx)
# Out:
# Epoch 0. Train Loss: 7.182033, Train Xent: 4.166586, Train Reconst: 0.699669, Train Pn: 0.000295, Train acc 0.076666, Valid Loss: 7.368681, Valid acc 0.092761, Best valid acc 0.092761, Time 00:03:29, lr 0.0001
# Epoch 0. Valid Loss EMA: 6.656285, Valid acc EMA 0.101062, Best valid acc EMA 0.092761, Time 00:03:29
# Epoch 1. Train Loss: 5.424252, Train Xent: 3.786090, Train Reconst: 0.289311, Train Pn: 0.000947, Train acc 0.133032, Valid Loss: 6.095891, Valid acc 0.132212, Best valid acc 0.132212, Time 00:03:44, lr 0.0001
# Epoch 1. Valid Loss EMA: 5.613025, Valid acc EMA 0.148638, Best valid acc EMA 0.132212, Time 00:03:44
# Epoch 2. Train Loss: 4.500122, Train Xent: 3.571621, Train Reconst: 0.214945, Train Pn: 0.002538, Train acc 0.165465, Valid Loss: 8.571475, Valid acc 0.097656, Best valid acc 0.132212, Time 00:03:43, lr 0.0001
# Epoch 2. Valid Loss EMA: 5.910604, Valid acc EMA 0.171975, Best valid acc EMA 0.132212, Time 00:03:43
# Epoch 3. Train Loss: 3.813007, Train Xent: 3.395284, Train Reconst: 0.175263, Train Pn: 0.004574, Train acc 0.192675, Valid Loss: 9.530871, Valid acc 0.136318, Best valid acc 0.136318, Time 00:03:44, lr 0.0001
# Epoch 3. Valid Loss EMA: 6.192488, Valid acc EMA 0.208333, Best valid acc EMA 0.136318, Time 00:03:44
# Epoch 4. Train Loss: 3.264604, Train Xent: 3.238887, Train Reconst: 0.149090, Train Pn: 0.006230, Train acc 0.219669, Valid Loss: 9.677531, Valid acc 0.124209, Best valid acc 0.136318, Time 00:03:43, lr 0.0001
# Epoch 4. Valid Loss EMA: 6.267048, Valid acc EMA 0.237480, Best valid acc EMA 0.136318, Time 00:03:43
# Epoch 5. Train Loss: 2.851065, Train Xent: 3.097004, Train Reconst: 0.129252, Train Pn: 0.007219, Train acc 0.243309, Valid Loss: 7.761136, Valid acc 0.186999, Best valid acc 0.186999, Time 00:03:42, lr 0.0001
# Epoch 5. Valid Loss EMA: 7.061140, Valid acc EMA 0.267328, Best valid acc EMA 0.186999, Time 00:03:42
# Epoch 6. Train Loss: 2.511399, Train Xent: 2.954487, Train Reconst: 0.114455, Train Pn: 0.007808, Train acc 0.269301, Valid Loss: 11.378269, Valid acc 0.213241, Best valid acc 0.213241, Time 00:03:43, lr 0.0001
# Epoch 6. Valid Loss EMA: 9.957404, Valid acc EMA 0.290966, Best valid acc EMA 0.213241, Time 00:03:43
# Epoch 7. Train Loss: 2.227741, Train Xent: 2.826215, Train Reconst: 0.104623, Train Pn: 0.008228, Train acc 0.296815, Valid Loss: 16.782439, Valid acc 0.252103, Best valid acc 0.252103, Time 00:03:42, lr 0.0001
# Epoch 7. Valid Loss EMA: 16.037293, Valid acc EMA 0.321715, Best valid acc EMA 0.252103, Time 00:03:42
# Epoch 8. Train Loss: 1.977872, Train Xent: 2.708240, Train Reconst: 0.095170, Train Pn: 0.008516, Train acc 0.318894, Valid Loss: 39.929685, Valid acc 0.236056, Best valid acc 0.252103, Time 00:03:43, lr 0.0001
# Epoch 8. Valid Loss EMA: 30.088044, Valid acc EMA 0.346755, Best valid acc EMA 0.252103, Time 00:03:43
# Epoch 9. Train Loss: 1.764318, Train Xent: 2.599323, Train Reconst: 0.087009, Train Pn: 0.008732, Train acc 0.340853, Valid Loss: 80.984224, Valid acc 0.247696, Best valid acc 0.252103, Time 00:03:43, lr 0.0001
# Epoch 9. Valid Loss EMA: 49.617523, Valid acc EMA 0.376502, Best valid acc EMA 0.252103, Time 00:03:43
# Epoch 10. Train Loss: 1.593588, Train Xent: 2.507545, Train Reconst: 0.080629, Train Pn: 0.008862, Train acc 0.358213, Valid Loss: 82.706119, Valid acc 0.315304, Best valid acc 0.315304, Time 00:03:42, lr 0.0001
# Epoch 10. Valid Loss EMA: 69.636618, Valid acc EMA 0.402043, Best valid acc EMA 0.315304, Time 00:03:42
# Epoch 11. Train Loss: 1.419228, Train Xent: 2.405119, Train Reconst: 0.074091, Train Pn: 0.008972, Train acc 0.379296, Valid Loss: 76.954352, Valid acc 0.350260, Best valid acc 0.350260, Time 00:03:43, lr 0.0001
# Epoch 11. Valid Loss EMA: 73.897429, Valid acc EMA 0.425280, Best valid acc EMA 0.350260, Time 00:03:43
# Epoch 12. Train Loss: 1.270514, Train Xent: 2.320358, Train Reconst: 0.068568, Train Pn: 0.008927, Train acc 0.398717, Valid Loss: 99.663763, Valid acc 0.263845, Best valid acc 0.350260, Time 00:03:43, lr 0.0001
# Epoch 12. Valid Loss EMA: 90.633385, Valid acc EMA 0.448718, Best valid acc EMA 0.350260, Time 00:03:43
# Epoch 13. Train Loss: 1.135219, Train Xent: 2.243000, Train Reconst: 0.064014, Train Pn: 0.008983, Train acc 0.418109, Valid Loss: 108.524144, Valid acc 0.432192, Best valid acc 0.432192, Time 00:03:43, lr 0.0001
# Epoch 13. Valid Loss EMA: 106.460081, Valid acc EMA 0.463442, Best valid acc EMA 0.432192, Time 00:03:43
# Epoch 14. Train Loss: 1.025114, Train Xent: 2.178591, Train Reconst: 0.059337, Train Pn: 0.008892, Train acc 0.430207, Valid Loss: 70.133043, Valid acc 0.448017, Best valid acc 0.448017, Time 00:03:43, lr 0.0001
# Epoch 14. Valid Loss EMA: 117.573186, Valid acc EMA 0.480168, Best valid acc EMA 0.448017, Time 00:03:43
# Epoch 15. Train Loss: 0.908889, Train Xent: 2.107423, Train Reconst: 0.055223, Train Pn: 0.008836, Train acc 0.447135, Valid Loss: 107.389783, Valid acc 0.463942, Best valid acc 0.463942, Time 00:03:42, lr 0.0001
# Epoch 15. Valid Loss EMA: 126.809326, Valid acc EMA 0.499700, Best valid acc EMA 0.463942, Time 00:03:42
# Epoch 16. Train Loss: 0.798829, Train Xent: 2.041264, Train Reconst: 0.052062, Train Pn: 0.008709, Train acc 0.461737, Valid Loss: 159.643623, Valid acc 0.417820, Best valid acc 0.463942, Time 00:03:43, lr 0.0001
# Epoch 16. Valid Loss EMA: 137.429084, Valid acc EMA 0.506611, Best valid acc EMA 0.463942, Time 00:03:43
# Epoch 17. Train Loss: 0.705971, Train Xent: 1.987198, Train Reconst: 0.048441, Train Pn: 0.008617, Train acc 0.472946, Valid Loss: 154.921535, Valid acc 0.433293, Best valid acc 0.463942, Time 00:03:43, lr 0.0001
# Epoch 17. Valid Loss EMA: 138.531982, Valid acc EMA 0.515725, Best valid acc EMA 0.463942, Time 00:03:43
# Epoch 18. Train Loss: 0.624254, Train Xent: 1.936954, Train Reconst: 0.045885, Train Pn: 0.008491, Train acc 0.488622, Valid Loss: 149.504048, Valid acc 0.458333, Best valid acc 0.463942, Time 00:03:42, lr 0.0001
# Epoch 18. Valid Loss EMA: 146.139571, Valid acc EMA 0.526542, Best valid acc EMA 0.463942, Time 00:03:42
# Epoch 19. Train Loss: 0.541447, Train Xent: 1.885652, Train Reconst: 0.043005, Train Pn: 0.008313, Train acc 0.497682, Valid Loss: 106.874336, Valid acc 0.512520, Best valid acc 0.512520, Time 00:03:43, lr 0.0001
# Epoch 19. Valid Loss EMA: 121.541468, Valid acc EMA 0.535156, Best valid acc EMA 0.512520, Time 00:03:43
# Epoch 20. Train Loss: 2.506263, Train Xent: 2.931368, Train Reconst: 0.067082, Train Pn: 0.016945, Train acc 0.307085, Valid Loss: 19.584343, Valid acc 0.349090, Best valid acc 0.512520, Time 00:03:41, lr 0.15
# Epoch 20. Valid Loss EMA: 5.790553, Valid acc EMA 0.504407, Best valid acc EMA 0.512520, Time 00:03:41
# Epoch 21. Train Loss: 1.053708, Train Xent: 2.269283, Train Reconst: 0.051725, Train Pn: 0.019436, Train acc 0.421675, Valid Loss: 27.070192, Valid acc 0.452123, Best valid acc 0.512520, Time 00:03:41, lr 0.14781331798330893
# Epoch 21. Valid Loss EMA: 11.293115, Valid acc EMA 0.546274, Best valid acc EMA 0.512520, Time 00:03:41
# Epoch 22. Train Loss: 0.653088, Train Xent: 2.044687, Train Reconst: 0.043057, Train Pn: 0.019365, Train acc 0.471507, Valid Loss: 13.424300, Valid acc 0.457833, Best valid acc 0.512520, Time 00:03:41, lr 0.14565851315489867
# Epoch 22. Valid Loss EMA: 9.911931, Valid acc EMA 0.569411, Best valid acc EMA 0.512520, Time 00:03:41
# Epoch 23. Train Loss: 0.422577, Train Xent: 1.891603, Train Reconst: 0.036313, Train Pn: 0.017820, Train acc 0.505108, Valid Loss: 7.369028, Valid acc 0.501803, Best valid acc 0.512520, Time 00:03:41, lr 0.14353512081294018
# Epoch 23. Valid Loss EMA: 7.709008, Valid acc EMA 0.587740, Best valid acc EMA 0.512520, Time 00:03:41
# Epoch 24. Train Loss: 0.258898, Train Xent: 1.778261, Train Reconst: 0.030550, Train Pn: 0.016374, Train acc 0.528493, Valid Loss: 4.997474, Valid acc 0.515328, Best valid acc 0.515328, Time 00:03:41, lr 0.14144268302997196
# Epoch 24. Valid Loss EMA: 4.518528, Valid acc EMA 0.604067, Best valid acc EMA 0.515328, Time 00:03:41
# Epoch 25. Train Loss: 0.112705, Train Xent: 1.684748, Train Reconst: 0.025407, Train Pn: 0.015065, Train acc 0.552629, Valid Loss: 4.733581, Valid acc 0.563802, Best valid acc 0.563802, Time 00:03:42, lr 0.13938074855414412
# Epoch 25. Valid Loss EMA: 3.578442, Valid acc EMA 0.615585, Best valid acc EMA 0.563802, Time 00:03:42
# Epoch 26. Train Loss: -0.002845, Train Xent: 1.604228, Train Reconst: 0.022220, Train Pn: 0.014268, Train acc 0.569772, Valid Loss: 3.183697, Valid acc 0.539263, Best valid acc 0.563802, Time 00:03:40, lr 0.13734887271190221
# Epoch 26. Valid Loss EMA: 3.033245, Valid acc EMA 0.625701, Best valid acc EMA 0.563802, Time 00:03:40
# Epoch 27. Train Loss: -0.095961, Train Xent: 1.547424, Train Reconst: 0.019724, Train Pn: 0.013755, Train acc 0.582601, Valid Loss: 3.610438, Valid acc 0.558994, Best valid acc 0.563802, Time 00:03:41, lr 0.1353466173120895
# Epoch 27. Valid Loss EMA: 2.978237, Valid acc EMA 0.631611, Best valid acc EMA 0.563802, Time 00:03:41
# Epoch 28. Train Loss: -0.188919, Train Xent: 1.484357, Train Reconst: 0.018338, Train Pn: 0.013389, Train acc 0.597087, Valid Loss: 3.281769, Valid acc 0.573675, Best valid acc 0.573675, Time 00:03:41, lr 0.1333735505514474
# Epoch 28. Valid Loss EMA: 2.644966, Valid acc EMA 0.637520, Best valid acc EMA 0.573675, Time 00:03:41
# Epoch 29. Train Loss: -0.267501, Train Xent: 1.427864, Train Reconst: 0.016952, Train Pn: 0.012986, Train acc 0.609696, Valid Loss: 3.108220, Valid acc 0.590244, Best valid acc 0.590244, Time 00:03:41, lr 0.1314292469214935
# Epoch 29. Valid Loss EMA: 2.448738, Valid acc EMA 0.647837, Best valid acc EMA 0.590244, Time 00:03:41
# Epoch 30. Train Loss: -0.333855, Train Xent: 1.380803, Train Reconst: 0.015704, Train Pn: 0.012954, Train acc 0.620424, Valid Loss: 2.120969, Valid acc 0.587941, Best valid acc 0.590244, Time 00:03:41, lr 0.12951328711675697
# Epoch 30. Valid Loss EMA: 2.007378, Valid acc EMA 0.653846, Best valid acc EMA 0.590244, Time 00:03:41
# Epoch 31. Train Loss: -0.398107, Train Xent: 1.334648, Train Reconst: 0.015161, Train Pn: 0.013178, Train acc 0.632171, Valid Loss: 2.844529, Valid acc 0.610777, Best valid acc 0.610777, Time 00:03:41, lr 0.12762525794435192
# Epoch 31. Valid Loss EMA: 1.614087, Valid acc EMA 0.662260, Best valid acc EMA 0.610777, Time 00:03:41
# Epoch 32. Train Loss: -0.457865, Train Xent: 1.291774, Train Reconst: 0.014559, Train Pn: 0.013139, Train acc 0.641964, Valid Loss: 1.871265, Valid acc 0.607298, Best valid acc 0.610777, Time 00:03:41, lr 0.12576475223486877
# Epoch 32. Valid Loss EMA: 1.500877, Valid acc EMA 0.665164, Best valid acc EMA 0.610777, Time 00:03:41
# Epoch 33. Train Loss: -0.507867, Train Xent: 1.254997, Train Reconst: 0.014322, Train Pn: 0.013204, Train acc 0.649816, Valid Loss: 1.201934, Valid acc 0.599559, Best valid acc 0.610777, Time 00:03:41, lr 0.12393136875456481
# Epoch 33. Valid Loss EMA: 1.335729, Valid acc EMA 0.672075, Best valid acc EMA 0.610777, Time 00:03:41
# Epoch 34. Train Loss: -0.563229, Train Xent: 1.216970, Train Reconst: 0.013440, Train Pn: 0.013318, Train acc 0.659976, Valid Loss: 1.354272, Valid acc 0.609976, Best valid acc 0.610777, Time 00:03:40, lr 0.12212471211883472
# Epoch 34. Valid Loss EMA: 0.975922, Valid acc EMA 0.674579, Best valid acc EMA 0.610777, Time 00:03:40
# Epoch 35. Train Loss: -0.607089, Train Xent: 1.183799, Train Reconst: 0.013285, Train Pn: 0.013511, Train acc 0.667439, Valid Loss: 0.934919, Valid acc 0.610276, Best valid acc 0.610777, Time 00:03:41, lr 0.12034439270694253
# Epoch 35. Valid Loss EMA: 0.856559, Valid acc EMA 0.678686, Best valid acc EMA 0.610777, Time 00:03:41
# Epoch 36. Train Loss: -0.659986, Train Xent: 1.144703, Train Reconst: 0.013474, Train Pn: 0.013365, Train acc 0.680287, Valid Loss: 1.023704, Valid acc 0.622429, Best valid acc 0.622429, Time 00:03:40, lr 0.11859002657799667
# Epoch 36. Valid Loss EMA: 0.477183, Valid acc EMA 0.678586, Best valid acc EMA 0.622429, Time 00:03:40
# Epoch 37. Train Loss: -0.683548, Train Xent: 1.129886, Train Reconst: 0.013701, Train Pn: 0.013644, Train acc 0.679768, Valid Loss: 1.304603, Valid acc 0.632212, Best valid acc 0.632212, Time 00:03:40, lr 0.11686123538814987
# Epoch 37. Valid Loss EMA: 0.523025, Valid acc EMA 0.681991, Best valid acc EMA 0.632212, Time 00:03:40
# Epoch 38. Train Loss: -0.743148, Train Xent: 1.082898, Train Reconst: 0.012541, Train Pn: 0.013541, Train acc 0.694873, Valid Loss: 1.135961, Valid acc 0.623898, Best valid acc 0.632212, Time 00:03:41, lr 0.11515764630900607
# Epoch 38. Valid Loss EMA: 0.276357, Valid acc EMA 0.685296, Best valid acc EMA 0.632212, Time 00:03:41
# Epoch 39. Train Loss: -0.777275, Train Xent: 1.056339, Train Reconst: 0.012364, Train Pn: 0.013638, Train acc 0.699339, Valid Loss: 0.969933, Valid acc 0.631410, Best valid acc 0.632212, Time 00:03:40, lr 0.11347889194721691
# Epoch 39. Valid Loss EMA: 0.239990, Valid acc EMA 0.690204, Best valid acc EMA 0.632212, Time 00:03:40
# Epoch 40. Train Loss: -0.803791, Train Xent: 1.039671, Train Reconst: 0.012396, Train Pn: 0.013762, Train acc 0.704484, Valid Loss: 0.482983, Valid acc 0.632516, Best valid acc 0.632516, Time 00:03:41, lr 0.1118246102652502
# Epoch 40. Valid Loss EMA: 0.069504, Valid acc EMA 0.689403, Best valid acc EMA 0.632516, Time 00:03:41
# Epoch 41. Train Loss: -0.844258, Train Xent: 1.007479, Train Reconst: 0.012011, Train Pn: 0.013720, Train acc 0.710498, Valid Loss: 0.295874, Valid acc 0.645633, Best valid acc 0.645633, Time 00:03:41, lr 0.11019444450331348
# Epoch 41. Valid Loss EMA: 0.116561, Valid acc EMA 0.690505, Best valid acc EMA 0.645633, Time 00:03:41
# Epoch 42. Train Loss: -0.870253, Train Xent: 0.989046, Train Reconst: 0.011887, Train Pn: 0.013807, Train acc 0.717688, Valid Loss: 0.456334, Valid acc 0.619892, Best valid acc 0.645633, Time 00:03:40, lr 0.10858804310241577
# Epoch 42. Valid Loss EMA: 0.204961, Valid acc EMA 0.693910, Best valid acc EMA 0.645633, Time 00:03:40
# Epoch 43. Train Loss: -0.904298, Train Xent: 0.963214, Train Reconst: 0.011882, Train Pn: 0.013982, Train acc 0.721487, Valid Loss: 0.823632, Valid acc 0.615385, Best valid acc 0.645633, Time 00:03:41, lr 0.10700505962855092
# Epoch 43. Valid Loss EMA: -0.045898, Valid acc EMA 0.695413, Best valid acc EMA 0.645633, Time 00:03:41
# Epoch 44. Train Loss: -0.938254, Train Xent: 0.938772, Train Reconst: 0.011690, Train Pn: 0.013833, Train acc 0.728201, Valid Loss: 0.489247, Valid acc 0.647053, Best valid acc 0.647053, Time 00:03:41, lr 0.10544515269798621
# Epoch 44. Valid Loss EMA: -0.024617, Valid acc EMA 0.699219, Best valid acc EMA 0.647053, Time 00:03:41
# Epoch 45. Train Loss: -0.969725, Train Xent: 0.914104, Train Reconst: 0.011540, Train Pn: 0.013927, Train acc 0.735537, Valid Loss: 0.289564, Valid acc 0.649239, Best valid acc 0.649239, Time 00:03:41, lr 0.10390798590364002
# Epoch 45. Valid Loss EMA: -0.123530, Valid acc EMA 0.700921, Best valid acc EMA 0.649239, Time 00:03:41
# Epoch 46. Train Loss: -0.994791, Train Xent: 0.895945, Train Reconst: 0.011611, Train Pn: 0.013969, Train acc 0.738531, Valid Loss: 0.121442, Valid acc 0.646534, Best valid acc 0.649239, Time 00:03:42, lr 0.10239322774253283
# Epoch 46. Valid Loss EMA: -0.201601, Valid acc EMA 0.697316, Best valid acc EMA 0.649239, Time 00:03:42
# Epoch 47. Train Loss: -1.013396, Train Xent: 0.881630, Train Reconst: 0.011270, Train Pn: 0.014165, Train acc 0.741707, Valid Loss: 0.264454, Valid acc 0.638421, Best valid acc 0.649239, Time 00:03:41, lr 0.10090055154429584
# Epoch 47. Valid Loss EMA: -0.246900, Valid acc EMA 0.700821, Best valid acc EMA 0.649239, Time 00:03:41
# Epoch 48. Train Loss: -1.052258, Train Xent: 0.852910, Train Reconst: 0.010778, Train Pn: 0.014083, Train acc 0.748901, Valid Loss: 0.013301, Valid acc 0.655360, Best valid acc 0.655360, Time 00:03:42, lr 0.0994296354007217
# Epoch 48. Valid Loss EMA: -0.306562, Valid acc EMA 0.702524, Best valid acc EMA 0.655360, Time 00:03:42
# Epoch 49. Train Loss: -1.077022, Train Xent: 0.833090, Train Reconst: 0.010719, Train Pn: 0.014092, Train acc 0.755095, Valid Loss: 0.237618, Valid acc 0.642929, Best valid acc 0.655360, Time 00:03:42, lr 0.09798016209634232
# Epoch 49. Valid Loss EMA: -0.417148, Valid acc EMA 0.701022, Best valid acc EMA 0.655360, Time 00:03:42
# Epoch 50. Train Loss: -1.100753, Train Xent: 0.816377, Train Reconst: 0.010626, Train Pn: 0.014053, Train acc 0.761078, Valid Loss: 0.101636, Valid acc 0.650942, Best valid acc 0.655360, Time 00:03:41, lr 0.09655181904001867
# Epoch 50. Valid Loss EMA: -0.389102, Valid acc EMA 0.705529, Best valid acc EMA 0.655360, Time 00:03:41
# Epoch 51. Train Loss: -1.114616, Train Xent: 0.805957, Train Reconst: 0.010564, Train Pn: 0.014099, Train acc 0.761509, Valid Loss: 0.109111, Valid acc 0.661659, Best valid acc 0.661659, Time 00:03:42, lr 0.09514429819752787
# Epoch 51. Valid Loss EMA: -0.327730, Valid acc EMA 0.708634, Best valid acc EMA 0.661659, Time 00:03:42
# Epoch 52. Train Loss: -1.142009, Train Xent: 0.785407, Train Reconst: 0.010352, Train Pn: 0.014102, Train acc 0.766284, Valid Loss: 0.067660, Valid acc 0.650415, Best valid acc 0.661659, Time 00:03:42, lr 0.09375729602513302
# Epoch 52. Valid Loss EMA: -0.382214, Valid acc EMA 0.703626, Best valid acc EMA 0.661659, Time 00:03:42
# Epoch 53. Train Loss: -1.159613, Train Xent: 0.772569, Train Reconst: 0.010409, Train Pn: 0.013939, Train acc 0.770693, Valid Loss: 0.162622, Valid acc 0.645533, Best valid acc 0.661659, Time 00:03:41, lr 0.09239051340412144
# Epoch 53. Valid Loss EMA: -0.453664, Valid acc EMA 0.708233, Best valid acc EMA 0.661659, Time 00:03:41
# Epoch 54. Train Loss: -1.189128, Train Xent: 0.748551, Train Reconst: 0.010161, Train Pn: 0.013909, Train acc 0.777294, Valid Loss: -0.076441, Valid acc 0.662961, Best valid acc 0.662961, Time 00:03:42, lr 0.09104365557629712
# Epoch 54. Valid Loss EMA: -0.435812, Valid acc EMA 0.707933, Best valid acc EMA 0.662961, Time 00:03:42
# Epoch 55. Train Loss: -1.205120, Train Xent: 0.737924, Train Reconst: 0.010096, Train Pn: 0.013884, Train acc 0.779728, Valid Loss: 0.078082, Valid acc 0.660256, Best valid acc 0.662961, Time 00:03:41, lr 0.08971643208041376
# Epoch 55. Valid Loss EMA: -0.396985, Valid acc EMA 0.709335, Best valid acc EMA 0.662961, Time 00:03:41
# Epoch 56. Train Loss: -1.229228, Train Xent: 0.718159, Train Reconst: 0.010411, Train Pn: 0.013896, Train acc 0.782109, Valid Loss: 0.124316, Valid acc 0.657733, Best valid acc 0.662961, Time 00:03:42, lr 0.08840855668953425
# Epoch 56. Valid Loss EMA: -0.446461, Valid acc EMA 0.709335, Best valid acc EMA 0.662961, Time 00:03:42
# Epoch 57. Train Loss: -1.251718, Train Xent: 0.701016, Train Reconst: 0.010087, Train Pn: 0.013964, Train acc 0.789023, Valid Loss: 0.226463, Valid acc 0.660857, Best valid acc 0.662961, Time 00:03:42, lr 0.08711974734930347
# Epoch 57. Valid Loss EMA: -0.384099, Valid acc EMA 0.711739, Best valid acc EMA 0.662961, Time 00:03:42
# Epoch 58. Train Loss: -1.263966, Train Xent: 0.692617, Train Reconst: 0.009905, Train Pn: 0.013937, Train acc 0.789663, Valid Loss: -0.021121, Valid acc 0.662961, Best valid acc 0.662961, Time 00:03:41, lr 0.08584972611712087
# Epoch 58. Valid Loss EMA: -0.386168, Valid acc EMA 0.714643, Best valid acc EMA 0.662961, Time 00:03:41
# Epoch 59. Train Loss: -1.275029, Train Xent: 0.684051, Train Reconst: 0.010004, Train Pn: 0.013862, Train acc 0.794557, Valid Loss: -0.031022, Valid acc 0.671274, Best valid acc 0.671274, Time 00:03:42, lr 0.08459821910219979
# Epoch 59. Valid Loss EMA: -0.392621, Valid acc EMA 0.714243, Best valid acc EMA 0.671274, Time 00:03:42
# Epoch 60. Train Loss: -1.305358, Train Xent: 0.660723, Train Reconst: 0.009750, Train Pn: 0.013748, Train acc 0.799832, Valid Loss: -0.038498, Valid acc 0.665546, Best valid acc 0.671274, Time 00:03:41, lr 0.08336495640650066
# Epoch 60. Valid Loss EMA: -0.352765, Valid acc EMA 0.712740, Best valid acc EMA 0.671274, Time 00:03:41
# Epoch 61. Train Loss: -1.323874, Train Xent: 0.646003, Train Reconst: 0.009825, Train Pn: 0.013748, Train acc 0.804046, Valid Loss: 0.216848, Valid acc 0.665465, Best valid acc 0.671274, Time 00:03:41, lr 0.08214967206652513
# Epoch 61. Valid Loss EMA: -0.393420, Valid acc EMA 0.716346, Best valid acc EMA 0.671274, Time 00:03:41
# Epoch 62. Train Loss: -1.336205, Train Xent: 0.638022, Train Reconst: 0.009805, Train Pn: 0.013773, Train acc 0.805367, Valid Loss: 0.269552, Valid acc 0.646434, Best valid acc 0.671274, Time 00:03:41, lr 0.08095210399595887
# Epoch 62. Valid Loss EMA: -0.383701, Valid acc EMA 0.714042, Best valid acc EMA 0.671274, Time 00:03:41
# Epoch 63. Train Loss: -1.356480, Train Xent: 0.622858, Train Reconst: 0.009696, Train Pn: 0.013544, Train acc 0.810276, Valid Loss: 0.197370, Valid acc 0.655248, Best valid acc 0.671274, Time 00:03:41, lr 0.07977199392915042
# Epoch 63. Valid Loss EMA: -0.380776, Valid acc EMA 0.713942, Best valid acc EMA 0.671274, Time 00:03:41
# Epoch 64. Train Loss: -1.372847, Train Xent: 0.610133, Train Reconst: 0.009814, Train Pn: 0.013587, Train acc 0.813079, Valid Loss: 0.297428, Valid acc 0.674446, Best valid acc 0.674446, Time 00:03:42, lr 0.07860908736541401
# Epoch 64. Valid Loss EMA: -0.391343, Valid acc EMA 0.715345, Best valid acc EMA 0.674446, Time 00:03:42
# Epoch 65. Train Loss: -1.383564, Train Xent: 0.601162, Train Reconst: 0.009846, Train Pn: 0.013634, Train acc 0.814178, Valid Loss: -0.012066, Valid acc 0.663261, Best valid acc 0.674446, Time 00:03:42, lr 0.07746313351414437
# Epoch 65. Valid Loss EMA: -0.390803, Valid acc EMA 0.716246, Best valid acc EMA 0.674446, Time 00:03:42
# Epoch 66. Train Loss: -1.413196, Train Xent: 0.578629, Train Reconst: 0.009794, Train Pn: 0.013467, Train acc 0.821074, Valid Loss: 0.248266, Valid acc 0.658554, Best valid acc 0.674446, Time 00:03:41, lr 0.07633388524073158
# Epoch 66. Valid Loss EMA: -0.368651, Valid acc EMA 0.716546, Best valid acc EMA 0.674446, Time 00:03:41
# Epoch 67. Train Loss: -1.433707, Train Xent: 0.563907, Train Reconst: 0.009844, Train Pn: 0.013234, Train acc 0.825208, Valid Loss: 0.008283, Valid acc 0.665665, Best valid acc 0.674446, Time 00:03:42, lr 0.07522109901326446
# Epoch 67. Valid Loss EMA: -0.420166, Valid acc EMA 0.718650, Best valid acc EMA 0.674446, Time 00:03:42
# Epoch 68. Train Loss: -1.441379, Train Xent: 0.558187, Train Reconst: 0.009595, Train Pn: 0.013194, Train acc 0.826806, Valid Loss: 0.071916, Valid acc 0.665645, Best valid acc 0.674446, Time 00:03:41, lr 0.07412453485001083
# Epoch 68. Valid Loss EMA: -0.402060, Valid acc EMA 0.717949, Best valid acc EMA 0.674446, Time 00:03:41
# Epoch 69. Train Loss: -1.459516, Train Xent: 0.541821, Train Reconst: 0.009790, Train Pn: 0.013207, Train acc 0.830729, Valid Loss: -0.034338, Valid acc 0.670373, Best valid acc 0.674446, Time 00:03:41, lr 0.07304395626766344
# Epoch 69. Valid Loss EMA: -0.359351, Valid acc EMA 0.718249, Best valid acc EMA 0.674446, Time 00:03:41
# Epoch 70. Train Loss: -1.474918, Train Xent: 0.530504, Train Reconst: 0.009895, Train Pn: 0.013038, Train acc 0.833460, Valid Loss: 0.036958, Valid acc 0.679587, Best valid acc 0.679587, Time 00:03:42, lr 0.07197913023034032
# Epoch 70. Valid Loss EMA: -0.366679, Valid acc EMA 0.719651, Best valid acc EMA 0.679587, Time 00:03:42
# Epoch 71. Train Loss: -1.498143, Train Xent: 0.515263, Train Reconst: 0.009384, Train Pn: 0.012953, Train acc 0.838962, Valid Loss: 0.217747, Valid acc 0.657452, Best valid acc 0.679587, Time 00:03:41, lr 0.07092982709932866
# Epoch 71. Valid Loss EMA: -0.314544, Valid acc EMA 0.714543, Best valid acc EMA 0.679587, Time 00:03:41
# Epoch 72. Train Loss: -1.501771, Train Xent: 0.512319, Train Reconst: 0.009512, Train Pn: 0.013012, Train acc 0.840593, Valid Loss: 0.104219, Valid acc 0.670886, Best valid acc 0.679587, Time 00:03:42, lr 0.06989582058356127
# Epoch 72. Valid Loss EMA: -0.401287, Valid acc EMA 0.717849, Best valid acc EMA 0.679587, Time 00:03:42
# Epoch 73. Train Loss: -1.513544, Train Xent: 0.504510, Train Reconst: 0.009319, Train Pn: 0.012857, Train acc 0.843151, Valid Loss: 0.165467, Valid acc 0.663762, Best valid acc 0.679587, Time 00:03:42, lr 0.06887688769081501
# Epoch 73. Valid Loss EMA: -0.338372, Valid acc EMA 0.717348, Best valid acc EMA 0.679587, Time 00:03:42
# Epoch 74. Train Loss: -1.527608, Train Xent: 0.492691, Train Reconst: 0.009044, Train Pn: 0.012880, Train acc 0.844571, Valid Loss: -0.022381, Valid acc 0.672376, Best valid acc 0.679587, Time 00:03:41, lr 0.06787280867962064
# Epoch 74. Valid Loss EMA: -0.316975, Valid acc EMA 0.716146, Best valid acc EMA 0.679587, Time 00:03:41
# Epoch 75. Train Loss: -1.542707, Train Xent: 0.482457, Train Reconst: 0.009133, Train Pn: 0.012704, Train acc 0.849285, Valid Loss: 0.113852, Valid acc 0.677284, Best valid acc 0.679587, Time 00:03:42, lr 0.06688336701187371
# Epoch 75. Valid Loss EMA: -0.347779, Valid acc EMA 0.718650, Best valid acc EMA 0.679587, Time 00:03:42
# Epoch 76. Train Loss: -1.554474, Train Xent: 0.474906, Train Reconst: 0.009210, Train Pn: 0.012592, Train acc 0.852222, Valid Loss: 0.130742, Valid acc 0.669502, Best valid acc 0.679587, Time 00:03:42, lr 0.06590834930613629
# Epoch 76. Valid Loss EMA: -0.329556, Valid acc EMA 0.719852, Best valid acc EMA 0.679587, Time 00:03:42
# Epoch 77. Train Loss: -1.581808, Train Xent: 0.452704, Train Reconst: 0.009367, Train Pn: 0.012381, Train acc 0.859635, Valid Loss: 0.082311, Valid acc 0.667067, Best valid acc 0.679587, Time 00:03:42, lr 0.06494754529161949
# Epoch 77. Valid Loss EMA: -0.361345, Valid acc EMA 0.717248, Best valid acc EMA 0.679587, Time 00:03:42
# Epoch 78. Train Loss: -1.593775, Train Xent: 0.443255, Train Reconst: 0.009155, Train Pn: 0.012331, Train acc 0.858096, Valid Loss: -0.037496, Valid acc 0.680789, Best valid acc 0.680789, Time 00:03:42, lr 0.06400074776283673
# Epoch 78. Valid Loss EMA: -0.376949, Valid acc EMA 0.721054, Best valid acc EMA 0.680789, Time 00:03:42
# Epoch 79. Train Loss: -1.589960, Train Xent: 0.447683, Train Reconst: 0.008816, Train Pn: 0.012505, Train acc 0.858554, Valid Loss: -0.052766, Valid acc 0.682993, Best valid acc 0.682993, Time 00:03:41, lr 0.06306775253491823
# Epoch 79. Valid Loss EMA: -0.365834, Valid acc EMA 0.721454, Best valid acc EMA 0.682993, Time 00:03:41
# Epoch 80. Train Loss: -1.615263, Train Xent: 0.427340, Train Reconst: 0.008850, Train Pn: 0.012213, Train acc 0.864650, Valid Loss: 0.049230, Valid acc 0.684237, Best valid acc 0.684237, Time 00:03:43, lr 0.062148358399576706
# Epoch 80. Valid Loss EMA: -0.326701, Valid acc EMA 0.720853, Best valid acc EMA 0.684237, Time 00:03:43
# Epoch 81. Train Loss: -1.626931, Train Xent: 0.419201, Train Reconst: 0.008720, Train Pn: 0.012146, Train acc 0.864890, Valid Loss: 0.006958, Valid acc 0.671775, Best valid acc 0.684237, Time 00:03:43, lr 0.0612423670817152
# Epoch 81. Valid Loss EMA: -0.348409, Valid acc EMA 0.721855, Best valid acc EMA 0.684237, Time 00:03:43
# Epoch 82. Train Loss: -1.638132, Train Xent: 0.411209, Train Reconst: 0.008776, Train Pn: 0.012079, Train acc 0.870633, Valid Loss: 0.147250, Valid acc 0.686999, Best valid acc 0.686999, Time 00:03:42, lr 0.06034958319666734
# Epoch 82. Valid Loss EMA: -0.340953, Valid acc EMA 0.720753, Best valid acc EMA 0.686999, Time 00:03:42
# Epoch 83. Train Loss: -1.649838, Train Xent: 0.403408, Train Reconst: 0.008911, Train Pn: 0.012035, Train acc 0.872043, Valid Loss: -0.024987, Valid acc 0.682893, Best valid acc 0.686999, Time 00:03:42, lr 0.05946981420806098
# Epoch 83. Valid Loss EMA: -0.350573, Valid acc EMA 0.719752, Best valid acc EMA 0.686999, Time 00:03:42
# Epoch 84. Train Loss: -1.664233, Train Xent: 0.391484, Train Reconst: 0.008914, Train Pn: 0.011780, Train acc 0.874840, Valid Loss: -0.043651, Valid acc 0.684434, Best valid acc 0.686999, Time 00:03:42, lr 0.05860287038629614
# Epoch 84. Valid Loss EMA: -0.351579, Valid acc EMA 0.720553, Best valid acc EMA 0.686999, Time 00:03:42
# Epoch 85. Train Loss: -1.677798, Train Xent: 0.382665, Train Reconst: 0.008962, Train Pn: 0.011665, Train acc 0.876883, Valid Loss: 0.048635, Valid acc 0.683894, Best valid acc 0.686999, Time 00:03:41, lr 0.0577485647676282
# Epoch 85. Valid Loss EMA: -0.341408, Valid acc EMA 0.716847, Best valid acc EMA 0.686999, Time 00:03:41
# Epoch 86. Train Loss: -1.684489, Train Xent: 0.378199, Train Reconst: 0.008807, Train Pn: 0.011576, Train acc 0.879476, Valid Loss: 0.112889, Valid acc 0.674179, Best valid acc 0.686999, Time 00:03:42, lr 0.05690671311384759
# Epoch 86. Valid Loss EMA: -0.320830, Valid acc EMA 0.720753, Best valid acc EMA 0.686999, Time 00:03:42
# Epoch 87. Train Loss: -1.690197, Train Xent: 0.374297, Train Reconst: 0.008677, Train Pn: 0.011567, Train acc 0.880168, Valid Loss: 0.016739, Valid acc 0.683794, Best valid acc 0.686999, Time 00:03:41, lr 0.05607713387254727
# Epoch 87. Valid Loss EMA: -0.329279, Valid acc EMA 0.722055, Best valid acc EMA 0.686999, Time 00:03:41
# Epoch 88. Train Loss: -1.711394, Train Xent: 0.357985, Train Reconst: 0.008604, Train Pn: 0.011396, Train acc 0.885310, Valid Loss: 0.074522, Valid acc 0.679984, Best valid acc 0.686999, Time 00:03:42, lr 0.05525964813796943
# Epoch 88. Valid Loss EMA: -0.317365, Valid acc EMA 0.720954, Best valid acc EMA 0.686999, Time 00:03:42
# Epoch 89. Train Loss: -1.717504, Train Xent: 0.352569, Train Reconst: 0.008662, Train Pn: 0.011220, Train acc 0.886069, Valid Loss: 0.136833, Valid acc 0.678786, Best valid acc 0.686999, Time 00:03:42, lr 0.05445407961242294
# Epoch 89. Valid Loss EMA: -0.271899, Valid acc EMA 0.721254, Best valid acc EMA 0.686999, Time 00:03:42
# Epoch 90. Train Loss: -1.731026, Train Xent: 0.343032, Train Reconst: 0.008508, Train Pn: 0.011185, Train acc 0.889002, Valid Loss: 0.101058, Valid acc 0.683393, Best valid acc 0.686999, Time 00:03:42, lr 0.05366025456826328
# Epoch 90. Valid Loss EMA: -0.314157, Valid acc EMA 0.720753, Best valid acc EMA 0.686999, Time 00:03:42
# Epoch 91. Train Loss: -1.737089, Train Xent: 0.339721, Train Reconst: 0.008369, Train Pn: 0.011158, Train acc 0.889626, Valid Loss: -0.004783, Valid acc 0.689303, Best valid acc 0.689303, Time 00:03:42, lr 0.05287800181042671
# Epoch 91. Valid Loss EMA: -0.302848, Valid acc EMA 0.720453, Best valid acc EMA 0.689303, Time 00:03:42
# Epoch 92. Train Loss: -1.756628, Train Xent: 0.325885, Train Reconst: 0.008409, Train Pn: 0.010983, Train acc 0.894222, Valid Loss: 0.061882, Valid acc 0.691752, Best valid acc 0.691752, Time 00:03:42, lr 0.052107152639510594
# Epoch 92. Valid Loss EMA: -0.318850, Valid acc EMA 0.723057, Best valid acc EMA 0.691752, Time 00:03:42
# Epoch 93. Train Loss: -1.761674, Train Xent: 0.321402, Train Reconst: 0.008802, Train Pn: 0.010761, Train acc 0.898017, Valid Loss: -0.049947, Valid acc 0.691306, Best valid acc 0.691752, Time 00:03:42, lr 0.051347540815391966
# Epoch 93. Valid Loss EMA: -0.306326, Valid acc EMA 0.722857, Best valid acc EMA 0.691752, Time 00:03:42
# Epoch 94. Train Loss: -1.773839, Train Xent: 0.312488, Train Reconst: 0.008572, Train Pn: 0.010761, Train acc 0.898278, Valid Loss: 0.020032, Valid acc 0.690405, Best valid acc 0.691752, Time 00:03:42, lr 0.050599002521376446
# Epoch 94. Valid Loss EMA: -0.274986, Valid acc EMA 0.721054, Best valid acc EMA 0.691752, Time 00:03:42
# Epoch 95. Train Loss: -1.777233, Train Xent: 0.310999, Train Reconst: 0.008392, Train Pn: 0.010635, Train acc 0.899239, Valid Loss: 0.039548, Valid acc 0.683994, Best valid acc 0.691752, Time 00:03:42, lr 0.049861376328869784
# Epoch 95. Valid Loss EMA: -0.283722, Valid acc EMA 0.721755, Best valid acc EMA 0.691752, Time 00:03:42
# Epoch 96. Train Loss: -1.787970, Train Xent: 0.303300, Train Reconst: 0.008509, Train Pn: 0.010617, Train acc 0.901914, Valid Loss: 0.065208, Valid acc 0.686709, Best valid acc 0.691752, Time 00:03:42, lr 0.049134503162564416
# Epoch 96. Valid Loss EMA: -0.292050, Valid acc EMA 0.721755, Best valid acc EMA 0.691752, Time 00:03:42
# Epoch 97. Train Loss: -1.787941, Train Xent: 0.303657, Train Reconst: 0.008031, Train Pn: 0.010555, Train acc 0.901275, Valid Loss: 0.201968, Valid acc 0.678586, Best valid acc 0.691752, Time 00:03:42, lr 0.048418226266133554
# Epoch 97. Valid Loss EMA: -0.266799, Valid acc EMA 0.721154, Best valid acc EMA 0.691752, Time 00:03:42
# Epoch 98. Train Loss: -1.815172, Train Xent: 0.284126, Train Reconst: 0.007988, Train Pn: 0.010230, Train acc 0.907893, Valid Loss: 0.230514, Valid acc 0.671575, Best valid acc 0.691752, Time 00:03:41, lr 0.047712391168425336
# Epoch 98. Valid Loss EMA: -0.275146, Valid acc EMA 0.720052, Best valid acc EMA 0.691752, Time 00:03:41
# Epoch 99. Train Loss: -1.830910, Train Xent: 0.271328, Train Reconst: 0.008445, Train Pn: 0.010100, Train acc 0.911845, Valid Loss: 0.010060, Valid acc 0.690204, Best valid acc 0.691752, Time 00:03:42, lr 0.04701684565014984
# Epoch 99. Valid Loss EMA: -0.277624, Valid acc EMA 0.723057, Best valid acc EMA 0.691752, Time 00:03:42
# Epoch 100. Train Loss: -1.828105, Train Xent: 0.274345, Train Reconst: 0.008567, Train Pn: 0.010199, Train acc 0.911265, Valid Loss: 0.119340, Valid acc 0.690763, Best valid acc 0.691752, Time 00:03:42, lr 0.04633143971105169
# Epoch 100. Valid Loss EMA: -0.293378, Valid acc EMA 0.723458, Best valid acc EMA 0.691752, Time 00:03:42
# Epoch 101. Train Loss: -1.837451, Train Xent: 0.267469, Train Reconst: 0.008351, Train Pn: 0.010062, Train acc 0.912720, Valid Loss: 0.014878, Valid acc 0.687500, Best valid acc 0.691752, Time 00:03:42, lr 0.045656025537561276
# Epoch 101. Valid Loss EMA: -0.273057, Valid acc EMA 0.725060, Best valid acc EMA 0.691752, Time 00:03:42
# Epoch 102. Train Loss: -1.843909, Train Xent: 0.263032, Train Reconst: 0.008149, Train Pn: 0.009869, Train acc 0.914722, Valid Loss: 0.035415, Valid acc 0.690304, Best valid acc 0.691752, Time 00:03:42, lr 0.044990457470917455
# Epoch 102. Valid Loss EMA: -0.278990, Valid acc EMA 0.727564, Best valid acc EMA 0.691752, Time 00:03:42
# Epoch 103. Train Loss: -1.853309, Train Xent: 0.256779, Train Reconst: 0.008149, Train Pn: 0.009675, Train acc 0.918089, Valid Loss: 0.060410, Valid acc 0.696214, Best valid acc 0.696214, Time 00:03:41, lr 0.04433459197575506
# Epoch 103. Valid Loss EMA: -0.293491, Valid acc EMA 0.729167, Best valid acc EMA 0.696214, Time 00:03:41
# Epoch 104. Train Loss: -1.864556, Train Xent: 0.248625, Train Reconst: 0.008276, Train Pn: 0.009577, Train acc 0.919417, Valid Loss: 0.203237, Valid acc 0.682654, Best valid acc 0.696214, Time 00:03:42, lr 0.043688287609150264
# Epoch 104. Valid Loss EMA: -0.307391, Valid acc EMA 0.730769, Best valid acc EMA 0.696214, Time 00:03:42
# Epoch 105. Train Loss: -1.861711, Train Xent: 0.251577, Train Reconst: 0.008163, Train Pn: 0.009664, Train acc 0.919537, Valid Loss: 0.167138, Valid acc 0.686498, Best valid acc 0.696214, Time 00:03:43, lr 0.043051404990117226
# Epoch 105. Valid Loss EMA: -0.327125, Valid acc EMA 0.732672, Best valid acc EMA 0.696214, Time 00:03:43
# Epoch 106. Train Loss: -1.877819, Train Xent: 0.238283, Train Reconst: 0.008290, Train Pn: 0.009374, Train acc 0.923438, Valid Loss: 0.061060, Valid acc 0.689103, Best valid acc 0.696214, Time 00:03:41, lr 0.042423806769549405
# Epoch 106. Valid Loss EMA: -0.335899, Valid acc EMA 0.731170, Best valid acc EMA 0.696214, Time 00:03:41
# Epoch 107. Train Loss: -1.894337, Train Xent: 0.227983, Train Reconst: 0.008127, Train Pn: 0.009257, Train acc 0.925671, Valid Loss: 0.048193, Valid acc 0.690905, Best valid acc 0.696214, Time 00:03:42, lr 0.04180535760059907
# Epoch 107. Valid Loss EMA: -0.324537, Valid acc EMA 0.731470, Best valid acc EMA 0.696214, Time 00:03:42
# Epoch 108. Train Loss: -1.897730, Train Xent: 0.226172, Train Reconst: 0.007853, Train Pn: 0.009140, Train acc 0.925212, Valid Loss: 0.112265, Valid acc 0.690368, Best valid acc 0.696214, Time 00:03:42, lr 0.041195924109488614
# Epoch 108. Valid Loss EMA: -0.329283, Valid acc EMA 0.729968, Best valid acc EMA 0.696214, Time 00:03:42
# Epoch 109. Train Loss: -1.902114, Train Xent: 0.222728, Train Reconst: 0.007977, Train Pn: 0.008985, Train acc 0.927584, Valid Loss: 0.021674, Valid acc 0.697015, Best valid acc 0.697015, Time 00:03:41, lr 0.04059537486674736
# Epoch 109. Valid Loss EMA: -0.349518, Valid acc EMA 0.735176, Best valid acc EMA 0.697015, Time 00:03:41
# Epoch 110. Train Loss: -1.904056, Train Xent: 0.221498, Train Reconst: 0.008010, Train Pn: 0.008952, Train acc 0.927410, Valid Loss: 0.093148, Valid acc 0.694511, Best valid acc 0.697015, Time 00:03:42, lr 0.040003580358867696
# Epoch 110. Valid Loss EMA: -0.330840, Valid acc EMA 0.733373, Best valid acc EMA 0.697015, Time 00:03:42
# Epoch 111. Train Loss: -1.919588, Train Xent: 0.210886, Train Reconst: 0.008017, Train Pn: 0.008853, Train acc 0.930088, Valid Loss: 0.067158, Valid acc 0.697115, Best valid acc 0.697115, Time 00:03:41, lr 0.03942041296037442
# Epoch 111. Valid Loss EMA: -0.318075, Valid acc EMA 0.733674, Best valid acc EMA 0.697115, Time 00:03:41
# Epoch 112. Train Loss: -1.926970, Train Xent: 0.204771, Train Reconst: 0.008190, Train Pn: 0.008679, Train acc 0.931985, Valid Loss: 0.043951, Valid acc 0.697884, Best valid acc 0.697884, Time 00:03:42, lr 0.03884574690630118
# Epoch 112. Valid Loss EMA: -0.330507, Valid acc EMA 0.732372, Best valid acc EMA 0.697884, Time 00:03:42
# Epoch 113. Train Loss: -1.930267, Train Xent: 0.204219, Train Reconst: 0.008093, Train Pn: 0.008616, Train acc 0.934203, Valid Loss: -0.007932, Valid acc 0.699419, Best valid acc 0.699419, Time 00:03:42, lr 0.03827945826506824
# Epoch 113. Valid Loss EMA: -0.314520, Valid acc EMA 0.733273, Best valid acc EMA 0.699419, Time 00:03:42
# Epoch 114. Train Loss: -1.938138, Train Xent: 0.197759, Train Reconst: 0.008137, Train Pn: 0.008516, Train acc 0.934395, Valid Loss: -0.010732, Valid acc 0.698518, Best valid acc 0.699419, Time 00:03:42, lr 0.03772142491175557
# Epoch 114. Valid Loss EMA: -0.319523, Valid acc EMA 0.734675, Best valid acc EMA 0.699419, Time 00:03:42
# Epoch 115. Train Loss: -1.945319, Train Xent: 0.193728, Train Reconst: 0.008065, Train Pn: 0.008329, Train acc 0.936501, Valid Loss: -0.090545, Valid acc 0.700821, Best valid acc 0.700821, Time 00:03:42, lr 0.037171526501765584
# Epoch 115. Valid Loss EMA: -0.331780, Valid acc EMA 0.733574, Best valid acc EMA 0.700821, Time 00:03:42
# Epoch 116. Train Loss: -1.953444, Train Xent: 0.188092, Train Reconst: 0.007970, Train Pn: 0.008252, Train acc 0.938439, Valid Loss: -0.057159, Valid acc 0.693829, Best valid acc 0.700821, Time 00:03:42, lr 0.03662964444486981
# Epoch 116. Valid Loss EMA: -0.318278, Valid acc EMA 0.733073, Best valid acc EMA 0.700821, Time 00:03:42
# Epoch 117. Train Loss: -1.956628, Train Xent: 0.186662, Train Reconst: 0.008018, Train Pn: 0.008185, Train acc 0.937380, Valid Loss: 0.031333, Valid acc 0.697015, Best valid acc 0.700821, Time 00:03:41, lr 0.036095661879633915
# Epoch 117. Valid Loss EMA: -0.300387, Valid acc EMA 0.731871, Best valid acc EMA 0.700821, Time 00:03:41
# Epoch 118. Train Loss: -1.964661, Train Xent: 0.180029, Train Reconst: 0.007829, Train Pn: 0.008082, Train acc 0.941956, Valid Loss: 0.013130, Valid acc 0.694611, Best valid acc 0.700821, Time 00:03:42, lr 0.03556946364821554
# Epoch 118. Valid Loss EMA: -0.308251, Valid acc EMA 0.732372, Best valid acc EMA 0.700821, Time 00:03:42
# Epoch 119. Train Loss: -1.973729, Train Xent: 0.174296, Train Reconst: 0.007784, Train Pn: 0.007930, Train acc 0.943850, Valid Loss: 0.072771, Valid acc 0.702925, Best valid acc 0.702925, Time 00:03:41, lr 0.03505093627152955
# Epoch 119. Valid Loss EMA: -0.293660, Valid acc EMA 0.733073, Best valid acc EMA 0.702925, Time 00:03:41
# Epoch 120. Train Loss: -1.975240, Train Xent: 0.175152, Train Reconst: 0.007956, Train Pn: 0.007955, Train acc 0.944613, Valid Loss: 0.003195, Valid acc 0.704411, Best valid acc 0.704411, Time 00:03:42, lr 0.034539967924775296
# Epoch 120. Valid Loss EMA: -0.305422, Valid acc EMA 0.734475, Best valid acc EMA 0.704411, Time 00:03:42
# Epoch 121. Train Loss: -1.986323, Train Xent: 0.165948, Train Reconst: 0.007526, Train Pn: 0.007737, Train acc 0.946651, Valid Loss: 0.005367, Valid acc 0.694211, Best valid acc 0.704411, Time 00:03:43, lr 0.03403644841332068
# Epoch 121. Valid Loss EMA: -0.299914, Valid acc EMA 0.732973, Best valid acc EMA 0.704411, Time 00:03:43
# Epoch 122. Train Loss: -1.987551, Train Xent: 0.165945, Train Reconst: 0.007745, Train Pn: 0.007645, Train acc 0.946975, Valid Loss: -0.033910, Valid acc 0.703826, Best valid acc 0.704411, Time 00:03:41, lr 0.033540269148937735
# Epoch 122. Valid Loss EMA: -0.291510, Valid acc EMA 0.734776, Best valid acc EMA 0.704411, Time 00:03:41
# Epoch 123. Train Loss: -1.998786, Train Xent: 0.158310, Train Reconst: 0.007552, Train Pn: 0.007457, Train acc 0.948270, Valid Loss: 0.074712, Valid acc 0.698417, Best valid acc 0.704411, Time 00:03:42, lr 0.03305132312638467
# Epoch 123. Valid Loss EMA: -0.282311, Valid acc EMA 0.734275, Best valid acc EMA 0.704411, Time 00:03:42
# Epoch 124. Train Loss: -2.001876, Train Xent: 0.155764, Train Reconst: 0.007710, Train Pn: 0.007392, Train acc 0.949728, Valid Loss: 0.004114, Valid acc 0.706685, Best valid acc 0.706685, Time 00:03:42, lr 0.03256950490032926
# Epoch 124. Valid Loss EMA: -0.266017, Valid acc EMA 0.735377, Best valid acc EMA 0.706685, Time 00:03:42
# Epoch 125. Train Loss: -2.001002, Train Xent: 0.157805, Train Reconst: 0.007800, Train Pn: 0.007313, Train acc 0.949700, Valid Loss: -0.036867, Valid acc 0.707732, Best valid acc 0.707732, Time 00:03:41, lr 0.03209471056260872
# Epoch 125. Valid Loss EMA: -0.285166, Valid acc EMA 0.734275, Best valid acc EMA 0.707732, Time 00:03:41
# Epoch 126. Train Loss: -2.007791, Train Xent: 0.153100, Train Reconst: 0.007666, Train Pn: 0.007227, Train acc 0.950807, Valid Loss: 0.004661, Valid acc 0.698618, Best valid acc 0.707732, Time 00:03:42, lr 0.03162683771982098
# Epoch 126. Valid Loss EMA: -0.305684, Valid acc EMA 0.731871, Best valid acc EMA 0.707732, Time 00:03:42
# Epoch 127. Train Loss: -2.015961, Train Xent: 0.147320, Train Reconst: 0.007482, Train Pn: 0.007073, Train acc 0.951803, Valid Loss: 0.021785, Valid acc 0.701623, Best valid acc 0.707732, Time 00:03:41, lr 0.031165785471242716
# Epoch 127. Valid Loss EMA: -0.274331, Valid acc EMA 0.733073, Best valid acc EMA 0.707732, Time 00:03:41
# Epoch 128. Train Loss: -2.020015, Train Xent: 0.144180, Train Reconst: 0.007526, Train Pn: 0.007028, Train acc 0.954584, Valid Loss: 0.054572, Valid acc 0.705597, Best valid acc 0.707732, Time 00:03:42, lr 0.030711454387069265
# Epoch 128. Valid Loss EMA: -0.268258, Valid acc EMA 0.732973, Best valid acc EMA 0.707732, Time 00:03:42
# Epoch 129. Train Loss: -2.031868, Train Xent: 0.137310, Train Reconst: 0.007508, Train Pn: 0.006792, Train acc 0.955982, Valid Loss: 0.041249, Valid acc 0.699119, Best valid acc 0.707732, Time 00:03:42, lr 0.030263746486971718
# Epoch 129. Valid Loss EMA: -0.287389, Valid acc EMA 0.733874, Best valid acc EMA 0.707732, Time 00:03:42
# Epoch 130. Train Loss: -2.035401, Train Xent: 0.134785, Train Reconst: 0.007505, Train Pn: 0.006724, Train acc 0.956410, Valid Loss: 0.016988, Valid acc 0.703726, Best valid acc 0.707732, Time 00:03:41, lr 0.029822565218966663
# Epoch 130. Valid Loss EMA: -0.275447, Valid acc EMA 0.732772, Best valid acc EMA 0.707732, Time 00:03:41
# Epoch 131. Train Loss: -2.032254, Train Xent: 0.136156, Train Reconst: 0.007458, Train Pn: 0.006729, Train acc 0.956861, Valid Loss: 0.027916, Valid acc 0.705729, Best valid acc 0.707732, Time 00:03:42, lr 0.029387815438593926
# Epoch 131. Valid Loss EMA: -0.253661, Valid acc EMA 0.733974, Best valid acc EMA 0.707732, Time 00:03:42
# Epoch 132. Train Loss: -2.042170, Train Xent: 0.130542, Train Reconst: 0.007235, Train Pn: 0.006573, Train acc 0.958460, Valid Loss: 0.078904, Valid acc 0.706388, Best valid acc 0.707732, Time 00:03:42, lr 0.028959403388397864
# Epoch 132. Valid Loss EMA: -0.277294, Valid acc EMA 0.733073, Best valid acc EMA 0.707732, Time 00:03:42
# Epoch 133. Train Loss: -2.047700, Train Xent: 0.126266, Train Reconst: 0.007532, Train Pn: 0.006434, Train acc 0.959896, Valid Loss: -0.019772, Valid acc 0.711238, Best valid acc 0.711238, Time 00:03:41, lr 0.028537236677707786
# Epoch 133. Valid Loss EMA: -0.274899, Valid acc EMA 0.734776, Best valid acc EMA 0.711238, Time 00:03:41
# Epoch 134. Train Loss: -2.055030, Train Xent: 0.121835, Train Reconst: 0.007055, Train Pn: 0.006334, Train acc 0.961857, Valid Loss: 0.053121, Valid acc 0.698117, Best valid acc 0.711238, Time 00:03:42, lr 0.02812122426271312
# Epoch 134. Valid Loss EMA: -0.278226, Valid acc EMA 0.735777, Best valid acc EMA 0.711238, Time 00:03:42
# Epoch 135. Train Loss: -2.058616, Train Xent: 0.120632, Train Reconst: 0.007253, Train Pn: 0.006251, Train acc 0.962099, Valid Loss: 0.045357, Valid acc 0.704127, Best valid acc 0.711238, Time 00:03:43, lr 0.027711276426829044
# Epoch 135. Valid Loss EMA: -0.284770, Valid acc EMA 0.735076, Best valid acc EMA 0.711238, Time 00:03:43
# Epoch 136. Train Loss: -2.060752, Train Xent: 0.118032, Train Reconst: 0.007275, Train Pn: 0.006203, Train acc 0.963195, Valid Loss: 0.015049, Valid acc 0.709355, Best valid acc 0.711238, Time 00:03:42, lr 0.027307304761348364
# Epoch 136. Valid Loss EMA: -0.279989, Valid acc EMA 0.732171, Best valid acc EMA 0.711238, Time 00:03:42
# Epoch 137. Train Loss: -2.068262, Train Xent: 0.114037, Train Reconst: 0.007208, Train Pn: 0.006056, Train acc 0.964454, Valid Loss: 0.010432, Valid acc 0.704627, Best valid acc 0.711238, Time 00:03:42, lr 0.026909222146375412
# Epoch 137. Valid Loss EMA: -0.265023, Valid acc EMA 0.735076, Best valid acc EMA 0.711238, Time 00:03:42
# Epoch 138. Train Loss: -2.072126, Train Xent: 0.111438, Train Reconst: 0.007131, Train Pn: 0.005960, Train acc 0.965525, Valid Loss: -0.023421, Valid acc 0.707432, Best valid acc 0.711238, Time 00:03:42, lr 0.026516942732037918
# Epoch 138. Valid Loss EMA: -0.243069, Valid acc EMA 0.734876, Best valid acc EMA 0.711238, Time 00:03:42
# Epoch 139. Train Loss: -2.077769, Train Xent: 0.108160, Train Reconst: 0.007303, Train Pn: 0.005824, Train acc 0.965833, Valid Loss: 0.063865, Valid acc 0.711238, Best valid acc 0.711238, Time 00:03:42, lr 0.02613038191997276
# Epoch 139. Valid Loss EMA: -0.262392, Valid acc EMA 0.734876, Best valid acc EMA 0.711238, Time 00:03:42
# Epoch 140. Train Loss: -2.072516, Train Xent: 0.110919, Train Reconst: 0.007256, Train Pn: 0.005835, Train acc 0.965014, Valid Loss: -0.007332, Valid acc 0.710641, Best valid acc 0.711238, Time 00:03:42, lr 0.025749456345081603
# Epoch 140. Valid Loss EMA: -0.246124, Valid acc EMA 0.733774, Best valid acc EMA 0.711238, Time 00:03:42
# Epoch 141. Train Loss: -2.078663, Train Xent: 0.108055, Train Reconst: 0.007360, Train Pn: 0.005691, Train acc 0.966406, Valid Loss: -0.043478, Valid acc 0.713241, Best valid acc 0.713241, Time 00:03:42, lr 0.025374083857552528
# Epoch 141. Valid Loss EMA: -0.251797, Valid acc EMA 0.733774, Best valid acc EMA 0.713241, Time 00:03:42
# Epoch 142. Train Loss: -2.085265, Train Xent: 0.103614, Train Reconst: 0.007028, Train Pn: 0.005628, Train acc 0.968171, Valid Loss: -0.035519, Valid acc 0.706731, Best valid acc 0.713241, Time 00:03:42, lr 0.02500418350514372
# Epoch 142. Valid Loss EMA: -0.234741, Valid acc EMA 0.733373, Best valid acc EMA 0.713241, Time 00:03:42
# Epoch 143. Train Loss: -2.082336, Train Xent: 0.105948, Train Reconst: 0.007117, Train Pn: 0.005625, Train acc 0.968429, Valid Loss: 0.015599, Valid acc 0.704527, Best valid acc 0.713241, Time 00:03:42, lr 0.024639675515725448
# Epoch 143. Valid Loss EMA: -0.238305, Valid acc EMA 0.732772, Best valid acc EMA 0.713241, Time 00:03:42
# Epoch 144. Train Loss: -2.086639, Train Xent: 0.102907, Train Reconst: 0.007210, Train Pn: 0.005490, Train acc 0.968151, Valid Loss: -0.033353, Valid acc 0.709256, Best valid acc 0.713241, Time 00:03:42, lr 0.024280481280076517
# Epoch 144. Valid Loss EMA: -0.241286, Valid acc EMA 0.732772, Best valid acc EMA 0.713241, Time 00:03:42
# Epoch 145. Train Loss: -2.099958, Train Xent: 0.093852, Train Reconst: 0.007186, Train Pn: 0.005322, Train acc 0.971427, Valid Loss: -0.013268, Valid acc 0.708033, Best valid acc 0.713241, Time 00:03:42, lr 0.023926523334931536
# Epoch 145. Valid Loss EMA: -0.253783, Valid acc EMA 0.733974, Best valid acc EMA 0.713241, Time 00:03:42
# Epoch 146. Train Loss: -2.098097, Train Xent: 0.095718, Train Reconst: 0.007005, Train Pn: 0.005225, Train acc 0.970292, Valid Loss: -0.019022, Valid acc 0.710337, Best valid acc 0.713241, Time 00:03:41, lr 0.02357772534627531
# Epoch 146. Valid Loss EMA: -0.237899, Valid acc EMA 0.733974, Best valid acc EMA 0.713241, Time 00:03:41
# Epoch 147. Train Loss: -2.103125, Train Xent: 0.092713, Train Reconst: 0.006952, Train Pn: 0.005172, Train acc 0.972027, Valid Loss: -0.021409, Valid acc 0.713542, Best valid acc 0.713542, Time 00:03:42, lr 0.02323401209288077
# Epoch 147. Valid Loss EMA: -0.232408, Valid acc EMA 0.732272, Best valid acc EMA 0.713542, Time 00:03:42
# Epoch 148. Train Loss: -2.105981, Train Xent: 0.090423, Train Reconst: 0.006874, Train Pn: 0.005154, Train acc 0.972566, Valid Loss: -0.015958, Valid acc 0.710641, Best valid acc 0.713542, Time 00:03:42, lr 0.02289530945008687
# Epoch 148. Valid Loss EMA: -0.233860, Valid acc EMA 0.731170, Best valid acc EMA 0.713542, Time 00:03:42
# Epoch 149. Train Loss: -2.106876, Train Xent: 0.090240, Train Reconst: 0.006989, Train Pn: 0.004986, Train acc 0.973518, Valid Loss: -0.044276, Valid acc 0.711438, Best valid acc 0.713542, Time 00:03:41, lr 0.02256154437381299
# Epoch 149. Valid Loss EMA: -0.233831, Valid acc EMA 0.732372, Best valid acc EMA 0.713542, Time 00:03:41
# Epoch 150. Train Loss: -2.113376, Train Xent: 0.086950, Train Reconst: 0.006990, Train Pn: 0.004843, Train acc 0.974045, Valid Loss: -0.049181, Valid acc 0.712640, Best valid acc 0.713542, Time 00:03:42, lr 0.022232644884806363
# Epoch 150. Valid Loss EMA: -0.239367, Valid acc EMA 0.731170, Best valid acc EMA 0.713542, Time 00:03:42
# Epoch 151. Train Loss: -2.116072, Train Xent: 0.084959, Train Reconst: 0.007080, Train Pn: 0.004856, Train acc 0.974599, Valid Loss: -0.030383, Valid acc 0.709435, Best valid acc 0.713542, Time 00:03:42, lr 0.02190854005311913
# Epoch 151. Valid Loss EMA: -0.245136, Valid acc EMA 0.731871, Best valid acc EMA 0.713542, Time 00:03:42
# Epoch 152. Train Loss: -2.121771, Train Xent: 0.081305, Train Reconst: 0.006834, Train Pn: 0.004654, Train acc 0.976083, Valid Loss: -0.019720, Valid acc 0.715783, Best valid acc 0.715783, Time 00:03:42, lr 0.02158915998281172
# Epoch 152. Valid Loss EMA: -0.235511, Valid acc EMA 0.732772, Best valid acc EMA 0.715783, Time 00:03:42
# Epoch 153. Train Loss: -2.118705, Train Xent: 0.083980, Train Reconst: 0.006828, Train Pn: 0.004730, Train acc 0.975044, Valid Loss: -0.053053, Valid acc 0.712841, Best valid acc 0.715783, Time 00:03:43, lr 0.021274435796879182
# Epoch 153. Valid Loss EMA: -0.250481, Valid acc EMA 0.732873, Best valid acc EMA 0.715783, Time 00:03:43
# Epoch 154. Train Loss: -2.124080, Train Xent: 0.079931, Train Reconst: 0.007044, Train Pn: 0.004581, Train acc 0.976282, Valid Loss: -0.051578, Valid acc 0.719251, Best valid acc 0.719251, Time 00:03:41, lr 0.020964299622397285
# Epoch 154. Valid Loss EMA: -0.226489, Valid acc EMA 0.733273, Best valid acc EMA 0.719251, Time 00:03:41
# Epoch 155. Train Loss: -2.124080, Train Xent: 0.080095, Train Reconst: 0.006927, Train Pn: 0.004543, Train acc 0.976543, Valid Loss: -0.031907, Valid acc 0.713341, Best valid acc 0.719251, Time 00:03:42, lr 0.020658684575885156
# Epoch 155. Valid Loss EMA: -0.221152, Valid acc EMA 0.733874, Best valid acc EMA 0.719251, Time 00:03:42
# Epoch 156. Train Loss: -2.130244, Train Xent: 0.076167, Train Reconst: 0.006993, Train Pn: 0.004437, Train acc 0.977781, Valid Loss: -0.005356, Valid acc 0.713509, Best valid acc 0.719251, Time 00:03:42, lr 0.020357524748881282
# Epoch 156. Valid Loss EMA: -0.186246, Valid acc EMA 0.731871, Best valid acc EMA 0.719251, Time 00:03:42
# Epoch 157. Train Loss: -2.129901, Train Xent: 0.076442, Train Reconst: 0.006991, Train Pn: 0.004458, Train acc 0.978005, Valid Loss: -0.017266, Valid acc 0.708734, Best valid acc 0.719251, Time 00:03:42, lr 0.020060755193729803
# Epoch 157. Valid Loss EMA: -0.225469, Valid acc EMA 0.731871, Best valid acc EMA 0.719251, Time 00:03:42
# Epoch 158. Train Loss: -2.133319, Train Xent: 0.075051, Train Reconst: 0.006875, Train Pn: 0.004380, Train acc 0.977602, Valid Loss: -0.060799, Valid acc 0.712640, Best valid acc 0.719251, Time 00:03:42, lr 0.019768311909573996
# Epoch 158. Valid Loss EMA: -0.220113, Valid acc EMA 0.730669, Best valid acc EMA 0.719251, Time 00:03:42
# Epoch 159. Train Loss: -2.138413, Train Xent: 0.071835, Train Reconst: 0.006942, Train Pn: 0.004230, Train acc 0.979828, Valid Loss: -0.068474, Valid acc 0.715244, Best valid acc 0.719251, Time 00:03:42, lr 0.019480131828553963
# Epoch 159. Valid Loss EMA: -0.232917, Valid acc EMA 0.731971, Best valid acc EMA 0.719251, Time 00:03:42
# Epoch 160. Train Loss: -2.138396, Train Xent: 0.071564, Train Reconst: 0.006950, Train Pn: 0.004201, Train acc 0.978980, Valid Loss: -0.037302, Valid acc 0.711630, Best valid acc 0.719251, Time 00:03:42, lr 0.019196152802205494
# Epoch 160. Valid Loss EMA: -0.231508, Valid acc EMA 0.729667, Best valid acc EMA 0.719251, Time 00:03:42
# Epoch 161. Train Loss: -2.140593, Train Xent: 0.070247, Train Reconst: 0.006978, Train Pn: 0.004153, Train acc 0.980099, Valid Loss: -0.099036, Valid acc 0.717949, Best valid acc 0.719251, Time 00:03:43, lr 0.01891631358805725
# Epoch 161. Valid Loss EMA: -0.232894, Valid acc EMA 0.728265, Best valid acc EMA 0.719251, Time 00:03:43
# Epoch 162. Train Loss: -2.140921, Train Xent: 0.070390, Train Reconst: 0.007039, Train Pn: 0.004076, Train acc 0.979046, Valid Loss: -0.058751, Valid acc 0.715244, Best valid acc 0.719251, Time 00:03:42, lr 0.018640553836423292
# Epoch 162. Valid Loss EMA: -0.228939, Valid acc EMA 0.729467, Best valid acc EMA 0.719251, Time 00:03:42
# Epoch 163. Train Loss: -2.146429, Train Xent: 0.066744, Train Reconst: 0.006947, Train Pn: 0.003927, Train acc 0.981158, Valid Loss: -0.077332, Valid acc 0.715445, Best valid acc 0.719251, Time 00:03:43, lr 0.01836881407738817
# Epoch 163. Valid Loss EMA: -0.222938, Valid acc EMA 0.732071, Best valid acc EMA 0.719251, Time 00:03:43
# Epoch 164. Train Loss: -2.149927, Train Xent: 0.064912, Train Reconst: 0.006903, Train Pn: 0.003874, Train acc 0.981318, Valid Loss: -0.045576, Valid acc 0.712718, Best valid acc 0.719251, Time 00:03:43, lr 0.018101035707981727
# Epoch 164. Valid Loss EMA: -0.219738, Valid acc EMA 0.731470, Best valid acc EMA 0.719251, Time 00:03:43
# Epoch 165. Train Loss: -2.151080, Train Xent: 0.064390, Train Reconst: 0.006775, Train Pn: 0.003910, Train acc 0.981831, Valid Loss: -0.059003, Valid acc 0.713542, Best valid acc 0.719251, Time 00:03:42, lr 0.017837160979540884
# Epoch 165. Valid Loss EMA: -0.233921, Valid acc EMA 0.732472, Best valid acc EMA 0.719251, Time 00:03:42
# Epoch 166. Train Loss: -2.148316, Train Xent: 0.066252, Train Reconst: 0.007058, Train Pn: 0.003860, Train acc 0.981638, Valid Loss: -0.026157, Valid acc 0.713241, Best valid acc 0.719251, Time 00:03:42, lr 0.017577132985255647
# Epoch 166. Valid Loss EMA: -0.214868, Valid acc EMA 0.731470, Best valid acc EMA 0.719251, Time 00:03:42
# Epoch 167. Train Loss: -2.153655, Train Xent: 0.062774, Train Reconst: 0.007076, Train Pn: 0.003783, Train acc 0.982352, Valid Loss: -0.033142, Valid acc 0.715545, Best valid acc 0.719251, Time 00:03:41, lr 0.017320895647896673
# Epoch 167. Valid Loss EMA: -0.222320, Valid acc EMA 0.732472, Best valid acc EMA 0.719251, Time 00:03:41
# Epoch 168. Train Loss: -2.156122, Train Xent: 0.061858, Train Reconst: 0.007246, Train Pn: 0.003712, Train acc 0.982816, Valid Loss: -0.056064, Valid acc 0.714201, Best valid acc 0.719251, Time 00:03:42, lr 0.017068393707721754
# Epoch 168. Valid Loss EMA: -0.223380, Valid acc EMA 0.730970, Best valid acc EMA 0.719251, Time 00:03:42
# Epoch 169. Train Loss: -2.156952, Train Xent: 0.061066, Train Reconst: 0.007026, Train Pn: 0.003587, Train acc 0.982717, Valid Loss: -0.081871, Valid acc 0.714744, Best valid acc 0.719251, Time 00:03:42, lr 0.016819572710558568
# Epoch 169. Valid Loss EMA: -0.209198, Valid acc EMA 0.731070, Best valid acc EMA 0.719251, Time 00:03:42
# Epoch 170. Train Loss: -2.158584, Train Xent: 0.060022, Train Reconst: 0.006833, Train Pn: 0.003597, Train acc 0.983934, Valid Loss: -0.072924, Valid acc 0.716346, Best valid acc 0.719251, Time 00:03:41, lr 0.016574378996061193
# Epoch 170. Valid Loss EMA: -0.221381, Valid acc EMA 0.732472, Best valid acc EMA 0.719251, Time 00:03:41
# Epoch 171. Train Loss: -2.161395, Train Xent: 0.058378, Train Reconst: 0.006615, Train Pn: 0.003546, Train acc 0.984255, Valid Loss: -0.079990, Valid acc 0.719752, Best valid acc 0.719752, Time 00:03:42, lr 0.016332759686137798
# Epoch 171. Valid Loss EMA: -0.220146, Valid acc EMA 0.732472, Best valid acc EMA 0.719752, Time 00:03:42
# Epoch 172. Train Loss: -2.161935, Train Xent: 0.058311, Train Reconst: 0.006636, Train Pn: 0.003462, Train acc 0.984075, Valid Loss: -0.084594, Valid acc 0.718058, Best valid acc 0.719752, Time 00:03:43, lr 0.016094662673547037
# Epoch 172. Valid Loss EMA: -0.231284, Valid acc EMA 0.731470, Best valid acc EMA 0.719752, Time 00:03:43
# Epoch 173. Train Loss: -2.163077, Train Xent: 0.058058, Train Reconst: 0.006729, Train Pn: 0.003406, Train acc 0.984235, Valid Loss: -0.058455, Valid acc 0.714042, Best valid acc 0.719752, Time 00:03:42, lr 0.015860036610660676
# Epoch 173. Valid Loss EMA: -0.231577, Valid acc EMA 0.732472, Best valid acc EMA 0.719752, Time 00:03:42
# Epoch 174. Train Loss: -2.167266, Train Xent: 0.055301, Train Reconst: 0.006808, Train Pn: 0.003340, Train acc 0.984855, Valid Loss: -0.095484, Valid acc 0.720252, Best valid acc 0.720252, Time 00:03:42, lr 0.015628830898390053
# Epoch 174. Valid Loss EMA: -0.232477, Valid acc EMA 0.730869, Best valid acc EMA 0.720252, Time 00:03:42
# Epoch 175. Train Loss: -2.169094, Train Xent: 0.054584, Train Reconst: 0.006579, Train Pn: 0.003302, Train acc 0.984956, Valid Loss: -0.108445, Valid acc 0.717548, Best valid acc 0.720252, Time 00:03:42, lr 0.015400995675273952
# Epoch 175. Valid Loss EMA: -0.230486, Valid acc EMA 0.731370, Best valid acc EMA 0.720252, Time 00:03:42
# Epoch 176. Train Loss: -2.169230, Train Xent: 0.054296, Train Reconst: 0.006634, Train Pn: 0.003263, Train acc 0.985594, Valid Loss: -0.108306, Valid acc 0.718354, Best valid acc 0.720252, Time 00:03:42, lr 0.015176481806725563
# Epoch 176. Valid Loss EMA: -0.219041, Valid acc EMA 0.731871, Best valid acc EMA 0.720252, Time 00:03:42
# Epoch 177. Train Loss: -2.170649, Train Xent: 0.053782, Train Reconst: 0.006730, Train Pn: 0.003254, Train acc 0.984934, Valid Loss: -0.086850, Valid acc 0.715244, Best valid acc 0.720252, Time 00:03:42, lr 0.014955240874436192
# Epoch 177. Valid Loss EMA: -0.226552, Valid acc EMA 0.732272, Best valid acc EMA 0.720252, Time 00:03:42
