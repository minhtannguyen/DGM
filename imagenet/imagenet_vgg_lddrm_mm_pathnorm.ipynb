# %%
import os
import math
import mxnet as mx
from mxnet import image
from mxnet import nd, gluon, autograd, init
from mxnet.gluon.data.vision import ImageFolderDataset
from mxnet.gluon.data import DataLoader
from mxnet.gluon import nn
from tensorboardX import SummaryWriter
import numpy as np
import shutil
import _pickle as cPickle
from sklearn import preprocessing
from mxnet.gluon.parameter import Parameter, ParameterDict
from common.util import download_file
import subprocess
import time

from IPython.core.debugger import Tracer

# %%
def unpickle(file):
    fo = open(file, 'rb')
    dict = cPickle.load(fo, encoding='bytes')
    fo.close()
    return dict

# %%
class Options:
    def __init__(self):
        self.seed_val = 0
        self.num_train_sup = 128000
        self.batch_size = 8
        self.data_dir = '/tanData/datasets/imagenet/data'
        self.log_dir = '/tanData/logs'
        self.model_dir ='/tanData/models'
        self.exp_name = 'imagenet_nlabels_%i_allconv13_lddrm_mm_pathnorm_seed_%i'%(self.num_train_sup, self.seed_val)
        self.gpus = 4
        self.first_gpu = 0
        self.alpha_drm = 0.005
        self.alpha_pn = 0.01
        self.alpha_kl = 0.005
        self.alpha_nn = 0.005
        
        self.use_bias = True
        self.use_bn = True
        self.do_topdown = True
        self.do_countpath = False
        self.do_pn = True
        self.relu_td = False
        self.do_nn = True

opt = Options()

# %%
batch_size = opt.batch_size
batch_size *= max(1, opt.gpus)
ctx = [mx.gpu(i+opt.first_gpu) for i in range(opt.gpus)] if opt.gpus > 0 else [mx.cpu()]
kv = mx.kvstore.create('device')

# %%
def gpu_device(ctx=mx.gpu(0)):
    try:
        _ = mx.nd.array([1, 2, 3], ctx=ctx)
    except mx.MXNetError:
        return None
    return ctx

for i, gpu in enumerate(ctx):
    assert gpu_device(gpu), 'GPU device %i is not available!'%(i + self.first_gpu)

# %%
log_dir = os.path.join(opt.log_dir, opt.exp_name)
if not os.path.exists(log_dir):
    os.makedirs(log_dir)

# %%
train_data_unsup = mx.io.ImageRecordIter(
    path_imgrec=os.path.join(opt.data_dir, 'train_unsup_480.rec'),
    label_width=1,
    data_name='data',
    label_name='softmax_label',
    data_shape=(3, 224, 224),
    batch_size=batch_size // 2,
    mean_r=123.68,
    mean_g=116.779,
    mean_b=103.939,
    pad=0,
    fill_value=0,
    shuffle=True,
    rand_crop=True,
    rand_mirror=True,
    max_random_scale=1.0,
    min_random_scale=0.533,
    max_aspect_ratio=0.25,
    random_h=36,
    random_s=50,
    random_l=50,
    num_parts=kv.num_workers,
    part_index=kv.rank,
    preprocess_threads=32)

train_data_sup = mx.io.ImageRecordIter(
    path_imgrec=os.path.join(opt.data_dir, 'train_sup_480.rec'),
    label_width=1,
    data_name='data',
    label_name='softmax_label',
    data_shape=(3, 224, 224),
    batch_size=batch_size // 2,
    mean_r=123.68,
    mean_g=116.779,
    mean_b=103.939,
    pad=0,
    fill_value=0,
    shuffle=True,
    rand_crop=True,
    rand_mirror=True,
    max_random_scale=1.0,
    min_random_scale=0.533,
    max_aspect_ratio=0.25,
    random_h=36,
    random_s=50,
    random_l=50,
    num_parts=kv.num_workers,
    part_index=kv.rank,
    preprocess_threads=32)

valid_data = mx.io.ImageRecordIter(
    path_imgrec=os.path.join(opt.data_dir,'val_256.rec'),
    label_width=1,
    data_name='data',
    label_name='softmax_label',
    batch_size=batch_size // 2,
    data_shape=(3, 224, 224),
    rand_crop=False,
    rand_mirror=False,
    fill_value=0,
    mean_r=123.68,
    mean_g=116.779,
    mean_b=103.939,
    num_parts=kv.num_workers,
    part_index=kv.rank,
    preprocess_threads=32)

# %%
criterion = gluon.loss.SoftmaxCrossEntropyLoss()
L2_loss = gluon.loss.L2Loss()
L1_loss = gluon.loss.L1Loss()

# %%
class Normal(mx.init.Initializer):
    """Initializes weights with random values sampled from a normal distribution
    with a mean and standard deviation of `sigma`.
    """
    def __init__(self, mean=0, sigma=0.01):
        super(Normal, self).__init__(sigma=sigma)
        self.sigma = sigma
        self.mean = mean

    def _init_weight(self, _, arr):
        mx.random.normal(self.mean, self.sigma, out=arr)

# %%
# from resnet import ResNet164_v2
from mxnet.gluon.model_zoo import vision as models
from vgg_ld_opt_imagenet import VGG_DRM

# %%
acc_top1 = mx.metric.Accuracy()
acc_top5 = mx.metric.TopKAccuracy(5)

# %%
import datetime
writer = SummaryWriter(os.path.join(opt.log_dir, opt.exp_name))

def test(ctx, val_data):
    acc_top1_val = mx.metric.Accuracy()
    acc_top5_val = mx.metric.TopKAccuracy(5)
    for i, batch in enumerate(val_data):
        data = gluon.utils.split_and_load(batch.data[0], ctx_list=ctx, batch_axis=0)
        label = gluon.utils.split_and_load(batch.label[0], ctx_list=ctx, batch_axis=0)
        outputs = [net(X) for X in data]
        acc_top1_val.update(label, outputs)
        acc_top5_val.update(label, outputs)

    _, top1 = acc_top1_val.get()
    _, top5 = acc_top5_val.get()
    return (1 - top1, 1 - top5)

# %%
def train(net, train_data_unsup, train_data_sup, valid_data, num_epochs, lr, wd, ctx, lr_decay, relu_indx):
    trainer = gluon.Trainer(
        net.collect_params(), 'adam', {'learning_rate': 0.0001, 'wd': wd})
    
    prev_time = datetime.datetime.now()
    best_top1_err = np.inf
    best_top5_err = np.inf
    log_interval = 1
    
#     # Learning rate decay factor
#     lr_decay = 0.1
#     # Epochs where learning rate decays
#     lr_decay_epoch = [30, 60, 90, np.inf]

#     # Nesterov accelerated gradient descent
#     optimizer = 'nag'
#     # Set parameters
#     optimizer_params = {'learning_rate': 0.1, 'wd': 0.0001, 'momentum': 0.9}

#     # Define our trainer for net
#     trainer = gluon.Trainer(net.collect_params(), optimizer, optimizer_params)
    
    for epoch in range(num_epochs-100):
        train_data_unsup.reset(); train_data_sup.reset()
        
        tic = time.time()
        btic = time.time()
        acc_top1.reset()
        acc_top5.reset()
        train_loss = 0
        num_batch = 0
        
        if epoch == 100:
            train_data_unsup = mx.io.ImageRecordIter(
                path_imgrec=os.path.join(opt.data_dir, 'train_unsup_256.rec'%(opt.num_train_sup, opt.seed_val)),
                label_width=1,
                data_name='data',
                label_name='softmax_label',
                data_shape=(3, 224, 224),
                batch_size=batch_size // 2,
                mean_r=123.68,
                mean_g=116.779,
                mean_b=103.939,
                pad=0,
                fill_value=0,
                shuffle=True,
                rand_crop=True,
                rand_mirror=True,
                num_parts=kv.num_workers,
                part_index=kv.rank,
                preprocess_threads=32)

            train_data_sup = mx.io.ImageRecordIter(
                path_imgrec=os.path.join(opt.data_dir, 'train_sup_256.rec'%(opt.num_train_sup, opt.seed_val)),
                label_width=1,
                data_name='data',
                label_name='softmax_label',
                data_shape=(3, 224, 224),
                batch_size=batch_size // 2,
                mean_r=123.68,
                mean_g=116.779,
                mean_b=103.939,
                pad=0,
                fill_value=0,
                shuffle=True,
                rand_crop=True,
                rand_mirror=True,
                num_parts=kv.num_workers,
                part_index=kv.rank,
                preprocess_threads=32)
            
        
#         if epoch == 20:
#             sgd_lr = 0.15
#             decay_val = np.exp(np.log(sgd_lr / 0.0001) / (num_epochs - 2))
#             sgd_lr = sgd_lr * decay_val
#             trainer = gluon.Trainer(net.collect_params(), 'SGD', {'learning_rate': sgd_lr, 'wd': wd})
            
#         if epoch >= 20:
#             trainer.set_learning_rate(trainer.learning_rate / decay_val)
        
        for i, (batch_unsup, batch_sup) in enumerate(zip(train_data_unsup, train_data_sup)):
            assert batch_unsup.data[0].shape[0] == batch_sup.data[0].shape[0], "batch_unsup and batch_sup must have the same size"
            
            bs = batch_unsup.data[0].shape[0]
            
            data_unsup = gluon.utils.split_and_load(batch_unsup.data[0], ctx_list=ctx, batch_axis=0)
            label_unsup = gluon.utils.split_and_load(batch_unsup.label[0], ctx_list=ctx, batch_axis=0)
            data_sup = gluon.utils.split_and_load(batch_sup.data[0], ctx_list=ctx, batch_axis=0)
            label_sup = gluon.utils.split_and_load(batch_sup.label[0], ctx_list=ctx, batch_axis=0)
            
            loss = []
            outputs_unsup = []
            outputs_sup = []
            
            with autograd.record():
                for xuns, yuns, xsup, ysup in zip(data_unsup, label_unsup, data_sup, label_sup):
                    [output_unsup, xhat_unsup, _, loss_pn_unsup, loss_nn_unsup] = net(xuns)
                    loss_drm_unsup = L2_loss(xhat_unsup, xuns)
                    softmax_unsup = nd.softmax(output_unsup)
                    loss_kl_unsup = -nd.sum(nd.log(1000.0*softmax_unsup + 1e-8) * softmax_unsup, axis=1)
                    loss_unsup = opt.alpha_drm * loss_drm_unsup + opt.alpha_kl * loss_kl_unsup + opt.alpha_nn * loss_nn_unsup + opt.alpha_pn * loss_pn_unsup

                    [output_sup, xhat_sup, _, loss_pn_sup, loss_nn_sup] = net(xsup, ysup)
                    loss_xentropy_sup = criterion(output_sup, ysup)
                    loss_drm_sup = L2_loss(xhat_sup, xsup)
                    softmax_sup = nd.softmax(output_sup)
                    loss_kl_sup = -nd.sum(nd.log(1000.0*softmax_sup + 1e-8) * softmax_sup, axis=1)
                    loss_sup = loss_xentropy_sup + opt.alpha_drm * loss_drm_sup + opt.alpha_kl * loss_kl_sup + opt.alpha_nn * loss_nn_sup + opt.alpha_pn * loss_pn_sup

                    loss.append(loss_unsup + loss_sup)
                    outputs_sup.append(output_sup)
                    outputs_unsup.append(output_unsup)
                    
            for l in loss:
                l.backward()
                
            trainer.step(bs)
            
            acc_top1.update(label_unsup, outputs_unsup)
            acc_top5.update(label_sup, outputs_sup)
            train_loss += sum([l.sum().asscalar() for l in loss])
            num_batch += 1
            if log_interval and not (i + 1) % log_interval:
                _, top1 = acc_top1.get()
                _, top5 = acc_top5.get()
                err_top1, err_top5 = (1-top1, 1-top5)
                print('Epoch[%d] Batch [%d]     Speed: %f samples/sec   top1-err=%f     top5-err=%f'%(
                          epoch, i, batch_size*log_interval/(time.time()-btic), err_top1, err_top5))
                btic = time.time()
        
        _, top1 = acc_top1.get()
        _, top5 = acc_top5.get()
        err_top1, err_top5 = (1-top1, 1-top5)
        train_loss /= num_batch * batch_size
        writer.add_scalars('acc', {'train_top1': 1.0 - err_top1}, epoch)
        writer.add_scalars('acc', {'train_top5': 1.0 - err_top5}, epoch)
        
        err_top1_val, err_top5_val = test(ctx, valid_data)
        
        if err_top1_val < best_top1_err:
            best_top1_err = err_top1_val
            net.collect_params().save('%s/%s_best_top1.params'%(opt.model_dir, opt.exp_name))
        
        if err_top5_val < best_top5_err:
            best_top5_err = err_top5_val
            net.collect_params().save('%s/%s_best_top5.params'%(opt.model_dir, opt.exp_name))
        
        print('[Epoch %d] training: err-top1=%f err-top5=%f loss=%f'%(epoch, err_top1, err_top5, train_loss))
        print('[Epoch %d] time cost: %f'%(epoch, time.time()-tic))
        print('[Epoch %d] validation: err-top1=%f err-top5=%f'%(epoch, err_top1_val, err_top5_val))
        
        writer.add_scalars('acc', {'valid_top1': 1.0 - err_top1_val}, epoch)
        writer.add_scalars('acc', {'valid_top5': 1.0 - err_top5_val}, epoch)
        
        if not epoch % 50:
            net.collect_params().save('%s/%s_epoch_%i.params'%(opt.model_dir, opt.exp_name, epoch))
    
    return best_top1_err, best_top5_err

# %%
num_epochs = 500
learning_rate = 0.15
weight_decay = 5e-4
lr_decay = 0.1

# %%
def run_train(num_exp, ctx):
    valid_acc = 0
    for i in range(num_exp):
        ### CIFAR VGG_DRM
        model = VGG_DRM('VGG16', batch_size=opt.batch_size // 2, num_class=1000, use_bias=opt.use_bias, use_bn=opt.use_bn, do_topdown=opt.do_topdown, do_countpath=opt.do_countpath, do_pn=opt.do_pn, relu_td=opt.relu_td, do_nn=opt.do_nn)
        for param in model.collect_params().values():
            if param.name.find('conv') != -1 or param.name.find('dense') != -1:
                if param.name.find('weight') != -1:
                    param.initialize(init=mx.initializer.Xavier(), ctx=ctx)
                else:
                    param.initialize(init=mx.init.Zero(), ctx=ctx)
            elif param.name.find('batchnorm') != -1 or param.name.find('instancenorm') != -1:
                if param.name.find('gamma') != -1:
                    param.initialize(init=Normal(mean=1, sigma=0.02), ctx=ctx)
                else:
                    param.initialize(init=mx.init.Zero(), ctx=ctx)
            elif param.name.find('biasadder') != -1:
                param.initialize(init=mx.init.Zero(), ctx=ctx)
                
        # model.hybridize()
        
        relu_indx = []
        
        for i in range(len(model.features._children)):
            if model.features._children[i].name.find('relu') != -1:
                relu_indx.append(i)
                
        best_top1_err, best_top5_err = train(model, train_data_unsup, train_data_sup, valid_data, num_epochs, learning_rate, weight_decay, ctx, lr_decay, relu_indx)

# %%
run_train(1, ctx=ctx)
# Out:
# Epoch[0] Batch [0]     Speed: 2.009015 samples/sec   top1-err=1.000000     top5-err=1.000000
# Epoch[0] Batch
# Epoch[0] Batch [1967]     Speed: 25.604390 samples/sec   top1-err=0.999301     top5-err=1.000000
# Epoch[0] Batch [1968]     Speed: 20.439309 samples/sec   top1-err=0.999302     top5-err=1.000000
# Epoch[0] Batch [1969]     Speed: 24.111877 samples/sec   top1-err=0.999302     top5-err=1.000000
# Epoch[0] Batch [1970]     Speed: 27.604508 samples/sec   top1-err=0.999302     top5-err=1.000000
# Epoch[0] Batch [1971]     Speed: 26.858990 samples/sec   top1-err=0.999303     top5-err=1.000000
# Epoch[0] Batch [1972]     Speed: 25.518352 samples/sec   top1-err=0.999303     top5-err=1.000000
# Epoch[0] Batch [1973]     Speed: 25.474099 samples/sec   top1-err=0.999303     top5-err=1.000000
# Epoch[0] Batch [1974]     Speed: 22.135972 samples/sec   top1-err=0.999304     top5-err=1.000000
# Epoch[0] Batch [1975]     Speed: 25.366150 samples/sec   top1-err=0.999304     top5-err=1.000000
# Epoch[0] Batch [1976]     Speed: 25.152866 samples/sec   top1-err=0.999305     top5-err=1.000000
# Epoch[0] Batch [1977]     Speed: 23.810185 samples/sec   top1-err=0.999305     top5-err=1.000000
# Epoch[0] Batch [1978]     Speed: 27.290831 samples/sec   top1-err=0.999305     top5-err=1.000000
# Epoch[0] Batch [1979]     Speed: 27.991225 samples/sec   top1-err=0.999306     top5-err=1.000000
# Epoch[0] Batch [1980]     Speed: 24.590604 samples/sec   top1-err=0.999306     top5-err=1.000000
# Epoch[0] Batch [1981]     Speed: 23.104638 samples/sec   top1-err=0.999306     top5-err=1.000000
# Epoch[0] Batch [1982]     Speed: 28.627271 samples/sec   top1-err=0.999307     top5-err=1.000000
# Epoch[0] Batch [1983]     Speed: 25.669048 samples/sec   top1-err=0.999307     top5-err=1.000000
# Epoch[0] Batch [1984]     Speed: 27.285866 samples/sec   top1-err=0.999307     top5-err=1.000000
# Epoch[0] Batch [1985]     Speed: 27.545419 samples/sec   top1-err=0.999308     top5-err=1.000000
# Epoch[0] Batch [1986]     Speed: 23.053789 samples/sec   top1-err=0.999308     top5-err=1.000000
# Epoch[0] Batch [1987]     Speed: 25.183372 samples/sec   top1-err=0.999308     top5-err=1.000000
# Epoch[0] Batch [1988]     Speed: 24.198700 samples/sec   top1-err=0.999309     top5-err=1.000000
# Epoch[0] Batch [1989]     Speed: 25.816558 samples/sec   top1-err=0.999309     top5-err=1.000000
# Epoch[0] Batch [1990]     Speed: 24.815696 samples/sec   top1-err=0.999309     top5-err=1.000000
# Epoch[0] Batch [1991]     Speed: 25.285708 samples/sec   top1-err=0.999310     top5-err=1.000000
# Epoch[0] Batch [1992]     Speed: 25.050613 samples/sec   top1-err=0.999310     top5-err=1.000000
# Epoch[0] Batch [1993]     Speed: 26.254371 samples/sec   top1-err=0.999310     top5-err=1.000000
# Epoch[0] Batch [1994]     Speed: 25.245500 samples/sec   top1-err=0.999311     top5-err=1.000000
# Epoch[0] Batch [1995]     Speed: 24.279829 samples/sec   top1-err=0.999311     top5-err=1.000000
# Epoch[0] Batch [1996]     Speed: 26.279087 samples/sec   top1-err=0.999311     top5-err=1.000000
# Epoch[0] Batch [1997]     Speed: 23.885979 samples/sec   top1-err=0.999312     top5-err=1.000000
# Epoch[0] Batch [1998]     Speed: 25.143249 samples/sec   top1-err=0.999312     top5-err=1.000000
# Epoch[0] Batch [1999]     Speed: 25.756473 samples/sec   top1-err=0.999313     top5-err=1.000000
# Epoch[0] Batch [2000]     Speed: 24.351373 samples/sec   top1-err=0.999313     top5-err=1.000000
# Epoch[0] Batch [2001]     Speed: 27.567331 samples/sec   top1-err=0.999313     top5-err=1.000000
# Epoch[0] Batch [2002]     Speed: 26.436987 samples/sec   top1-err=0.999314     top5-err=1.000000
# Epoch[0] Batch [2003]     Speed: 24.430412 samples/sec   top1-err=0.999314     top5-err=1.000000
# Epoch[0] Batch [2004]     Speed: 25.735533 samples/sec   top1-err=0.999314     top5-err=1.000000
# Epoch[0] Batch [2005]     Speed: 25.377363 samples/sec   top1-err=0.999315     top5-err=1.000000
# Epoch[0] Batch [2006]     Speed: 24.419571 samples/sec   top1-err=0.999315     top5-err=1.000000
# Epoch[0] Batch [2007]     Speed: 19.629715 samples/sec   top1-err=0.999284     top5-err=1.000000
# Epoch[0] Batch [2008]     Speed: 23.934772 samples/sec   top1-err=0.999284     top5-err=1.000000
# Epoch[0] Batch [2009]     Speed: 25.837103 samples/sec   top1-err=0.999285     top5-err=1.000000
# Epoch[0] Batch [2010]     Speed: 28.332085 samples/sec   top1-err=0.999285     top5-err=1.000000
# Epoch[0] Batch [2011]     Speed: 28.693404 samples/sec   top1-err=0.999286     top5-err=1.000000
# Epoch[0] Batch [2012]     Speed: 25.964879 samples/sec   top1-err=0.999286     top5-err=1.000000
# Epoch[0] Batch [2013]     Speed: 24.511770 samples/sec   top1-err=0.999286     top5-err=1.000000
# Epoch[0] Batch [2014]     Speed: 27.656395 samples/sec   top1-err=0.999287     top5-err=1.000000
# Epoch[0] Batch [2015]     Speed: 23.894743 samples/sec   top1-err=0.999287     top5-err=1.000000
# Epoch[0] Batch [2016]     Speed: 27.577612 samples/sec   top1-err=0.999287     top5-err=1.000000
# Epoch[0] Batch [2017]     Speed: 26.669972 samples/sec   top1-err=0.999288     top5-err=1.000000
# Epoch[0] Batch [2018]     Speed: 25.531643 samples/sec   top1-err=0.999288     top5-err=1.000000
# Epoch[0] Batch [2019]     Speed: 26.293434 samples/sec   top1-err=0.999288     top5-err=1.000000
# Epoch[0] Batch [2020]     Speed: 26.136201 samples/sec   top1-err=0.999289     top5-err=1.000000
# Epoch[0] Batch [2021]     Speed: 23.380993 samples/sec   top1-err=0.999289     top5-err=1.000000
# Epoch[0] Batch [2022]     Speed: 26.328538 samples/sec   top1-err=0.999289     top5-err=1.000000
# Epoch[0] Batch [2023]     Speed: 27.508092 samples/sec   top1-err=0.999290     top5-err=1.000000
# Epoch[0] Batch [2024]     Speed: 23.122756 samples/sec   top1-err=0.999290     top5-err=1.000000
# Epoch[0] Batch [2025]     Speed: 27.446501 samples/sec   top1-err=0.999290     top5-err=1.000000
# Epoch[0] Batch [2026]     Speed: 21.905145 samples/sec   top1-err=0.999291     top5-err=1.000000
# Epoch[0] Batch [2027]     Speed: 27.180607 samples/sec   top1-err=0.999291     top5-err=1.000000
# Epoch[0] Batch [2028]     Speed: 25.169455 samples/sec   top1-err=0.999292     top5-err=1.000000
# Epoch[0] Batch [2029]     Speed: 24.323954 samples/sec   top1-err=0.999292     top5-err=1.000000
# Epoch[0] Batch [2030]     Speed: 24.731997 samples/sec   top1-err=0.999292     top5-err=1.000000
# Epoch[0] Batch [2031]     Speed: 24.861244 samples/sec   top1-err=0.999293     top5-err=1.000000
# Epoch[0] Batch [2032]     Speed: 28.098992 samples/sec   top1-err=0.999293     top5-err=1.000000
# Epoch[0] Batch [2033]     Speed: 22.927156 samples/sec   top1-err=0.999293     top5-err=1.000000
# Epoch[0] Batch [2034]     Speed: 23.459462 samples/sec   top1-err=0.999294     top5-err=1.000000
# Epoch[0] Batch [2035]     Speed: 25.163995 samples/sec   top1-err=0.999294     top5-err=1.000000
# Epoch[0] Batch [2036]     Speed: 25.358851 samples/sec   top1-err=0.999294     top5-err=1.000000
# Epoch[0] Batch [2037]     Speed: 25.992539 samples/sec   top1-err=0.999295     top5-err=1.000000
# Epoch[0] Batch [2038]     Speed: 27.014178 samples/sec   top1-err=0.999295     top5-err=1.000000
# Epoch[0] Batch [2039]     Speed: 25.318467 samples/sec   top1-err=0.999295     top5-err=1.000000
# Epoch[0] Batch [2040]     Speed: 22.256370 samples/sec   top1-err=0.999296     top5-err=1.000000
# Epoch[0] Batch [2041]     Speed: 23.769145 samples/sec   top1-err=0.999296     top5-err=1.000000
# Epoch[0] Batch [2042]     Speed: 26.707072 samples/sec   top1-err=0.999296     top5-err=1.000000
# Epoch[0] Batch [2043]     Speed: 25.555137 samples/sec   top1-err=0.999297     top5-err=1.000000
# Epoch[0] Batch [2044]     Speed: 27.332552 samples/sec   top1-err=0.999297     top5-err=1.000000
# Epoch[0] Batch [2045]     Speed: 27.079445 samples/sec   top1-err=0.999297     top5-err=1.000000
# Epoch[0] Batch [2046]     Speed: 24.733214 samples/sec   top1-err=0.999298     top5-err=1.000000
# Epoch[0] Batch [2047]     Speed: 26.072610 samples/sec   top1-err=0.999298     top5-err=1.000000
# Epoch[0] Batch [2048]     Speed: 26.153272 samples/sec   top1-err=0.999298     top5-err=1.000000
# Epoch[0] Batch [2049]     Speed: 27.958392 samples/sec   top1-err=0.999299     top5-err=1.000000
# Epoch[0] Batch [2050]     Speed: 24.713717 samples/sec   top1-err=0.999299     top5-err=1.000000
# Epoch[0] Batch [2051]     Speed: 25.233421 samples/sec   top1-err=0.999299     top5-err=1.000000
# Epoch[0] Batch [2052]     Speed: 27.152662 samples/sec   top1-err=0.999300     top5-err=1.000000
# Epoch[0] Batch [2053]     Speed: 26.088234 samples/sec   top1-err=0.999300     top5-err=1.000000
# Epoch[0] Batch [2054]     Speed: 22.495721 samples/sec   top1-err=0.999300     top5-err=1.000000
# Epoch[0] Batch [2055]     Speed: 25.290239 samples/sec   top1-err=0.999301     top5-err=1.000000
# Epoch[0] Batch [2056]     Speed: 26.903012 samples/sec   top1-err=0.999301     top5-err=1.000000
# Epoch[0] Batch [2057]     Speed: 25.261418 samples/sec   top1-err=0.999302     top5-err=1.000000
# Epoch[0] Batch [2058]     Speed: 25.759963 samples/sec   top1-err=0.999302     top5-err=1.000000
# Epoch[0] Batch [2059]     Speed: 26.922326 samples/sec   top1-err=0.999302     top5-err=1.000000
# Epoch[0] Batch [2060]     Speed: 23.002607 samples/sec   top1-err=0.999303     top5-err=1.000000
# Epoch[0] Batch [2061]     Speed: 23.632778 samples/sec   top1-err=0.999303     top5-err=1.000000
# Epoch[0] Batch [2062]     Speed: 23.763745 samples/sec   top1-err=0.999303     top5-err=1.000000
# Epoch[0] Batch [2063]     Speed: 25.881639 samples/sec   top1-err=0.999304     top5-err=1.000000
# Epoch[0] Batch [2064]     Speed: 26.952011 samples/sec   top1-err=0.999304     top5-err=1.000000
# Epoch[0] Batch [2065]     Speed: 25.574522 samples/sec   top1-err=0.999304     top5-err=1.000000
# Epoch[0] Batch [2066]     Speed: 24.309336 samples/sec   top1-err=0.999305     top5-err=1.000000
# Epoch[0] Batch [2067]     Speed: 24.061342 samples/sec   top1-err=0.999305     top5-err=1.000000
# Epoch[0] Batch [2068]     Speed: 23.039510 samples/sec   top1-err=0.999305     top5-err=1.000000
# Epoch[0] Batch [2069]     Speed: 27.582968 samples/sec   top1-err=0.999275     top5-err=1.000000
# Epoch[0] Batch [2070]     Speed: 27.079205 samples/sec   top1-err=0.999276     top5-err=1.000000
# Epoch[0] Batch [2071]     Speed: 27.147632 samples/sec   top1-err=0.999276     top5-err=1.000000
# Epoch[0] Batch [2072]     Speed: 26.627881 samples/sec   top1-err=0.999276     top5-err=1.000000
# Epoch[0] Batch [2073]     Speed: 23.100904 samples/sec   top1-err=0.999277     top5-err=1.000000
# Epoch[0] Batch [2074]     Speed: 24.977929 samples/sec   top1-err=0.999277     top5-err=1.000000
# Epoch[0] Batch [2075]     Speed: 24.774315 samples/sec   top1-err=0.999277     top5-err=1.000000
# Epoch[0] Batch [2076]     Speed: 24.734923 samples/sec   top1-err=0.999278     top5-err=1.000000
# Epoch[0] Batch [2077]     Speed: 27.282682 samples/sec   top1-err=0.999278     top5-err=1.000000
# Epoch[0] Batch [2078]     Speed: 25.249936 samples/sec   top1-err=0.999278     top5-err=1.000000
# Epoch[0] Batch [2079]     Speed: 27.695509 samples/sec   top1-err=0.999279     top5-err=1.000000
# Epoch[0] Batch [2080]     Speed: 23.966437 samples/sec   top1-err=0.999279     top5-err=1.000000
# Epoch[0] Batch [2081]     Speed: 25.697036 samples/sec   top1-err=0.999280     top5-err=1.000000
# Epoch[0] Batch [2082]     Speed: 26.135819 samples/sec   top1-err=0.999280     top5-err=1.000000
# Epoch[0] Batch [2083]     Speed: 27.202907 samples/sec   top1-err=0.999280     top5-err=1.000000
# Epoch[0] Batch [2084]     Speed: 25.897759 samples/sec   top1-err=0.999281     top5-err=1.000000
# Epoch[0] Batch [2085]     Speed: 26.122893 samples/sec   top1-err=0.999281     top5-err=1.000000
# Epoch[0] Batch [2086]     Speed: 26.387434 samples/sec   top1-err=0.999281     top5-err=1.000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-f911d46ca9a1> in <module>()
# ----> 1 run_train(1, ctx=ctx)
#
# <ipython-input-15-82ac1c22d968> in run_train(num_exp, ctx)
#      26                 relu_indx.append(i)
#      27
# ---> 28         best_top1_err, best_top5_err = train(model, train_data_unsup, train_data_sup, valid_data, num_epochs, learning_rate, weight_decay, ctx, lr_decay, relu_indx)
#
# <ipython-input-13-3af1ba482368> in train(net, train_data_unsup, train_data_sup, valid_data, num_epochs, lr, wd, ctx, lr_decay, relu_indx)
#      96             with autograd.record():
#      97                 for xuns, yuns, xsup, ysup in zip(data_unsup, label_unsup, data_sup, label_sup):
# ---> 98                     [output_unsup, xhat_unsup, _, loss_pn_unsup, loss_nn_unsup] = net(xuns)
#      99                     loss_drm_unsup = L2_loss(xhat_unsup, xuns)
#     100                     softmax_unsup = nd.softmax(output_unsup)
#
# /home/ubuntu/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/mxnet/gluon/block.py in __call__(self, *args)
#     358     def __call__(self, *args):
#     359         """Calls forward. Only accepts positional arguments."""
# --> 360         return self.forward(*args)
#     361
#     362     def forward(self, *args):
#
# /home/ubuntu/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/mxnet/gluon/block.py in forward(self, x, *args)
#     573                     return self._call_cached_op(x, *args)
#     574                 params = {i: j.data(ctx) for i, j in self._reg_params.items()}
# --> 575                 return self.hybrid_forward(ndarray, x, *args, **params)
#     576
#     577         assert isinstance(x, Symbol), \
#
# ~/repos/DRMM/classification/cifar/vgg_ld_opt_imagenet.py in hybrid_forward(self, F, x, y)
#     262                             xbias = self.insnorms_fw[insnormfw_indx](xbias)
#     263                             insnormfw_indx += 1
# --> 264                         else:
#     265                             xbias = layer(xbias)
#     266                     if layer.name.find('relu') != -1:
#
# /home/ubuntu/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/mxnet/gluon/block.py in __call__(self, *args)
#     358     def __call__(self, *args):
#     359         """Calls forward. Only accepts positional arguments."""
# --> 360         return self.forward(*args)
#     361
#     362     def forward(self, *args):
#
# /home/ubuntu/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/mxnet/gluon/block.py in forward(self, x, *args)
#     573                     return self._call_cached_op(x, *args)
#     574                 params = {i: j.data(ctx) for i, j in self._reg_params.items()}
# --> 575                 return self.hybrid_forward(ndarray, x, *args, **params)
#     576
#     577         assert isinstance(x, Symbol), \
#
# /home/ubuntu/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/mxnet/gluon/nn/conv_layers.py in hybrid_forward(self, F, x, weight, bias)
#     130     def hybrid_forward(self, F, x, weight, bias=None):
#     131         if bias is None:
# --> 132             act = getattr(F, self._op_name)(x, weight, name='fwd', **self._kwargs)
#     133         else:
#     134             act = getattr(F, self._op_name)(x, weight, bias, name='fwd', **self._kwargs)
#
# /home/ubuntu/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/mxnet/ndarray/register.py in Convolution(data, weight, bias, kernel, stride, dilate, pad, num_filter, num_group, workspace, no_bias, cudnn_tune, cudnn_off, layout, out, name, **kwargs)
#
# /home/ubuntu/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/mxnet/_ctypes/ndarray.py in _imperative_invoke(handle, ndargs, keys, vals, out)
#      90         c_str_array(keys),
#      91         c_str_array([str(s) for s in vals]),
# ---> 92         ctypes.byref(out_stypes)))
#      93
#      94     if original_output is not None:
#
# KeyboardInterrupt:
